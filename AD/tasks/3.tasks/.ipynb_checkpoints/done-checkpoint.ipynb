# %% [markdown]
# # <a href="https://mipt-stats.gitlab.io/courses/ad_fivt.html">Введение в анализ данных</a>
# ## Домашнее задание 3. Сбор и анализ данных.

# %% [markdown]
# **Правила, <font color="red">прочитайте внимательно</font>:**
#
# * Выполненную работу нужно отправить телеграм-боту `@miptstats_ds22_bot`. Для начала работы с ботом каждый раз отправляйте `/start`. Работы, присланные иным способом, не принимаются.
# * Дедлайн см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно ноутбук в формате ipynb.
# * Телеграм не разрешает боту получать файлы более **20 Мб**. Если ваше решение весит больше, *заранее* разделите ноутбук на несколько.
# * Будьте внимательны при работе со сбором данных. Ответственность за корректность ваших действий лежит на вас. Не нагружайте сервера, *делайте паузы между запросами*. Как следствие, начинайте выполнять задание заранее. **Если вас где-то забаннили и т.п., то это не является уважительной причиной продления дедлайна.**
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания будут сдавать устный зачет.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, ничего не удаляя из него. Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
#
# **Перед выполнением задания посмотрите презентацию по выполнению и оформлению домашних заданий с занятия 2.**
#
# ---
#
# **Баллы за задание:**
#
# <b><font color="blue">Легкая часть</font></b> (достаточно на "хор"):
# * Задача 1 &mdash; 50 баллов
#
# <b><font color="orange">Сложная часть</font></b> (необходимо на "отл"):
# * Задача 2 &mdash; 80 баллов
# * Задача 3 &mdash; 100 баллов
#
# ---

# %% [markdown]
# **Добрый день, уважаемый проверяющий.** Я очень старался, делая это задание, надеюсь и вам будет приятно его проверять. Иногда я использовал стандартный plt (а не sns), чтобы разобраться в базовой библиотеке, надеюсь это не проблема.

# %%
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install seaborn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid', font_scale=1.3, palette='Set2')
# %matplotlib inline

print("Success")
# Out:
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (1.22.2)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (1.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from pandas) (1.22.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/six/1.16.0_2/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from seaborn) (1.8.0)
# Requirement already satisfied: numpy>=1.15 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from seaborn) (1.22.2)
# Requirement already satisfied: pandas>=0.23 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/six/1.16.0_2/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Success

# %% [markdown]
# ### <font color="blue"><i>Легкая часть</i></font>
#
#
# ### Задача 1.

# %% [markdown]
# На занятии мы уже <a href="https://mipt-stats.gitlab.io/courses/ad_fivt/titanik.html" target="_blank">начинали</a> работать с датасетом Титаник. Сейчас ваша задача &mdash; на основе простого анализа предоставленных данных получить некоторое приближенное правило определения, выжил пассажир или нет.
#
# #### 1. Подготовка данных
#
# Загрузите данные с помощью `pandas`.

# %%
PATH_TO_DATASET = "titanik.csv"

# %%
data = pd.read_csv(PATH_TO_DATASET)
# data

# %% [markdown]
# Разделите данные по строкам на две части случайным образом в соотношении 7:3. Первую часть мы будем называть *обучающей*, а вторую &mdash; *тестовой*.

# %%
train = data.sample(frac=0.7, random_state=0).sort_values(by='PassengerId')
test = data.drop(train.index).sort_values(by='PassengerId').reset_index(drop=True)
train.reset_index(drop=True, inplace=True)
# print(train["PassengerId"], test["PassengerId"])

# %% [markdown]
# Из каждой части оставим несколько признаков, с которыми мы будем работать, а также отдельно &mdash; целевой признак. Примените к обеим частям таблицы функцию ниже

# %%
features_columns = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']
target_column = 'Survived'  # Целевой признак

def get_features_and_target(data):
    features = data[features_columns]
    target = data[target_column]
    return features, target

# %%
train, train_target = get_features_and_target(train)
test, test_target = get_features_and_target(test)

# %% [markdown]
# #### 2. Исследование
#
# **Внимание.** Эта часть задачи должна выполняться *исключительно на обучающих данных*. За использование тестовых данных решение не будет оценено.
#
# Проведите визуальный анализ данных чтобы понять, как различные признаки влияют на целевой. Исследовать можно не целиком обучающие данные, а разделить их на две части по одному из признаков, а далее рассматривать каждую часть отдельно.
#
# *Не забывайте про информативность и эстетичность графиков.*

# %% [markdown]
# **Здесь я решил проверить как устроена таблица, чтобы удостовериться о типах и пропусках.**

# %%
print("NaNs:\n\n", train.isna().sum())

print("\nTypes:\n\n", train.dtypes)
# Out:
# NaNs:
#
#  Pclass      0
# Sex         0
# Age       121
# SibSp       0
# Parch       0
# Fare        0
# dtype: int64
#
# Types:
#
#  Pclass      int64
# Sex        object
# Age       float64
# SibSp       int64
# Parch       int64
# Fare      float64
# dtype: object

# %% [markdown]
# **Создадим функцию plot_data, с помощью которой построим 6 графиков с зависимостями каждой величины (Pclass/Sex/...) от целевого признака. Разместим их на одной Figure.**

# %%
plt.rcParams['figure.figsize'] = [14, 14]

def plot_data(data, target, label):
    fig, axs = plt.subplots(3, 2)
    fig.suptitle(label, fontsize=32)
    plt.subplots_adjust(wspace=0.5, hspace=0.5)

    for i, column in enumerate(train.columns):
        ax = axs[i // 2][i % 2]
        ax.hist([data[target == 1][column], data[target == 0][column]],
                    bins=20, label=['Выжившие', 'Не выжившие'])
        ax.legend()
        ax.set_title(f'Распределение {str(column)}')
        ax.set_xlabel(column)
        ax.set_ylabel("Количество")

plot_data(train, train_target, "Все данные")

# %% [markdown]
# **Разделим людей по признаку Sex и рассмотрим отдельно данные для мужчин и женщин**

# %%
plot_data(train[train["Sex"] == 'male'], train_target[train["Sex"] == 'male'], "Данные среди мужчин")

# %%
plot_data(train[train["Sex"] == 'female'], train_target[train["Sex"] == 'female'], "Данные среди женщин")

# %% [markdown]
# **Подробнее рассмотрим график Цены билета(Fare). Это понадобится нам для дерева2.**

# %%
ax = plt.axes()
ax.hist([train[train_target == 1]["Fare"], train[train_target == 0]["Fare"]],
                    bins=30, label=['Выжившие', 'Не выжившие'])
ax.legend()
ax.set_title(f'Распределение Fare')
ax.set_xlabel("Fare")
ax.set_xticks(np.arange(0, 300, 50))
ax.set_xlim(right=300)
ax.set_ylabel("Количество")
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# #### 3. Классификация
#
# На основе проведенного исследования предложите два разных правила в виде решающего дерева, пример которого можете посмотреть в презентации с первой лекции (классификация котиков).
#
# В данной задаче достаточно, если первое дерево будет иметь максимальную глубину 2, а второе &mdash; глубину 1, и при этом не является поддеревом первого. *Примечание*: дерево из одного листа имеет глубину 0.
#
# **Дерево 1:**
#
# **Легко заметить, что есть женщины чаще выживают, мужчины чаще - нет.**
# **После выбора первичного признака(Sex), попробуем подробнее рассмотреть мужчин и женщин отдельно.\
# Заметим, что женщины с Pclass = 3 реже выживают, чем умирают.\
# Заметим, что мужчины с небольшим Age чаще выживают, чем умирают.\
# В обоих утверждениях имеется логика, к тому же.**
#
# **Дерево 2:**
#
# **Внимателнее взглянув на график распределения Цены билета, выведем критерий Fare > 50.**
#
# Реализуйте полученные деревья по шаблону,

# %%
'''
    Предсказание целевого признака для данных features -- pandas-таблица данных.
    Возвращает pandas.Series с теми же индексами, что и у features.
'''

def tree1(features):
    female = (features["Sex"] == 'female')
    klass = (features["Pclass"] < 2.5)
    age = (features["Age"] < 5)
    return ((female & klass) | (~female & age)).apply(lambda x: 1 if x else 0)

def tree2(features):
    prediction = (features["Fare"] > 50)
    return prediction.apply(lambda x: 1 if x else 0)

# %% [markdown]
# #### 4. Качество
#
# Вспомним, что у нас имеется тестовая часть выборки. Самое время ее использовать для того, чтобы оценить, насколько хорошими получились деревья. Предложите какой-нибудь критерий качества.
#
# *Замечание*. Не стоит пытаться искать, какие критерии существуют. В данном случае легко предложить адекватный критерий. Стандартные критерии мы разберем позже, но для начала лучше подумать самостоятельно.
#
# **Критерий:**
#
# **Соотношение верно угаданных ко всем.**
#
# Реализуйте данный критерий по шаблону

# %%
def criteria(target, predicted):
    array = (target == predicted)
    return len(array[array == True]) / len(array)

# %% [markdown]
# Посчитайте качество полученных ранее деревьев
#
# *Примечание.* Полученные значения не влияют на оценку по задание. Оценивается только корректность и обоснованность решения, а также графики и выводы.
#
# **Выведем качество деревьев на тренировочной выборке(нерепрезентативно) и на контрольной.**

# %%
print(f"!Нерепрезентативно!, дерево глубины 2: {criteria(train_target, tree1(train))}")
print(f"!Нерепрезентативно!, дерево глубины 1: {criteria(train_target, tree2(train))}")
print()
print(f"Дерево глубины 2: {criteria(test_target, tree1(test))}")
print(f"Дерево глубины 1: {criteria(test_target, tree2(test))}")
# Out:
# !Нерепрезентативно!, дерево глубины 2: 0.8157051282051282
# !Нерепрезентативно!, дерево глубины 1: 0.6971153846153846
#
# Дерево глубины 2: 0.7453183520599251
# Дерево глубины 1: 0.6441947565543071

# %% [markdown]
# #### 5. Выводы

# %% [markdown]
# **После анализа графиков различных признаков в зависимости от целевого признака удалось найти признаки, по которым были построены решающие деревья. Признаки: Пол(первичный), Возраст и Класс билета, а также Цена билета.**
#
# Выведены закономерности - выживали чаще:
# 1. Женщины
# 2. Дети
# 3. Люди с высоким классом билета
# 4. Люди с высокой ценой билета

# %% [markdown]
# ---
# ### <font color="orange"><i>Сложная часть</i></font>

# %% [markdown]
# ### Задача 2

# %% [markdown]
# <a target="_blank" href="yelp.com">Yelp</a> — веб-сайт для поиска на местном рынке услуг, например ресторанов или парикмахерских, с возможностью добавлять и просматривать рейтинги и обзоры этих услуг. Для популярных бизнесов имеются сотни обзоров. Для обозревателей на сайте предусмотрены элементы социальной сети.
#
# ![Yelp_Logo_No_Outline_Color.jpg](attachment:Yelp_Logo_No_Outline_Color.jpg)
#
# _____________
#
# Вам предоставляется следующая информация о компаниях на Yelp:
#
# Файл `yelp_business.csv`:
# * `business_id` — уникальный идентификатор компании;
# * `name` — имя компании;
# * `address`, `city`, `state` — месторасположении компании;
# * `latitude`, `longitude` — географические координаты;
# * `categories` — категории услуг компании.
#
# Файл `yelp_review.csv`, содержащий оценки пользователей:
# * `business_id` — идентификатор компании, соответствующий файлу `yelp_business.csv`;
# * `stars` — поставленная пользователем оценка от 1 до 5.
#
# В целях сокращения объема файла, текстовые отзывы пользователей не были включены.
#
# Оригинальную версию датасета в формате `json` можно посмотреть по <a target="_blank" href="https://www.kaggle.com/yelp-dataset/yelp-dataset/data">ссылке</a>.
#
# _____________
#
# **Что нужно сделать:**
#
# * Найти город с наибольшим количеством компаний;
# * Для этого города определить районы с наиболее качественными услугами. <a target="_blank" href="https://yandex.ru/company/researches/2017/msk_mobile_map">Пример</a> с несколько другой задачей.
# * А также найти рестораны с наилучшими отзывами.
#
# ------

# %% [markdown]
# ### Note: В этом задании пояснения часто излишни, ведь задания вполне исчерпывающие.

# %% [markdown]
# #### Город с наибольшим количеством компаний
#
# Загрузите данные из файла `yelp_business.csv` с помощью функции `pd.read_csv`. Посмотрите на первые несколько строк с помощью метода `head`.

# %%
data = pd.read_csv("yelp_business.csv")
data.head()
# Out:
#    Unnamed: 0             business_id                        name  \
# 0           0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"
# 1           1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"
# 2           2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"
# 3           3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"
# 4           4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"
#
#   neighborhood                           address            city state  \
# 0          NaN        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ
# 1          NaN              "3101 Washington Rd"        McMurray    PA
# 2          NaN          "6025 N 27th Ave, Ste 1"         Phoenix    AZ
# 3          NaN  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ
# 4          NaN                    "581 Howe Ave"  Cuyahoga Falls    OH
#
#   postal_code   latitude   longitude  is_open  \
# 0       85044  33.330690 -111.978599        1
# 1       15317  40.291685  -80.104900        1
# 2       85017  33.524903 -112.115310        1
# 3       85282  33.383147 -111.964725        0
# 4       44221  41.119535  -81.475690        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %% [markdown]
# Найдите пять городов, по которым присутствует информация о наибольшем количестве компаний. В таблице должен быть указан город (название) и количество компаний в этом городе.
#
# *Подсказка.* Для выполнения стоит воспользоваться методами `groupby`, `count`, `sort_values`, `head`.

# %%
top = data.groupby("city").count().sort_values(by="business_id", ascending=False).head(5)
target_city = top.index[0]
top
# Out:
#             Unnamed: 0  business_id   name  neighborhood  address  state  \
# city
# Las Vegas        26775        26775  26775         21887    26775  26775
# Phoenix          17213        17213  17213             0    17213  17213
# Toronto          17206        17206  17206         14064    17206  17206
# Charlotte         8553         8553   8553          5844     8553   8553
# Scottsdale        8228         8228   8228             0     8228   8228
#
#             postal_code  latitude  longitude  is_open  categories
# city
# Las Vegas         26655     26775      26775    26775       26775
# Phoenix           17121     17213      17213    17213       17213
# Toronto           17102     17205      17205    17206       17206
# Charlotte          8517      8553       8553     8553        8553
# Scottsdale         8201      8228       8228     8228        8228

# %% [markdown]
# Пусть `N` &mdash; город с наибольшим количеством компаний. Оставьте в таблице только записи, соответствующие городу `N`. Нанесите все эти компании на график, в котором по оси $x$ отметьте долготу, а по оси $y$ &mdash; широту.

# %%
target_data = data[data.city == target_city]
target_data = target_data.drop('Unnamed: 0', axis='columns')

# %% [markdown]
# **Перед выполнением графической части второго задания(начиная с этого момента), ожидается, что первое задание было полностью запущено. Это повлияет на внешний вид графиков.**

# %%
ax = plt.axes()
ax.scatter(target_data.longitude, target_data.latitude)
ax.set_xlabel("Долгота")
ax.set_ylabel("Широта")
ax.set_title("Бизнесы в Лас-Вегасе")
# Out:
# Text(0.5, 1.0, 'Бизнесы в Лас-Вегасе')

# %% [markdown]
# Сам город находится в сгустке точек. Есть какие-то компании, которые приписаны к этому городу, но находятся далеко от него. Избавьтесь от них, подобрав некоторые границы значений широты и долготы. Изобразите все компании на новом графике.
#
# На этом графике должны выделяться некоторые улицы. Откройте карту города `N` и сравните ее с построенным графиком.
#
# *Замечание. Подгружать карту города в качестве фона графика мы научимся чуть позже.*

# %%
ax = plt.axes()
target_data = target_data[target_data.longitude.between(-116, -114) & target_data.latitude.between(35, 40)] 
ax.scatter(target_data.longitude, target_data.latitude, s=2)
ax.set_xlabel("Долгота")
ax.set_ylabel("Широта")
ax.set_title("Бизнесы в Лас-Вегасе")
# Out:
# Text(0.5, 1.0, 'Бизнесы в Лас-Вегасе')

# %% [markdown]
# Интересно, что увеличив масштам и уменьшив точки, мы можем заметить улицы, вдоль которых расположены бизнесы.

# %% [markdown]
# #### Оценки компаний
#
# Для выполнения задания нужно посчитать среднюю оценку каждой компании, а также количество выставленных оценок.
#
# Загрузите таблицу оценок `yelp_review.csv`.

# %%
reviews = pd.read_csv("yelp_review.csv")
reviews
# Out:
#          Unnamed: 0             business_id  stars
# 0                 0  AEx2SYEUJmTxVVB18LlCwA      5
# 1                 1  VR6GpWIda3SfvPC-lg9H3w      5
# 2                 2  CKC0-MOWMqoeWf6s-szl8g      5
# 3                 3  ACFtxLv8pGrrxMm6EgjreA      4
# 4                 4  s2I_Ni76bjJNK9yG60iD-Q      4
# ...             ...                     ...    ...
# 5261663     5261663  Ngk84Ax1tXgpoJFEGxot3w      1
# 5261664     5261664  pOEL97ld-FJMKO8Ki8JmYg      3
# 5261665     5261665  5ubokMNw8qfbX2WtxgJG1Q      4
# 5261666     5261666  EO3i5kTUG7_S2OIQ23sdSA      3
# 5261667     5261667  HloEEXm_QzEpycuwA_RtQA      3
#
# [5261668 rows x 3 columns]

# %% [markdown]
# В подгруженной таблице оценок оставьте только компании города `N`. Для этого установите значения `business_id` в качестве индекса у таблицы оценок и воспользуйтесь методом `loc`.
#
# *Подсказка.* Чтобы индекс снова сделать полем таблицы, можно воспользоваться методом `reset_index`.

# %%
target_reviews = reviews.set_index("business_id").loc[target_data["business_id"]].reset_index()
target_reviews = target_reviews.reindex(columns=["business_id", "stars"])
target_reviews
# Out:
#                     business_id  stars
# 0        kCoE3jvEtg6UVz5SOD3GVw      4
# 1        kCoE3jvEtg6UVz5SOD3GVw      1
# 2        kCoE3jvEtg6UVz5SOD3GVw      5
# 3        kCoE3jvEtg6UVz5SOD3GVw      5
# 4        kCoE3jvEtg6UVz5SOD3GVw      5
# ...                         ...    ...
# 1603437  9ouC6BpmjFpLfHeQnLQqng      5
# 1603438  9ouC6BpmjFpLfHeQnLQqng      5
# 1603439  n9a-3YhibkMDUEgncIivHg      5
# 1603440  n9a-3YhibkMDUEgncIivHg      1
# 1603441  n9a-3YhibkMDUEgncIivHg      4
#
# [1603442 rows x 2 columns]

# %% [markdown]
# Теперь посчитайте среднюю оценку каждой компании, а также количество выставленных компании оценок.
#
# *Подсказка.* Помочь в этом могут функции `groupby` и `aggregate([np.mean, np.size])`.

# %%
reviews_by_business = target_reviews.groupby("business_id").aggregate([np.mean, np.size])
reviews_by_business
# Out:
#                            stars
#                             mean  size
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  4.088904  1451
# --DdmeR16TRb3LsjG0ejrQ  3.200000     5
# --WsruI0IGEoeRmkErU5Gg  4.928571    14
# --Y7NhBKzLTbNliMUX_wfg  4.875000     8
# --e8PjCNhEz32pprnPhCwQ  3.473684    19
# ...                          ...   ...
# zzOo9n22fBbKAhbSpMzggA  3.230769    26
# zzXuJF6UUT1kgTyCsmgDmQ  5.000000     4
# zzjqFOujmM9surbMANZ_ag  5.000000     3
# zzsKbL1KMNJqazSqBXskxQ  3.666667     6
# zzzaIBwimxVej4tY6qFOUQ  3.432432    37
#
# [26761 rows x 2 columns]

# %% [markdown]
# Назовите колонки таблицы красивыми именами, изменив `<имя таблицы>.columns`, после чего напечатайте несколько строк полученной таблицы. Красивые имена &mdash; то, что будет понятно простому человеку при чтении ваших результатов. Как именно их назвать &mdash; задача аналитика, то есть в данном случае ваша :)

# %%
reviews_by_business.columns = ['stars', 'count']

# %% [markdown]
# Соедините две полученные ранее таблицы по компаниям города `N` в одну.
# Для этого сначала установите поле `business_id` в качестве индекса в обеих таблицах с помощью `set_index`. В одной из них это уже должно было быть сделано.
# В полученной таблице должны получится поля `latitude`, `longitude`, `categories`, `name`, `stars`, `count`.
#
# *Подсказка.* Соединение таблиц можно выполнить с помощью `join`.
# Индексы у этих таблиц одинаковые, так что тип джойна не имеет значения.
#
# **Note: reviews_by_business - ключевая таблица, которая будет использоваться раз за разом.**

# %%
reviews_by_business = target_data.set_index("business_id").join(reviews_by_business)
reviews_by_business = reviews_by_business.reindex(columns=['latitude', 'longitude', 'categories', 'name', 'stars', 'count'])
reviews_by_business
# Out:
#                          latitude   longitude  \
# business_id
# kCoE3jvEtg6UVz5SOD3GVw  36.207430 -115.268460
# OD2hnuuTJI9uotcKycxg1A  36.197484 -115.249660
# VBHEsoXQb2AQ76J9l8h1uQ  36.085051 -115.119421
# 1Jp_hmPNUZArNqzpbm7B0g  36.056382 -115.269332
# DPQnTnNw2PJj7DdENM98Cw  36.105196 -115.056880
# ...                           ...         ...
# swjz4q8gI79Ndg4APuHEUA  36.134355 -115.224462
# pUhU5ohYv65g8B47dTXAKA  36.173589 -115.116779
# sH9WsMj8sNTTSAUWv4UEEg  36.055130 -115.243488
# 9ouC6BpmjFpLfHeQnLQqng  36.128780 -115.208990
# n9a-3YhibkMDUEgncIivHg  36.150022 -115.333169
#
#                                                                categories  \
# business_id
# kCoE3jvEtg6UVz5SOD3GVw  Real Estate Services;Real Estate;Home Services...
# OD2hnuuTJI9uotcKycxg1A                            Shopping;Sporting Goods
# VBHEsoXQb2AQ76J9l8h1uQ       Shopping;Jewelry;Watch Repair;Local Services
# 1Jp_hmPNUZArNqzpbm7B0g  Home Services;Lighting Fixtures & Equipment;Lo...
# DPQnTnNw2PJj7DdENM98Cw       Nurseries & Gardening;Home & Garden;Shopping
# ...                                                                   ...
# swjz4q8gI79Ndg4APuHEUA  Real Estate Services;Home Services;Property Ma...
# pUhU5ohYv65g8B47dTXAKA                                  Coffee & Tea;Food
# sH9WsMj8sNTTSAUWv4UEEg  Mobile Phone Accessories;Mobile Phones;Electro...
# 9ouC6BpmjFpLfHeQnLQqng  Martial Arts;Sports Wear;Men's Clothing;Sporti...
# n9a-3YhibkMDUEgncIivHg                            Beauty & Spas;Skin Care
#
#                                                     name     stars  count
# business_id
# kCoE3jvEtg6UVz5SOD3GVw                      "BDJ Realty"  4.000000      5
# OD2hnuuTJI9uotcKycxg1A                     "Soccer Zone"  1.444444      9
# VBHEsoXQb2AQ76J9l8h1uQ               "Alfredo's Jewelry"  4.739130     23
# 1Jp_hmPNUZArNqzpbm7B0g                   "Task Electric"  4.450000     20
# DPQnTnNw2PJj7DdENM98Cw                    "Star Nursery"  3.680000     25
# ...                                                  ...       ...    ...
# swjz4q8gI79Ndg4APuHEUA  "Stonegate Real Estate Services"  4.466667     15
# pUhU5ohYv65g8B47dTXAKA                       "Starbucks"  2.400000     35
# sH9WsMj8sNTTSAUWv4UEEg                    "Sprint Store"  3.857143     35
# 9ouC6BpmjFpLfHeQnLQqng            "9 Dragons Fight Shop"  5.000000      5
# n9a-3YhibkMDUEgncIivHg                      "L'Occitane"  3.333333      3
#
# [26761 rows x 6 columns]

# %% [markdown]
# Изобразите все компании на графике, раскрасив точку в цвет, оттенок которого соответствует средней оценке компании. Прозрачность точки выставляйте не более $0.3$.

# %%
ax = plt.axes()
ax.scatter(reviews_by_business.longitude, reviews_by_business.latitude, c=reviews_by_business.stars, alpha=0.3, s=10)
ax.set_xlabel("Долгота")
ax.set_ylabel("Широта")
ax.set_xlim(-115.6, -114.8)
ax.set_ylim(35.8, 36.4)
ax.set_title("Оценки бизнесов в Лас-Вегасе")
# Out:
# Text(0.5, 1.0, 'Оценки бизнесов в Лас-Вегасе')

# %% [markdown]
# Чтобы получить районы города, то есть разделить город на "клетки", округлите значения широты и долготы, подобрав оптимальный размер района.
#
# *Подсказка.* Например, можно сделать так
# `np.round(долгота*4, decimals=1)*0.25`.

# %%
import copy
fineness = 4
reviews_by_area = copy.deepcopy(reviews_by_business)
reviews_by_area.latitude = reviews_by_area.latitude.apply(lambda x: np.round(x * fineness, decimals=1) / fineness)
reviews_by_area.longitude = reviews_by_area.longitude.apply(lambda x: np.round(x * fineness, decimals=1) / fineness)

# %% [markdown]
# Для получения средней оценки компании по району постройте сводную таблицу при помощи `pd.pivot_table`, взяв в качестве индексов и колонок округленные широту и долготу, а в качестве значений &mdash; оценки. Аггрегирующей функцией является среднее.
#
# Изобразите полученную таблицу при помощи `sns.heatmap`.

# %%
table = pd.pivot_table(reviews_by_area, index="latitude", columns="longitude", values="stars")
plt.axes().clear()
with sns.axes_style('whitegrid'):
    ax = sns.heatmap(table, annot=True)
    ax.set_title("Оценки бизнесов в Лас-Вегасе")
    ax.set_xlabel("Долгота")
    ax.set_ylabel("Широта")

# %% [markdown]
# Полученный график имеет ряд недостатков. Во-первых, не очень правильно судить о районе, если в нем мало компаний. Во-вторых,  на графике цветовая гамма автоматически подстроилась под минимальное и максимальное значения оценки.
#
# Почему эти недостатки могут быть существенными?
#
# **Ответ:** **Очевидно, когда в районе мало компаний (крайний случай - 1 компания), то на среднюю по району влияет не местоположение, а качество оказываемых услуг этой самой компанией. Когда компаний становится много, мы верим что этот под-датасет района переймёт все свойства большого датасета(в том числе распределение качества услуг).**
#
# **Ну а по поводу цветовой гаммы - график просто становится визуально не информативным. В крайнем случае без параметров vmin и vmax, а также датасетом: (одна компанию с 5.0 и все остальные в районе 2.0) - получим одноцветный график, анализировать который невозможно.**
#
# **Note: Вообще по хорошему стоит и компании с малым кол-вом оценок выбросить.**

# %% [markdown]
# Оставьте районы, в которых имеется информация о не менее $30$ компаний. Постройте новый график районов, использовав параметры `vmin` и `vmax` у функции `sns.heatmap`.

# %%
series = reviews_by_area.groupby(["latitude", "longitude"])["count"].count()
series = series[series >= 30]
reviews_by_area = reviews_by_area.reset_index().set_index(["latitude", "longitude"]).loc[series.index]
reviews_by_area = reviews_by_area.reset_index().set_index("business_id")

# %% [markdown]
# **После небольшой магии с индексами (основы которой были даны в условии данного notebook) и получив reviews_by_area с ресторанами из только популярных районов - построим heatmap.**

# %%
table = pd.pivot_table(reviews_by_area, index="latitude", columns="longitude", values="stars")
plt.axes().clear()
with sns.axes_style('whitegrid'):
    ax = sns.heatmap(table, annot=True, vmax=4.5, vmin=2.5)
    ax.set_title("Оценки бизнесов в Лас-Вегасе")
    ax.set_xlabel("Долгота")
    ax.set_ylabel("Широта")

# %% [markdown]
# Сравните полученный график с предыдущим и сделайте вывод.
#
# **Вывод:** **Относительно предыдущего графика уменьшился рассматриваемый округ(ведь мы отбросили районы), диапазон цветов стал приемлемым. Стало отчётливо видно, что с западной стороны оценки выше. В рассмотренном округе самые высокие средние достигнуты на северо-западе, самые низкие на востоке/юго-востоке. Средняя варьируется между 3 и 4.2.**

# %% [markdown]
# #### Рестораны
#
# Будем считать компанию рестораном, если в поле `categories` *содержится* слово `restaurant`. Обратите внимание, что в анализе данных часто нет четкого формата данных. Например, данное слово может быть написано как с большой буквы, так и с маленькой; может как разделяться `;`, так и не разделяться. При возникновении недопонимания стоит посмотреть данные.
#
# Составьте таблицу, в которой будет информация о всех ресторанах города `N`, для которых имеется не менее $5$ отзывов. Далее постройте heatmap-график районов, в котором каждому району сопоставьте среднюю оценку по ресторанам этого района. Рассматривайте только те районы, в которых есть не менее $10$ ресторанов, для каждого из которых есть не менее $5$ отзывов.
#
# **Note: соберём всё ранее написанное в функцию show_heatmap и применим её.**

# %%
def show_heatmap(reviews, vmin, vmax, title, area_lower_bound):
    fineness = 4
    reviews_by_area = copy.deepcopy(reviews)
    reviews_by_area.latitude = reviews_by_area.latitude.apply(lambda x: np.round(x * fineness, decimals=1) / fineness)
    reviews_by_area.longitude = reviews_by_area.longitude.apply(lambda x: np.round(x * fineness, decimals=1) / fineness)
    series = reviews_by_area.groupby(["latitude", "longitude"])["count"].count()
    series = series[series >= area_lower_bound]
    reviews_by_area = reviews_by_area.reset_index().set_index(["latitude", "longitude"]).loc[series.index]
    reviews_by_area = reviews_by_area.reset_index().set_index("business_id")
    table = pd.pivot_table(reviews_by_area, index="latitude", columns="longitude", values="stars")
    plt.axes().clear()
    with sns.axes_style('whitegrid'):
        ax = sns.heatmap(table, annot=True, vmax=vmax, vmin=vmin)
        ax.set_title(title)
        ax.set_xlabel("Долгота")
        ax.set_ylabel("Широта")

# %%
reviews_by_business["is_cafe"] = reviews_by_business["categories"].apply(lambda x: x.lower().find("restaurant") != -1)
reviews_by_restaurant = reviews_by_business[reviews_by_business["is_cafe"] == True]
reviews_by_restaurant = reviews_by_restaurant.drop(columns=["is_cafe"])
reviews_by_restaurant = reviews_by_restaurant[reviews_by_restaurant["count"] >= 5] # Expected table

show_heatmap(reviews_by_restaurant, 2.5, 4, "Оценки ресторанов в Лас-Вегасе", 10)

# %% [markdown]
# Чем полезны ограничения снизу на количество отзывов для ресторана и количество ресторанов в районе?
#
# **Ответ:** **как и в прошлый раз - убираем нерепрезентативные районы. Делаем heatmap информативным.**

# %% [markdown]
# Кот Василий из города `N` очень придирчив к выбору ресторана. Он доверяет только ресторанам с высоким рейтингом, который основывается на большом количестве отзывов. Напечатайте в виде таблицы информацию $10$ ресторанах с самым большим рейтингом в порядке убывания рейтинга. Для каждого из этих ресторанов должно быть не менее $50$ отзывов. По каждому ресторану необходимо вывести следующую информации: название ресторана, средняя оценка, количество отзывов, географические координаты, категории.

# %%
restaraunts_top = reviews_by_restaurant[reviews_by_restaurant["count"] >= 50].sort_values(by="stars", ascending=False).head(10).reindex(columns=["name", "stars", "count", "latitude", "longitude", "categories"])
restaraunts_top
# Out:
#                                                  name     stars  count  \
# business_id
# iBPyahdJRP5y0t25fF2W9w    "Lip Smacking Foodie Tours"  4.966480    179
# Fmij544FE1iOruoxI41kew                 "Pepito Shack"  4.907692     65
# qw9SyduMZ53KB6GlBQqvZQ               "Bosa Boba Cafe"  4.890909     55
# k9b96JXlNewj36ddrce9Jw                 "Garden Grill"  4.868132     91
# IhNASEZ3XnBHmuuVnWdIwA                 "Brew Tea Bar"  4.848069   1165
# k5ddmLvAKKw9zSusRPM2cQ               "Poppa Naps BBQ"  4.836538    104
# 8fFTJBh0RB2EKG53ibiBKw               "Zenaida's Cafe"  4.833333    180
# l1GJnB9TJgGgEeI4at1M0A   "El Frescos Cocina Mexicana"  4.816754    191
# hFT3HuxVZJb1uYEsYfp-0A  "Blaqcat Ultra Hookah Lounge"  4.809524     63
# wZkjm9TGa7nXLYHxhIRO5w     "California Sushi Burrito"  4.807018     57
#
#                          latitude   longitude  \
# business_id
# iBPyahdJRP5y0t25fF2W9w  36.114537 -115.172678
# Fmij544FE1iOruoxI41kew  36.152477 -115.151945
# qw9SyduMZ53KB6GlBQqvZQ  36.125960 -115.184846
# k9b96JXlNewj36ddrce9Jw  36.166783 -115.286197
# IhNASEZ3XnBHmuuVnWdIwA  36.054195 -115.242443
# k5ddmLvAKKw9zSusRPM2cQ  36.116549 -115.088115
# 8fFTJBh0RB2EKG53ibiBKw  36.101741 -115.100359
# l1GJnB9TJgGgEeI4at1M0A  36.098527 -115.148446
# hFT3HuxVZJb1uYEsYfp-0A  36.159742 -115.232738
# wZkjm9TGa7nXLYHxhIRO5w  36.125636 -115.202487
#
#                                                                categories
# business_id
# iBPyahdJRP5y0t25fF2W9w  Food Tours;Restaurants;Event Planning & Servic...
# Fmij544FE1iOruoxI41kew  Restaurants;Burgers;Food Stands;Sandwiches;Hot...
# qw9SyduMZ53KB6GlBQqvZQ  Vietnamese;Bubble Tea;Sandwiches;Food;Coffee &...
# k9b96JXlNewj36ddrce9Jw  Tacos;Street Vendors;Farmers Market;Vegetarian...
# IhNASEZ3XnBHmuuVnWdIwA  Cafes;Tea Rooms;Food;Bubble Tea;Restaurants;De...
# k5ddmLvAKKw9zSusRPM2cQ  Food Stands;Hot Dogs;Caterers;Restaurants;Amer...
# 8fFTJBh0RB2EKG53ibiBKw               Restaurants;Breakfast & Brunch;Cafes
# l1GJnB9TJgGgEeI4at1M0A  Caterers;Mexican;Restaurants;Food;Event Planni...
# hFT3HuxVZJb1uYEsYfp-0A  Adult Entertainment;Lounges;Hookah Bars;Restau...
# wZkjm9TGa7nXLYHxhIRO5w  Asian Fusion;Fast Food;Restaurants;Japanese;Po...

# %% [markdown]
# Нанесите на карту все рестораны со средней оценкой не менее $4.7$, которая посчитана по не менее $50$ отзывам. Отдельным цветом отметьте 10 ресторанов, которые вы получили ранее.

# %%
reviews_by_restaurant = reviews_by_restaurant[(reviews_by_restaurant["count"] >= 50) & (reviews_by_restaurant["stars"] >= 4.7)]

new_col_name = "Топ 10"
reviews_by_restaurant[new_col_name] = reviews_by_restaurant["count"].apply(lambda x: "Нет")
reviews_by_restaurant.loc[restaraunts_top.index, new_col_name] = "Да"
with sns.axes_style('whitegrid'):
    ax = sns.scatterplot(data=reviews_by_restaurant, x='longitude', y='latitude', hue=new_col_name, s=100)
    ax.set_title("Топ ресторанов")
    ax.set_xlabel("Долгота")
    ax.set_ylabel("Широта")

# %% [markdown]
# Охарактеризуйте кота Василия, а также сделайте общий вывод по задаче.
#
# **Вывод:** **Речь в задаче шла о городе Лас-Вегас. Согласно графикам "restautants/business grades on map" запад/северо-запад - районы с более качественными услугами, опираясь на оценки клиентов. С другой стороны восток/юго-восток предлагают менее качественные услуги, опираясь на оценки клиентов. Кот Василий действительно избирателен, ведь посещает самые известные и хорошо-оценённые рестораны, которые расположены в разных районах. Несмотря на успешность северо-запада в среднем, топовые рестораны расположены и в центре/на востоке также.**

# %% [markdown]
# ---
# ### Задача 3.
#
# В данной задаче вам предстоит распарсить сайт, который вы выберите.
#
# **1.** Каждая ссылка (URL) в интернете состоит из нескольких компонент:
#
# * схема, *например, `http` или `https`*,
# * хост, *наример, `en.wikipedia.org`*
# * путь, по которому находится информация,
# * параметры,
# * якорь &mdash; указание фрагмента страницы.

# %% [markdown]
# ![url_parts.png](data:image/png;base64,...)

# %% [markdown]
# Одна и та же ссылка может иметь несколько форм и вести на ту же самую страницу. Во время обхода сайта это надо учитывать и сохранять один уникальный урл для каждой страницы. Процедура, приводящая урл к каноничному виду, называется нормализацией.
# Процедуры, которые применяются к урлу для нормализации, описаны, например, на <a target="_blank" href="https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D1%80%D0%BC%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F_URL">Википедии</a>.
#
# Установите пакет `url_normalize`, в котором есть готовая функция для нормализации.

# %%
import sys
# !{sys.executable} -m pip install url_normalize
# Out:
# Requirement already satisfied: url_normalize in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (1.4.3)
# Requirement already satisfied: six in /opt/homebrew/Cellar/six/1.16.0_2/lib/python3.9/site-packages (from url_normalize) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/bin/python3.9 -m pip install --upgrade pip' command.

# %% [markdown]
# Прочитайте, как именно функция `url_normalize` меняет ссылку, и приведите примеры $4$ урлов, которые нормализуются к одному и тому же. Примеры должны демонстрировать различные этапы процедуры нормализации. Одним из этих примеров может быть сам нормализованный урл.

# %%
from url_normalize import url_normalize

# %%
urls = """
http://example.com/products/?product_id=123
HTTP://EXAMPLE.COM/products/?product_id=123
http://example.com:80/products/?product_id=123
http://example.com/products/./?product_id=123
http://example.com//products/?product_id=123
"""

for url in urls.split('\n'):
    print(url_normalize(url))
# Out:
# http://example.com/products/?product_id=123
# http://example.com/products/?product_id=123
# http://example.com/products/?product_id=123
# http://example.com/products/?product_id=123
# http://example.com/products/?product_id=123

# %% [markdown]
# _____________
# Изучите код, в котором скачиваются страницы сайта `simple.wikipedia.org` с <a href="https://mipt-stats.gitlab.io/courses/ad_fivt/data_parsing.html">занятия про парсинг данных</a> и **скопируйте его в решение данной задачи**. Код, реализующий обход в ширину с фильтрацией и нормализацией урлов, приведён в виде функции.

# %%
# !{sys.executable} -m pip install bs4
from urllib.parse import urlparse, urldefrag, urljoin
from urllib.request import urlopen
from bs4 import BeautifulSoup
from queue import Queue
import time
# Out:
# Requirement already satisfied: bs4 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/lib/python3.9/site-packages (from beautifulsoup4->bs4) (2.3.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/homebrew/Cellar/jupyterlab/3.2.9/libexec/bin/python3.9 -m pip install --upgrade pip' command.

# %% [markdown]
# Готовые функции для парсинга html/url:

# %%
def download_from_the_internet(url):
    '''Скачивает сраницу с интернета

    Параметры:
        url (str) - ссылка на страницу для скачивания

    Возвращает:
        str - html-страница в виде строки, None в случае неудачи
    '''
    try:
        return urlopen(url).read().decode('utf-8')
    except KeyboardInterrupt:
        raise
    except:
        return None

    
def extract_links_from_html(url, html):
    '''Парсит ссылки на странице

    Принимает:
        url (str) - исходный урл страницы
        html (str) - содержание html-страницы

    Возвращает:
        list - список ссылок, находящихся на странице
    '''
    parser = BeautifulSoup(html)
    # Формируем ссылки на те страницы, на которые ссылается документ
    return [urljoin(url, link.get('href')) for link in parser.findAll('a')]


def extract_text_info_from_html(html):
    '''Парсит текстовую информацию на странице

    Принимает:
         html (str) - содержание html-страницы

    Возвращает:
        dict - текстовая часть страницы по ключу text,
               название по ключу title
    '''
    soup = BeautifulSoup(html, features="html.parser")
    for script in soup(["script", "style"]):
        script.extract()
    
    # Объединяем строки текста
    text = soup.get_text()
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)

    # Находим название на странице
    title = soup.find('title').string
    
    return {'text': text, 'title': title}

# %% [markdown]
# Код обхода в ширину:

# %%
def load_web_pages(seed, max_downloads, url_filtration,
                   soft_html_filtration, hard_html_filtration):    
    # Создаём список со страницами
    pages_json = []
    
    # Создаём очередь для обхода в ширину
    q = Queue()
    q.put(seed)

    already_visited = set()
    n_downloads = 0
    time_start = time.time()

    while not q.empty():
        # Нормализуем урл
        main_url = url_normalize(q.get())
        try:
            if main_url in already_visited:
                continue
            already_visited.add(main_url)
            html = download_from_the_internet(main_url)
        
            # Извлекаем ссылки из страницы
            children_links = extract_links_from_html(main_url, html)
            time.sleep(1)

            # Извлекаем текст страницы
            text_info = extract_text_info_from_html(html) 

            # Добавляем запись в таблицу
            text_info['url'] = main_url
            hardOK = hard_html_filtration(text_info)
            softOK = soft_html_filtration(text_info)
            if ((not hardOK) and (not softOK)):
                continue
            '''В этом месте я хотел if (hardOK) -> pages.append(...),
            но будущие задания требуют всех данных, так что ничего.'''
            pages_json.append(text_info)
            print(f"Status {n_downloads},\nPage: {main_url}\nAdded: {hardOK}\n")
        
            n_downloads += 1
            if n_downloads > max_downloads:
                break
            
            # Добавляем ещё не посещённые ссылки в очередь
            for child in children_links:
                # print(f"Child: {child}")
                if (url_normalize(child) not in already_visited)\
                        and url_filtration(child):
                    # print("Put")
                    q.put(child)
        except Exception as ex:
            print(f"-------EXCEPTION-------\n{ex}\n")
            continue
    return pages_json

# %%
def is_wiki_article(url):
    if 'simple.wikipedia' not in url:
        return False
    
    prohibited = ['Category', 'Special', 'Wikipedia',
                  'php', 'Help']
    
    # Проверяем, есть ли запрещённые строки в ссылке
    for token in prohibited:
        if token in url:
            return False
        
    return True

MAX_DOWNLOADS = 1
SEED = "https://simple.wikipedia.org/wiki/Data_science"

df = pd.DataFrame(load_web_pages(SEED, MAX_DOWNLOADS, is_wiki_article, lambda x: True, lambda x: True))
list(df["url"])
# Out:
# Status 0,
# Page: https://simple.wikipedia.org/wiki/Data_science
# Added: True
#
# Status 1,
# Page: https://simple.wikipedia.org/wiki/Data_science#mw-head
# Added: True
# ['https://simple.wikipedia.org/wiki/Data_science',
#  'https://simple.wikipedia.org/wiki/Data_science#mw-head']

# %% [markdown]
# **Кажется, нужно поправить реализацию, ведь url_normalize не приводит две эти ссылки к одному виду.**

# %% [markdown]
# **2.** Выберите достаточно крупный сайт, который вам интересен, а также некоторую категорию страниц в нём. Поймите, с какой страницы сайта надо начать обход, чтобы обходить сайты данной категории.
#
# *Пример: ищем статьи про Data Science на Википедии, начинаем со статьи Data Dcience*.
#
# **Укажите, что выбрали:** Ищем странички википедии про войны, в которых фигурировала Россия.
#
# Придумайте критерий, который по тексту из HTML-страницы будет определять, находится ли страница в определённой вами категории.
#
# *Пример: статья на Википедии про Data Science, если в ней есть слово "data" или термины из статистики, теории вероятностей и анализа данных*.
#
# **Опишите критерий:**
# Я выбрал трёх-факторный критерий (то есть немного поменял исходную функцию парсинга, добавив ей аргументов. Изменение этой функции неизбежно - ловить исключения и логировать состояние - важно)
# 1. Если ссылка содержит # ? & % File ( .jpg, то мы даже не рассматриваем её. *За это отвечает url_filter.*
#
# 2. Если на сайте есть некоторые из слов "warrior", "battle", "weapon", "conflict", "military", "forces", то рассмотрим эту страницу как промежуточный узел(т.е. будем искать ссылки на ней), но её саму в ответ не добавим. *За это отвечает soft_html_filter*
#
# 3. Если на сайте есть слова "war" И "russia", а также в url лежит слово war, то сочтём что это нужная нам страница. *За это отвечает hard_html_filter*
#
# Такой подход позволяет не рассматривать лишнее, но и не терять "нить" с помощью промежуточных страниц.
#
# Начав с выбранной страницы, скачайте не менее $500$ страниц сайта. В качестве функции фильтрации возьмите функцию, которая отделяет страницы с выбранного сайта от других.

# %%
raise Exception("Do not launch")

def url_filter(url):    
    if 'en.wikipedia.org' not in url:
        return False  
    
    accepted = []
    
    for token in accepted:
        if token in url:
            return True
    
    prohibited = ["#", "?", "&", "%", "File", "(", ".jpg"]
    
    for token in prohibited:
        if token in url:
            return False
    
    return True

def soft_html_filter(html_object):
    accepted = ["warrior","battle", "weapon",
                "conflict", "military", "forces"]
    for token in accepted:
        if token in html_object["text"].lower():
            return True
    return False

def hard_html_filter(html_object):
    accepted_text = ["war", "russia"]
    for token in accepted_text:
        if token not in html_object["text"].lower():
            return False
    accepted_url = ["war"]
    for token in accepted_url:
        if token not in html_object["url"].lower():
            return False
    return True
    
MAX_DOWNLOADS = 500
SEED = "https://en.wikipedia.org/wiki/War"

df = pd.DataFrame(load_web_pages(SEED, MAX_DOWNLOADS, url_filter,
                                    soft_html_filter, hard_html_filter))
df
# Out:
# Status 0,
# Page: https://en.wikipedia.org/wiki/War
# Added: True
#
# Status 1,
# Page: https://en.wikipedia.org/wiki/Conflict_Zone
# Added: False
#
# Status 2,
# Page: https://en.wikipedia.org/wiki/Stele_of_the_Vultures
# Added: False
#
# Status 3,
# Page: https://en.wikipedia.org/wiki/Battle_of_Hastings
# Added: False
#
# Status 4,
# Page: https://en.wikipedia.org/wiki/Retreat_from_Moscow
# Added: False
#
# Status 5,
# Page: https://en.wikipedia.org/wiki/Battle_of_the_Somme
# Added: False
#
# Status 6,
# Page: https://en.wikipedia.org/wiki/Normandy_landings
# Added: False
#
# Status 7,
# Page: https://en.wikipedia.org/wiki/Nuclear_weapon
# Added: False
#
# Status 8,
# Page: https://en.wikipedia.org/wiki/Military_history
# Added: False
#
# Status 9,
# Page: https://en.wikipedia.org/wiki/Prehistoric_warfare
# Added: False
#
# Status 10,
# Page: https://en.wikipedia.org/wiki/Ancient_warfare
# Added: False
#
# Status 11,
# Page: https://en.wikipedia.org/wiki/Medieval_warfare
# Added: True
#
# Status 12,
# Page: https://en.wikipedia.org/wiki/Early_modern_warfare
# Added: True
#
# Status 13,
# Page: https://en.wikipedia.org/wiki/Modern_warfare
# Added: True
#
# Status 14,
# Page: https://en.wikipedia.org/wiki/Industrial_warfare
# Added: True
#
# Status 15,
# Page: https://en.wikipedia.org/wiki/Fourth-generation_warfare
# Added: True
#
# Status 16,
# Page: https://en.wikipedia.org/wiki/Battlespace
# Added: False
#
# Status 17,
# Page: https://en.wikipedia.org/wiki/Aerial_warfare
# Added: False
#
# Status 18,
# Page: https://en.wikipedia.org/wiki/Airborne_forces
# Added: False
#
# Status 19,
# Page: https://en.wikipedia.org/wiki/Space_warfare
# Added: True
#
# Status 20,
# Page: https://en.wikipedia.org/wiki/Ground_warfare
# Added: False
#
# Status 21,
# Page: https://en.wikipedia.org/wiki/Cold-weather_warfare
# Added: True
#
# Status 22,
# Page: https://en.wikipedia.org/wiki/Desert_warfare
# Added: False
#
# Status 23,
# Page: https://en.wikipedia.org/wiki/Jungle_warfare
# Added: False
#
# Status 24,
# Page: https://en.wikipedia.org/wiki/Mountain_warfare
# Added: True
#
# Status 25,
# Page: https://en.wikipedia.org/wiki/Urban_warfare
# Added: True
#
# Status 26,
# Page: https://en.wikipedia.org/wiki/Naval_warfare
# Added: True
#
# Status 27,
# Page: https://en.wikipedia.org/wiki/Amphibious_warfare
# Added: True
#
# Status 28,
# Page: https://en.wikipedia.org/wiki/Blue-water_navy
# Added: False
#
# Status 29,
# Page: https://en.wikipedia.org/wiki/Brown-water_navy
# Added: False
#
# Status 30,
# Page: https://en.wikipedia.org/wiki/Green-water_navy
# Added: False
#
# Status 31,
# Page: https://en.wikipedia.org/wiki/Surface_warfare
# Added: False
#
# Status 32,
# Page: https://en.wikipedia.org/wiki/Underwater_warfare
# Added: True
#
# Status 33,
# Page: https://en.wikipedia.org/wiki/Subterranean_warfare
# Added: False
#
# Status 34,
# Page: https://en.wikipedia.org/wiki/Tunnel_warfare
# Added: True
#
# Status 35,
# Page: https://en.wikipedia.org/wiki/Cyberwarfare
# Added: True
#
# Status 36,
# Page: https://en.wikipedia.org/wiki/Information_warfare
# Added: True
#
# Status 37,
# Page: https://en.wikipedia.org/wiki/Weapon
# Added: False
#
# Status 38,
# Page: https://en.wikipedia.org/wiki/Armoured_warfare
# Added: True
#
# Status 39,
# Page: https://en.wikipedia.org/wiki/Artillery
# Added: False
#
# Status 40,
# Page: https://en.wikipedia.org/wiki/Biological_warfare
# Added: True
#
# Status 41,
# Page: https://en.wikipedia.org/wiki/Military_camouflage
# Added: False
#
# Status 42,
# Page: https://en.wikipedia.org/wiki/Cavalry
# Added: False
#
# Status 43,
# Page: https://en.wikipedia.org/wiki/Chemical_warfare
# Added: True
#
# Status 44,
# Page: https://en.wikipedia.org/wiki/Class_conflict
# Added: False
#
# Status 45,
# Page: https://en.wikipedia.org/wiki/Combined_arms
# Added: False
#
# Status 46,
# Page: https://en.wikipedia.org/wiki/Conventional_warfare
# Added: True
#
# Status 47,
# Page: https://en.wikipedia.org/wiki/Cyberweapon
# Added: False
#
# Status 48,
# Page: https://en.wikipedia.org/wiki/Area_denial_weapon
# Added: False
#
# Status 49,
# Page: https://en.wikipedia.org/wiki/Disinformation
# Added: False
#
# Status 50,
# Page: https://en.wikipedia.org/wiki/Drone_strike
# Added: False
#
# Status 51,
# Page: https://en.wikipedia.org/wiki/Electronic_warfare
# Added: True
#
# Status 52,
# Page: https://en.wikipedia.org/wiki/Infantry
# Added: False
#
# Status 53,
# Page: https://en.wikipedia.org/wiki/Lawfare
# Added: False
#
# Status 54,
# Page: https://en.wikipedia.org/wiki/Loitering_munition
# Added: False
#
# Status 55,
# Page: https://en.wikipedia.org/wiki/Martial_music
# Added: False
#
# Status 56,
# Page: https://en.wikipedia.org/wiki/Nuclear_warfare
# Added: True
#
# Status 57,
# Page: https://en.wikipedia.org/wiki/Psychological_warfare
# Added: True
#
# Status 58,
# Page: https://en.wikipedia.org/wiki/Unconventional_warfare
# Added: False
#
# Status 59,
# Page: https://en.wikipedia.org/wiki/Military_tactics
# Added: False
#
# Status 60,
# Page: https://en.wikipedia.org/wiki/List_of_military_tactics
# Added: False
#
# Status 61,
# Page: https://en.wikipedia.org/wiki/Air_combat_manoeuvring
# Added: False
#
# Status 62,
# Page: https://en.wikipedia.org/wiki/Battle
# Added: False
#
# Status 63,
# Page: https://en.wikipedia.org/wiki/Cavalry_tactics
# Added: False
#
# Status 64,
# Page: https://en.wikipedia.org/wiki/Counterattack
# Added: False
#
# Status 65,
# Page: https://en.wikipedia.org/wiki/Counterinsurgency
# Added: False
#
# Status 66,
# Page: https://en.wikipedia.org/wiki/Defeat_in_detail
# Added: False
#
# Status 67,
# Page: https://en.wikipedia.org/wiki/Defensive_fighting_position
# Added: False
#
# Status 68,
# Page: https://en.wikipedia.org/wiki/Envelopment
# Added: False
#
# Status 69,
# Page: https://en.wikipedia.org/wiki/Guerrilla_warfare
# Added: True
#
# Status 70,
# Page: https://en.wikipedia.org/wiki/Morale
# Added: False
#
# Status 71,
# Page: https://en.wikipedia.org/wiki/Shock_and_awe
# Added: False
#
# Status 72,
# Page: https://en.wikipedia.org/wiki/Siege
# Added: False
#
# Status 73,
# Page: https://en.wikipedia.org/wiki/Tactical_objective
# Added: False
#
# Status 74,
# Page: https://en.wikipedia.org/wiki/Saturation_attack
# Added: False
#
# Status 75,
# Page: https://en.wikipedia.org/wiki/Trench_warfare
# Added: True
#
# Status 76,
# Page: https://en.wikipedia.org/wiki/Operational_level_of_war
# Added: True
#
# Status 77,
# Page: https://en.wikipedia.org/wiki/Blitzkrieg
# Added: False
#
# Status 78,
# Page: https://en.wikipedia.org/wiki/Expeditionary_warfare
# Added: True
#
# Status 79,
# Page: https://en.wikipedia.org/wiki/Deep_operation
# Added: False
#
# Status 80,
# Page: https://en.wikipedia.org/wiki/Maneuver_warfare
# Added: True
#
# Status 81,
# Page: https://en.wikipedia.org/wiki/Operational_manoeuvre_group
# Added: False
#
# Status 82,
# Page: https://en.wikipedia.org/wiki/Military_strategy
# Added: False
#
# Status 83,
# Page: https://en.wikipedia.org/wiki/List_of_military_strategies_and_concepts
# Added: False
#
# Status 84,
# Page: https://en.wikipedia.org/wiki/Attrition_warfare
# Added: True
#
# Status 85,
# Page: https://en.wikipedia.org/wiki/Counter-offensive
# Added: False
#
# Status 86,
# Page: https://en.wikipedia.org/wiki/Culminating_point
# Added: False
#
# Status 87,
# Page: https://en.wikipedia.org/wiki/Defence_in_depth
# Added: False
#
# Status 88,
# Page: https://en.wikipedia.org/wiki/Fabian_strategy
# Added: False
#
# Status 89,
# Page: https://en.wikipedia.org/wiki/Mosaic_Warfare
# Added: False
#
# Status 90,
# Page: https://en.wikipedia.org/wiki/Military_deception
# Added: False
#
# Status 91,
# Page: https://en.wikipedia.org/wiki/Strategic_defence
# Added: False
#
# Status 92,
# Page: https://en.wikipedia.org/wiki/Strategic_depth
# Added: False
#
# Status 93,
# Page: https://en.wikipedia.org/wiki/Naval_strategy
# Added: False
#
# Status 94,
# Page: https://en.wikipedia.org/wiki/Scorched_earth
# Added: False
#
# Status 95,
# Page: https://en.wikipedia.org/wiki/Grand_strategy
# Added: False
#
# Status 96,
# Page: https://en.wikipedia.org/wiki/Containment
# Added: False
#
# Status 97,
# Page: https://en.wikipedia.org/wiki/Economic_warfare
# Added: False
#
# Status 98,
# Page: https://en.wikipedia.org/wiki/Limited_war
# Added: True
#
# Status 99,
# Page: https://en.wikipedia.org/wiki/Philosophy_of_war
# Added: True
#
# Status 100,
# Page: https://en.wikipedia.org/wiki/Political_warfare
# Added: True
#
# Status 101,
# Page: https://en.wikipedia.org/wiki/Religious_war
# Added: False
#
# Status 102,
# Page: https://en.wikipedia.org/wiki/Strategic_studies
# Added: False
#
# Status 103,
# Page: https://en.wikipedia.org/wiki/Military_technology
# Added: False
#
# Status 104,
# Page: https://en.wikipedia.org/wiki/Total_war
# Added: True
#
# Status 105,
# Page: https://en.wikipedia.org/wiki/Military_administration
# Added: False
# Status 106,
# Page: https://en.wikipedia.org/wiki/Military_branch
# Added: False
#
# Status 107,
# Page: https://en.wikipedia.org/wiki/Military_policy
# Added: False
#
# Status 108,
# Page: https://en.wikipedia.org/wiki/Military_education_and_training
# Added: False
#
# Status 109,
# Page: https://en.wikipedia.org/wiki/Military_service
# Added: False
#
# Status 110,
# Page: https://en.wikipedia.org/wiki/Military_sociology
# Added: False
#
# Status 111,
# Page: https://en.wikipedia.org/wiki/Military_organization
# Added: False
#
# Status 112,
# Page: https://en.wikipedia.org/wiki/Command_hierarchy
# Added: False
#
# Status 113,
# Page: https://en.wikipedia.org/wiki/Command_and_control
# Added: False
#
# Status 114,
# Page: https://en.wikipedia.org/wiki/Military_doctrine
# Added: False
#
# Status 115,
# Page: https://en.wikipedia.org/wiki/Military_engineering
# Added: False
#
# Status 116,
# Page: https://en.wikipedia.org/wiki/Military_intelligence
# Added: False
#
# Status 117,
# Page: https://en.wikipedia.org/wiki/Military_rank
# Added: False
#
# Status 118,
# Page: https://en.wikipedia.org/wiki/Military_personnel
# Added: False
#
# Status 119,
# Page: https://en.wikipedia.org/wiki/Military_recruitment
# Added: False
#
# Status 120,
# Page: https://en.wikipedia.org/wiki/Conscription
# Added: False
#
# Status 121,
# Page: https://en.wikipedia.org/wiki/Recruit_training
# Added: False
#
# Status 122,
# Page: https://en.wikipedia.org/wiki/Military_specialism
# Added: False
#
# Status 123,
# Page: https://en.wikipedia.org/wiki/Women_in_the_military
# Added: False
#
# Status 124,
# Page: https://en.wikipedia.org/wiki/Children_in_the_military
# Added: False
#
# Status 125,
# Page: https://en.wikipedia.org/wiki/Transgender_people_and_military_service
# Added: False
#
# Status 126,
# Page: https://en.wikipedia.org/wiki/Sexual_harassment_in_the_military
# Added: False
#
# Status 127,
# Page: https://en.wikipedia.org/wiki/Conscientious_objector
# Added: False
#
# Status 128,
# Page: https://en.wikipedia.org/wiki/Counter-recruitment
# Added: False
#
# Status 129,
# Page: https://en.wikipedia.org/wiki/Military_logistics
# Added: False
#
# Status 130,
# Page: https://en.wikipedia.org/wiki/Arms_industry
# Added: False
#
# Status 131,
# Page: https://en.wikipedia.org/wiki/Materiel
# Added: False
#
# Status 132,
# Page: https://en.wikipedia.org/wiki/Military_supply-chain_management
# Added: False
#
# Status 133,
# Page: https://en.wikipedia.org/wiki/Main_operating_base
# Added: False
#
# Status 134,
# Page: https://en.wikipedia.org/wiki/Forward_operating_base
# Added: False
#
# Status 135,
# Page: https://en.wikipedia.org/wiki/Military_science
# Added: False
#
# Status 136,
# Page: https://en.wikipedia.org/wiki/Power_projection
# Added: False
#
# Status 137,
# Page: https://en.wikipedia.org/wiki/Loss_of_Strength_Gradient
# Added: False
#
# Status 138,
# Page: https://en.wikipedia.org/wiki/Law_of_war
# Added: False
#
# Status 139,
# Page: https://en.wikipedia.org/wiki/Court-martial
# Added: False
#
# Status 140,
# Page: https://en.wikipedia.org/wiki/Military_justice
# Added: False
#
# Status 141,
# Page: https://en.wikipedia.org/wiki/Perfidy
# Added: False
#
# Status 142,
# Page: https://en.wikipedia.org/wiki/Martial_law
# Added: False
#
# Status 143,
# Page: https://en.wikipedia.org/wiki/War_crime
# Added: True
#
# Status 144,
# Page: https://en.wikipedia.org/wiki/Military_theory
# Added: False
#
# Status 145,
# Page: https://en.wikipedia.org/wiki/Air_supremacy
# Added: False
#
# Status 146,
# Page: https://en.wikipedia.org/wiki/Full-spectrum_dominance
# Added: False
#
# Status 147,
# Page: https://en.wikipedia.org/wiki/Overmatch
# Added: False
#
# Status 148,
# Page: https://en.wikipedia.org/wiki/Asymmetric_warfare
# Added: False
#
# Status 149,
# Page: https://en.wikipedia.org/wiki/Broken-backed_war_theory
# Added: False
#
# Status 150,
# Page: https://en.wikipedia.org/wiki/Horses_in_warfare
# Added: True
#
# Status 151,
# Page: https://en.wikipedia.org/wiki/Irregular_warfare
# Added: False
#
# Status 152,
# Page: https://en.wikipedia.org/wiki/Just_war_theory
# Added: True
#
# Status 153,
# Page: https://en.wikipedia.org/wiki/Mercenary
# Added: False
#
# -------EXCEPTION-------
# encoding with 'idna' codec failed (UnicodeError: label empty or too long)
#
# Status 154,
# Page: https://en.wikipedia.org/wiki/Military_campaign
# Added: False
#
# Status 155,
# Page: https://en.wikipedia.org/wiki/Military_operation
# Added: False
#
# Status 156,
# Page: https://en.wikipedia.org/wiki/Network-centric_warfare
# Added: False
#
# Status 157,
# Page: https://en.wikipedia.org/wiki/Operations_research
# Added: False
#
# Status 158,
# Page: https://en.wikipedia.org/wiki/Perpetual_war
# Added: False
#
# Status 159,
# Page: https://en.wikipedia.org/wiki/Principles_of_war
# Added: True
#
# Status 160,
# Page: https://en.wikipedia.org/wiki/Proxy_war
# Added: False
#
# Status 161,
# Page: https://en.wikipedia.org/wiki/Security_dilemma
# Added: False
#
# Status 162,
# Page: https://en.wikipedia.org/wiki/Tripwire_force
# Added: False
#
# Status 163,
# Page: https://en.wikipedia.org/wiki/War_film
# Added: True
#
# Status 164,
# Page: https://en.wikipedia.org/wiki/Military_exercise
# Added: False
#
# Status 165,
# Page: https://en.wikipedia.org/wiki/War_novel
# Added: True
#
# Status 166,
# Page: https://en.wikipedia.org/wiki/Wartime_sexual_violence
# Added: True
#
# Status 167,
# Page: https://en.wikipedia.org/wiki/Women_in_war
# Added: False
#
# Status 168,
# Page: https://en.wikipedia.org/wiki/World_war
# Added: True
#
# Status 169,
# Page: https://en.wikipedia.org/wiki/Colonial_war
# Added: True
#
# Status 170,
# Page: https://en.wikipedia.org/wiki/Endemic_warfare
# Added: False
#
# Status 171,
# Page: https://en.wikipedia.org/wiki/Category:Military_lists
# Added: False
#
# Status 172,
# Page: https://en.wikipedia.org/wiki/Lists_of_battles
# Added: False
#
# Status 173,
# Page: https://en.wikipedia.org/wiki/List_of_military_occupations
# Added: False
#
# Status 174,
# Page: https://en.wikipedia.org/wiki/List_of_military_operations
# Added: False
#
# Status 175,
# Page: https://en.wikipedia.org/wiki/List_of_sieges
# Added: False
#
# Status 176,
# Page: https://en.wikipedia.org/wiki/List_of_war_crimes
# Added: True
#
# Status 177,
# Page: https://en.wikipedia.org/wiki/Lists_of_weapons
# Added: False
#
# Status 178,
# Page: https://en.wikipedia.org/wiki/List_of_military_writers
# Added: False
#
# Status 179,
# Page: https://en.wikipedia.org/wiki/Template:War
# Added: False
#
# Status 180,
# Page: https://en.wikipedia.org/wiki/Template_talk:War
# Added: False
#
# Status 181,
# Page: https://en.wikipedia.org/wiki/Government
# Added: False
#
# Status 182,
# Page: https://en.wikipedia.org/wiki/Society
# Added: False
#
# Status 183,
# Page: https://en.wikipedia.org/wiki/Paramilitary
# Added: False
#
# Status 184,
# Page: https://en.wikipedia.org/wiki/Insurgency
# Added: False
#
# Status 185,
# Page: https://en.wikipedia.org/wiki/Militia
# Added: False
#
# Status 186,
# Page: https://en.wikipedia.org/wiki/Violence
# Added: False
#
# Status 187,
# Page: https://en.wikipedia.org/wiki/Aggression
# Added: False
#
# Status 188,
# Page: https://en.wikipedia.org/wiki/Regular_army
# Added: False
#
# Status 189,
# Page: https://en.wikipedia.org/wiki/Irregular_military
# Added: False
#
# Status 190,
# Page: https://en.wikipedia.org/wiki/Military_forces
# Added: False
#
# Status 191,
# Page: https://en.wikipedia.org/wiki/Legitimate_military_target
# Added: False
#
# Status 192,
# Page: https://en.wikipedia.org/wiki/Civilian_casualties
# Added: False
#
# Status 193,
# Page: https://en.wikipedia.org/wiki/Non-combatant
# Added: False
#
# Status 194,
# Page: https://en.wikipedia.org/wiki/War_studies
# Added: False
#
# Status 195,
# Page: https://en.wikipedia.org/wiki/Human_nature
# Added: False
#
# Status 196,
# Page: https://en.wikipedia.org/wiki/Old_English
# Added: False
#
# Status 197,
# Page: https://en.wikipedia.org/wiki/Franks
# Added: False
#
# Status 198,
# Page: https://en.wikipedia.org/wiki/Proto-Germanic_language
# Added: False
#
# Status 199,
# Page: https://en.wikipedia.org/wiki/Siege_of_Dapur
# Added: False
#
# Status 200,
# Page: https://en.wikipedia.org/wiki/Ramesseum
# Added: False
#
# Status 201,
# Page: https://en.wikipedia.org/wiki/Thebes,_Egypt
# Added: False
#
# Status 202,
# Page: https://en.wikipedia.org/wiki/Mesolithic
# Added: False
#
# Status 203,
# Page: https://en.wikipedia.org/wiki/Jebel_Sahaba
# Added: False
#
# Status 204,
# Page: https://en.wikipedia.org/wiki/Gunpowder
# Added: False
#
# Status 205,
# Page: https://en.wikipedia.org/wiki/War_Before_Civilization
# Added: True
#
# Status 206,
# Page: https://en.wikipedia.org/wiki/Samurai
# Added: False
#
# Status 207,
# Page: https://en.wikipedia.org/wiki/Mongol_Empire
# Added: False
#
# Status 208,
# Page: https://en.wikipedia.org/wiki/Winter_War
# Added: True
# Status 209,
# Page: https://en.wikipedia.org/wiki/Atom_bomb
# Added: False
#
# Status 210,
# Page: https://en.wikipedia.org/wiki/Albert_Einstein
# Added: False
#
# Status 211,
# Page: https://en.wikipedia.org/wiki/Mao_Zedong
# Added: False
#
# Status 212,
# Page: https://en.wikipedia.org/wiki/Nuclear_war
# Added: True
#
# Status 213,
# Page: https://en.wikipedia.org/wiki/Indo-Pakistani_War_of_1971
# Added: True
#
# Status 214,
# Page: https://en.wikipedia.org/wiki/Gulf_War
# Added: True
#
# Status 215,
# Page: https://en.wikipedia.org/wiki/Human_Security_Report_2005
# Added: False
#
# Status 216,
# Page: https://en.wikipedia.org/wiki/Cold_War
# Added: True
#
# Status 217,
# Page: https://en.wikipedia.org/wiki/Australian_4th_Division
# Added: False
#
# Status 218,
# Page: https://en.wikipedia.org/wiki/Chemical_weapons_in_World_War_I
# Added: True
#
# Status 219,
# Page: https://en.wikipedia.org/wiki/Third_Battle_of_Ypres
# Added: False
#
# Status 220,
# Page: https://en.wikipedia.org/wiki/Belligerent
# Added: False
#
# Status 221,
# Page: https://en.wikipedia.org/wiki/World_War_I
# Added: True
#
# Status 222,
# Page: https://en.wikipedia.org/wiki/Cold_warfare
# Added: True
#
# Status 223,
# Page: https://en.wikipedia.org/wiki/Covert_operation
# Added: False
#
# Status 224,
# Page: https://en.wikipedia.org/wiki/Espionage
# Added: False
#
# Status 225,
# Page: https://en.wikipedia.org/wiki/Biological_weapon
# Added: False
#
# Status 226,
# Page: https://en.wikipedia.org/wiki/Chemical_weapons
# Added: False
#
# Status 227,
# Page: https://en.wikipedia.org/wiki/Computer
# Added: False
#
# Status 228,
# Page: https://en.wikipedia.org/wiki/Computer_network
# Added: False
#
# Status 229,
# Page: https://en.wikipedia.org/wiki/Laws_of_war
# Added: False
#
# Status 230,
# Page: https://en.wikipedia.org/wiki/War_effort
# Added: True
#
# Status 231,
# Page: https://en.wikipedia.org/wiki/Lebensraum
# Added: False
#
# Status 232,
# Page: https://en.wikipedia.org/wiki/Anglo-Dutch_Wars
# Added: True
#
# Status 233,
# Page: https://en.wikipedia.org/wiki/Effects_of_war
# Added: True
#
# Status 234,
# Page: https://en.wikipedia.org/wiki/World_War_II
# Added: True
#
# Status 235,
# Page: https://en.wikipedia.org/wiki/List_of_wars_by_death_toll
# Added: True
#
# Status 236,
# Page: https://en.wikipedia.org/wiki/Casualty_recording
# Added: False
#
# Status 237,
# Page: https://en.wikipedia.org/wiki/Mongol_conquests
# Added: False
#
# Status 238,
# Page: https://en.wikipedia.org/wiki/Modern_history
# Added: False
#
# Status 239,
# Page: https://en.wikipedia.org/wiki/Paraguayan_War
# Added: False
#
# Status 240,
# Page: https://en.wikipedia.org/wiki/Paraguayan_War_casualties
# Added: False
#
# Status 241,
# Page: https://en.wikipedia.org/wiki/Famine
# Added: False
#
# Status 242,
# Page: https://en.wikipedia.org/wiki/Prisoner_of_war
# Added: True
#
# Status 243,
# Page: https://en.wikipedia.org/wiki/Byelorussian_Soviet_Socialist_Republic
# Added: False
#
# Status 244,
# Page: https://en.wikipedia.org/wiki/Propaganda
# Added: False
#
# Status 245,
# Page: https://en.wikipedia.org/wiki/Weapons_manufacturers
# Added: False
#
# Status 246,
# Page: https://en.wikipedia.org/wiki/Second_Sino-Japanese_War
# Added: True
#
# Status 247,
# Page: https://en.wikipedia.org/wiki/World_War_II_casualties
# Added: True
#
# Status 248,
# Page: https://en.wikipedia.org/wiki/Tatar_invasions
# Added: False
#
# Status 249,
# Page: https://en.wikipedia.org/wiki/Taiping_Rebellion
# Added: False
#
# Status 250,
# Page: https://en.wikipedia.org/wiki/World_War_I_casualties
# Added: True
#
# Status 251,
# Page: https://en.wikipedia.org/wiki/An_Lushan_Rebellion
# Added: False
#
# Status 252,
# Page: https://en.wikipedia.org/wiki/Qing_dynasty
# Added: False
#
# Status 253,
# Page: https://en.wikipedia.org/wiki/Ming_dynasty
# Added: False
#
# Status 254,
# Page: https://en.wikipedia.org/wiki/Tamerlane
# Added: False
#
# Status 255,
# Page: https://en.wikipedia.org/wiki/Russian_Civil_War
# Added: True
#
# Status 256,
# Page: https://en.wikipedia.org/wiki/Allied_intervention_in_the_Russian_Civil_War
# Added: True
#
# Status 257,
# Page: https://en.wikipedia.org/wiki/Posttraumatic_stress_disorder
# Added: False
#
# Status 258,
# Page: https://en.wikipedia.org/wiki/US_Army
# Added: False
#
# Status 259,
# Page: https://en.wikipedia.org/wiki/S.L.A._Marshall
# Added: False
#
# Status 260,
# Page: https://en.wikipedia.org/wiki/The_Apotheosis_of_War
# Added: True
#
# Status 261,
# Page: https://en.wikipedia.org/wiki/Vasily_Vereshchagin
# Added: False
#
# Status 262,
# Page: https://en.wikipedia.org/wiki/American_Civil_War
# Added: True
#
# Status 263,
# Page: https://en.wikipedia.org/wiki/United_States_military_casualties_of_war
# Added: True
#
# Status 264,
# Page: https://en.wikipedia.org/wiki/Crow_Indians
# Added: False
#
# Status 265,
# Page: https://en.wikipedia.org/wiki/Napoleon_I_of_France
# Added: False
#
# Status 266,
# Page: https://en.wikipedia.org/wiki/Typhus
# Added: False
#
# Status 267,
# Page: https://en.wikipedia.org/wiki/Royal_Navy
# Added: False
#
# Status 268,
# Page: https://en.wikipedia.org/wiki/Civilian
# Added: False
#
# Status 269,
# Page: https://en.wikipedia.org/wiki/Population
# Added: False
#
# Status 270,
# Page: https://en.wikipedia.org/wiki/Holy_Roman_Empire
# Added: False
#
# Status 271,
# Page: https://en.wikipedia.org/wiki/Genocide
# Added: False
#
# Status 272,
# Page: https://en.wikipedia.org/wiki/Infant_mortality
# Added: False
#
# Status 273,
# Page: https://en.wikipedia.org/wiki/Malnutrition
# Added: False
#
# Status 274,
# Page: https://en.wikipedia.org/wiki/Drinking_water
# Added: False
#
# Status 275,
# Page: https://en.wikipedia.org/wiki/Soviet_Union
# Added: False
#
# Status 276,
# Page: https://en.wikipedia.org/wiki/World_War_II_casualties_of_the_Soviet_Union
# Added: True
#
# Status 277,
# Page: https://en.wikipedia.org/wiki/Military_Keynesianism
# Added: False
#
# Status 278,
# Page: https://en.wikipedia.org/wiki/War_reparations
# Added: True
#
# Status 279,
# Page: https://en.wikipedia.org/wiki/Alsace-Lorraine
# Added: False
#
# Status 280,
# Page: https://en.wikipedia.org/wiki/Great_Depression
# Added: False
#
# Status 281,
# Page: https://en.wikipedia.org/wiki/Keynesian
# Added: False
#
# Status 282,
# Page: https://en.wikipedia.org/wiki/Franco-Prussian_War
# Added: True
#
# Status 283,
# Page: https://en.wikipedia.org/wiki/Russian_Revolution_of_1917
# Added: False
#
# Status 284,
# Page: https://en.wikipedia.org/wiki/Warsaw
# Added: True
#
# Status 285,
# Page: https://en.wikipedia.org/wiki/International_relations_theory
# Added: False
#
# Status 286,
# Page: https://en.wikipedia.org/wiki/List_of_campaigns_of_Suleiman_the_Magnificent
# Added: False
#
# Status 287,
# Page: https://en.wikipedia.org/wiki/Ottoman_wars_in_Europe
# Added: True
#
# Status 288,
# Page: https://en.wikipedia.org/wiki/Carl_von_Clausewitz
# Added: False
#
# Status 289,
# Page: https://en.wikipedia.org/wiki/Psychoanalyst
# Added: False
#
# Status 290,
# Page: https://en.wikipedia.org/wiki/Joost_Meerloo
# Added: False
#
# Status 291,
# Page: https://en.wikipedia.org/wiki/John_Bowlby
# Added: False
#
# Status 292,
# Page: https://en.wikipedia.org/wiki/Inheritance
# Added: False
#
# Status 293,
# Page: https://en.wikipedia.org/wiki/Psychological_projection
# Added: False
#
# Status 294,
# Page: https://en.wikipedia.org/wiki/Ideology
# Added: False
#
# Status 295,
# Page: https://en.wikipedia.org/wiki/Melanie_Klein
# Added: False
#
# Status 296,
# Page: https://en.wikipedia.org/wiki/Adolf_Hitler
# Added: False
#
# Status 297,
# Page: https://en.wikipedia.org/wiki/Battle_of_Schwaderloh
# Added: False
#
# Status 298,
# Page: https://en.wikipedia.org/wiki/Luzerner_Schilling
# Added: False
#
# Status 299,
# Page: https://en.wikipedia.org/wiki/Competition
# Added: False
#
# Status 300,
# Page: https://en.wikipedia.org/wiki/Common_chimpanzee
# Added: False
#
# Status 301,
# Page: https://en.wikipedia.org/wiki/Ant
# Added: False
#
# Status 302,
# Page: https://en.wikipedia.org/wiki/Steven_Pinker
# Added: False
#
# Status 303,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Verifiability
# Added: False
#
# Status 304,
# Page: https://en.wikipedia.org/wiki/Deterrence_theory
# Added: False
#
# Status 305,
# Page: https://en.wikipedia.org/wiki/Revenge
# Added: False
#
# Status 306,
# Page: https://en.wikipedia.org/wiki/Honor
# Added: False
#
# Status 307,
# Page: https://en.wikipedia.org/wiki/Maya_warfare
# Added: False
#
# Status 308,
# Page: https://en.wikipedia.org/wiki/Classic_Maya_collapse
# Added: False
#
# Status 309,
# Page: https://en.wikipedia.org/wiki/Maya_civilization
# Added: False
#
# Status 310,
# Page: https://en.wikipedia.org/wiki/Ashley_Montagu
# Added: False
#
# Status 311,
# Page: https://en.wikipedia.org/wiki/Semai_people
# Added: False
#
# Status 312,
# Page: https://en.wikipedia.org/wiki/Oil_well
# Added: False
# Status 313,
# Page: https://en.wikipedia.org/wiki/Natural_resource
# Added: False
#
# Status 314,
# Page: https://en.wikipedia.org/wiki/State-building
# Added: False
#
# Status 315,
# Page: https://en.wikipedia.org/wiki/Fiscal_capacity
# Added: False
#
# Status 316,
# Page: https://en.wikipedia.org/wiki/Presidents_of_the_United_States
# Added: False
#
# Status 317,
# Page: https://en.wikipedia.org/wiki/General_officer
# Added: False
#
# Status 318,
# Page: https://en.wikipedia.org/wiki/Marxist_explanations_of_warfare
# Added: True
#
# Status 319,
# Page: https://en.wikipedia.org/wiki/Marxism
# Added: False
#
# Status 320,
# Page: https://en.wikipedia.org/wiki/Imperialism
# Added: False
#
# Status 321,
# Page: https://en.wikipedia.org/wiki/Capitalism
# Added: False
#
# Status 322,
# Page: https://en.wikipedia.org/wiki/Karl_Kautsky
# Added: False
#
# Status 323,
# Page: https://en.wikipedia.org/wiki/Rosa_Luxemburg
# Added: False
#
# Status 324,
# Page: https://en.wikipedia.org/wiki/Rudolf_Hilferding
# Added: False
#
# Status 325,
# Page: https://en.wikipedia.org/wiki/Vladimir_Lenin
# Added: False
#
# Status 326,
# Page: https://en.wikipedia.org/wiki/Means_of_production
# Added: False
#
# Status 327,
# Page: https://en.wikipedia.org/wiki/Consumer_demand
# Added: False
#
# Status 328,
# Page: https://en.wikipedia.org/wiki/Capitalist_economy
# Added: False
#
# Status 329,
# Page: https://en.wikipedia.org/wiki/Unified_Task_Force
# Added: False
#
# Status 330,
# Page: https://en.wikipedia.org/wiki/Malthusian_catastrophe
# Added: False
#
# Status 331,
# Page: https://en.wikipedia.org/wiki/Pope_Urban_II
# Added: False
#
# Status 332,
# Page: https://en.wikipedia.org/wiki/First_Crusade
# Added: False
#
# Status 333,
# Page: https://en.wikipedia.org/wiki/Thomas_Malthus
# Added: False
#
# Status 334,
# Page: https://en.wikipedia.org/wiki/Mali
# Added: False
#
# Status 335,
# Page: https://en.wikipedia.org/wiki/Sudanese_nomadic_conflicts
# Added: False
#
# Status 336,
# Page: https://en.wikipedia.org/wiki/Sahel
# Added: False
#
# Status 337,
# Page: https://en.wikipedia.org/wiki/Land_degradation
# Added: False
#
# Status 338,
# Page: https://en.wikipedia.org/wiki/Population_pyramid
# Added: False
#
# Status 339,
# Page: https://en.wikipedia.org/wiki/Demographics_of_Africa
# Added: False
#
# Status 340,
# Page: https://en.wikipedia.org/wiki/Gunnar_Heinsohn
# Added: False
#
# Status 341,
# Page: https://en.wikipedia.org/wiki/Youth_bulge
# Added: False
#
# Status 342,
# Page: https://en.wikipedia.org/wiki/French_Revolution
# Added: False
#
# Status 343,
# Page: https://en.wikipedia.org/wiki/Nazism
# Added: False
#
# Status 344,
# Page: https://en.wikipedia.org/wiki/Rwandan_genocide
# Added: False
#
# Status 345,
# Page: https://en.wikipedia.org/wiki/Population_Action_International
# Added: False
#
# Status 346,
# Page: https://en.wikipedia.org/wiki/Game_theory
# Added: False
#
# Status 347,
# Page: https://en.wikipedia.org/wiki/Peace_war_game
# Added: False
#
# Status 348,
# Page: https://en.wikipedia.org/wiki/James_Fearon
# Added: False
#
# Status 349,
# Page: https://en.wikipedia.org/wiki/Information_asymmetry
# Added: False
#
# Status 350,
# Page: https://en.wikipedia.org/wiki/Geoffrey_Blainey
# Added: False
#
# Status 351,
# Page: https://en.wikipedia.org/wiki/Cognitive_bias
# Added: False
#
# Status 352,
# Page: https://en.wikipedia.org/wiki/Iain_King
# Added: False
#
# Status 353,
# Page: https://en.wikipedia.org/wiki/GroupThink
# Added: False
#
# Status 354,
# Page: https://en.wikipedia.org/wiki/Lewis_Fry_Richardson
# Added: False
#
# Status 355,
# Page: https://en.wikipedia.org/wiki/Correlates_of_War
# Added: False
#
# Status 356,
# Page: https://en.wikipedia.org/wiki/Uppsala_Conflict_Data_Program
# Added: False
#
# Status 357,
# Page: https://en.wikipedia.org/wiki/Kenneth_Waltz
# Added: False
#
# Status 358,
# Page: https://en.wikipedia.org/wiki/Man,_the_State,_and_War
# Added: False
#
# Status 359,
# Page: https://en.wikipedia.org/wiki/Realism_in_international_relations
# Added: False
#
# Status 360,
# Page: https://en.wikipedia.org/wiki/Henry_Kissinger
# Added: False
#
# Status 361,
# Page: https://en.wikipedia.org/wiki/Hans_Morgenthau
# Added: False
#
# Status 362,
# Page: https://en.wikipedia.org/wiki/John_Mearsheimer
# Added: False
#
# Status 363,
# Page: https://en.wikipedia.org/wiki/Power_transition_theory
# Added: False
#
# Status 364,
# Page: https://en.wikipedia.org/wiki/Diversionary_foreign_policy
# Added: False
#
# Status 365,
# Page: https://en.wikipedia.org/wiki/Realistic_conflict_theory
# Added: False
#
# Status 366,
# Page: https://en.wikipedia.org/wiki/Group_cohesiveness
# Added: False
#
# Status 367,
# Page: https://en.wikipedia.org/wiki/Bounded_rationality
# Added: False
#
# Status 368,
# Page: https://en.wikipedia.org/wiki/Cognitive_biases
# Added: False
#
# Status 369,
# Page: https://en.wikipedia.org/wiki/Prospect_theory
# Added: False
#
# Status 370,
# Page: https://en.wikipedia.org/wiki/Battle_of_Waterloo
# Added: False
#
# Status 371,
# Page: https://en.wikipedia.org/wiki/John_Heaviside_Clark
# Added: False
#
# Status 372,
# Page: https://en.wikipedia.org/wiki/Morality
# Added: False
#
# Status 373,
# Page: https://en.wikipedia.org/wiki/Jus_ad_bellum
# Added: False
#
# Status 374,
# Page: https://en.wikipedia.org/wiki/Jus_in_bello
# Added: False
#
# Status 375,
# Page: https://en.wikipedia.org/wiki/Leningrad
# Added: False
#
# Status 376,
# Page: https://en.wikipedia.org/wiki/General_Plan_East
# Added: False
#
# Status 377,
# Page: https://en.wikipedia.org/wiki/International_law
# Added: False
#
# Status 378,
# Page: https://en.wikipedia.org/wiki/Pragmatism
# Added: False
#
# Status 379,
# Page: https://en.wikipedia.org/wiki/Social_Darwinism
# Added: False
#
# Status 380,
# Page: https://en.wikipedia.org/wiki/Archetypes
# Added: False
#
# Status 381,
# Page: https://en.wikipedia.org/wiki/Anti-war_movement
# Added: True
#
# Status 382,
# Page: https://en.wikipedia.org/wiki/Second_Vatican_Council
# Added: False
#
# Status 383,
# Page: https://en.wikipedia.org/wiki/Vietnam_War
# Added: True
#
# Status 384,
# Page: https://en.wikipedia.org/wiki/Iraq_War
# Added: True
#
# Status 385,
# Page: https://en.wikipedia.org/wiki/Mexican_Drug_War
# Added: False
#
# Status 386,
# Page: https://en.wikipedia.org/wiki/Portal:War
# Added: True
#
# Status 387,
# Page: https://en.wikipedia.org/wiki/Outline_of_war
# Added: True
#
# Status 388,
# Page: https://en.wikipedia.org/wiki/International_Committee_of_the_Red_Cross
# Added: False
#
# Status 389,
# Page: https://en.wikipedia.org/wiki/Wayback_Machine
# Added: False
#
# Status 390,
# Page: https://en.wikipedia.org/wiki/Hugo_Haase
# Added: False
#
# Status 391,
# Page: https://en.wikipedia.org/wiki/Marc_Pilisuk
# Added: False
#
# Status 392,
# Page: https://en.wikipedia.org/wiki/The_New_York_Times
# Added: False
#
# Status 393,
# Page: https://en.wikipedia.org/wiki/Roger_Griffin
# Added: False
#
# Status 394,
# Page: https://en.wikipedia.org/wiki/Marxists_Internet_Archive
# Added: False
#
# Status 395,
# Page: https://en.wikipedia.org/wiki/Foreign_Policy
# Added: False
#
# Status 396,
# Page: https://en.wikipedia.org/wiki/Henrik_Urdal
# Added: False
#
# Status 397,
# Page: https://en.wikipedia.org/wiki/I.C.B._Dear
# Added: False
#
# Status 398,
# Page: https://en.wikipedia.org/wiki/M.R.D._Foot
# Added: False
#
# Status 399,
# Page: https://en.wikipedia.org/wiki/Template:Cite_book
# Added: False
#
# Status 400,
# Page: https://en.wikipedia.org/wiki/Smedley_Butler
# Added: False
#
# Status 401,
# Page: https://en.wikipedia.org/wiki/War_is_a_Racket
# Added: False
#
# Status 402,
# Page: https://en.wikipedia.org/wiki/John_Keegan
# Added: False
#
# Status 403,
# Page: https://en.wikipedia.org/wiki/A_History_of_Warfare
# Added: False
#
# Status 404,
# Page: https://en.wikipedia.org/wiki/Gabriel_Kolko
# Added: False
#
# Status 405,
# Page: https://en.wikipedia.org/wiki/The_New_Press
# Added: False
#
# Status 406,
# Page: https://en.wikipedia.org/wiki/Strategic_Studies_Institute
# Added: False
#
# Status 407,
# Page: https://en.wikipedia.org/wiki/United_States_Army_War_College
# Added: False
#
# Status 408,
# Page: https://en.wikipedia.org/wiki/Hew_Strachan
# Added: False
#
# Status 409,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Wikimedia_sister_projects
# Added: False
#
# Status 410,
# Page: https://en.wikipedia.org/wiki/Template:War_navbox
# Added: False
#
# Status 411,
# Page: https://en.wikipedia.org/wiki/Template_talk:War_navbox
# Added: False
#
# Status 412,
# Page: https://en.wikipedia.org/wiki/Category:Peace
# Added: False
#
# Status 413,
# Page: https://en.wikipedia.org/wiki/List_of_periods_of_regional_peace
# Added: False
#
# Status 414,
# Page: https://en.wikipedia.org/wiki/Category:Conflicts
# Added: False
#
# Status 415,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_military_conflicts
# Added: False
# Status 416,
# Page: https://en.wikipedia.org/wiki/Category:War
# Added: False
#
# Status 417,
# Page: https://en.wikipedia.org/wiki/Category:Civil_wars
# Added: False
#
# Status 418,
# Page: https://en.wikipedia.org/wiki/List_of_civil_wars
# Added: True
#
# Status 419,
# Page: https://en.wikipedia.org/wiki/Category:Attacks
# Added: False
#
# Status 420,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_attacks
# Added: False
#
# Status 421,
# Page: https://en.wikipedia.org/wiki/Category:Terrorism_by_form
# Added: False
#
# Status 422,
# Page: https://en.wikipedia.org/wiki/List_of_terrorist_incidents
# Added: False
#
# Status 423,
# Page: https://en.wikipedia.org/wiki/Category:Massacres
# Added: False
#
# Status 424,
# Page: https://en.wikipedia.org/wiki/List_of_events_named_massacres
# Added: False
#
# Status 425,
# Page: https://en.wikipedia.org/wiki/Category:Warfare
# Added: False
#
# Status 426,
# Page: https://en.wikipedia.org/wiki/Category:Battles
# Added: False
#
# Status 427,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_battles
# Added: False
#
# Status 428,
# Page: https://en.wikipedia.org/wiki/Category:Wars
# Added: False
#
# Status 429,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_wars
# Added: False
#
# Status 430,
# Page: https://en.wikipedia.org/wiki/Category:Ongoing_conflicts
# Added: False
#
# Status 431,
# Page: https://en.wikipedia.org/wiki/List_of_ongoing_armed_conflicts
# Added: False
#
# Status 432,
# Page: https://en.wikipedia.org/wiki/International_relations
# Added: False
#
# Status 433,
# Page: https://en.wikipedia.org/wiki/International_organization
# Added: False
#
# Status 434,
# Page: https://en.wikipedia.org/wiki/BRICS
# Added: False
#
# Status 435,
# Page: https://en.wikipedia.org/wiki/Collective_Security_Treaty_Organization
# Added: False
#
# Status 436,
# Page: https://en.wikipedia.org/wiki/International_Criminal_Court
# Added: False
#
# Status 437,
# Page: https://en.wikipedia.org/wiki/League_of_Nations
# Added: False
#
# Status 438,
# Page: https://en.wikipedia.org/wiki/Non-Aligned_Movement
# Added: False
#
# Status 439,
# Page: https://en.wikipedia.org/wiki/NATO
# Added: False
#
# Status 440,
# Page: https://en.wikipedia.org/wiki/Shanghai_Cooperation_Organisation
# Added: False
#
# Status 441,
# Page: https://en.wikipedia.org/wiki/United_Nations
# Added: False
#
# Status 442,
# Page: https://en.wikipedia.org/wiki/Warsaw_Pact
# Added: True
#
# Status 443,
# Page: https://en.wikipedia.org/wiki/Political_history_of_the_world
# Added: False
#
# Status 444,
# Page: https://en.wikipedia.org/wiki/Diplomatic_history_of_World_War_II
# Added: True
#
# Status 445,
# Page: https://en.wikipedia.org/wiki/International_relations_since_1989
# Added: False
#
# Status 446,
# Page: https://en.wikipedia.org/wiki/Appeasement
# Added: False
#
# Status 447,
# Page: https://en.wikipedia.org/wiki/Collective_security
# Added: False
#
# Status 448,
# Page: https://en.wikipedia.org/wiki/Colonialism
# Added: False
#
# Status 449,
# Page: https://en.wikipedia.org/wiki/Hegemony
# Added: False
#
# Status 450,
# Page: https://en.wikipedia.org/wiki/Idealism_in_international_relations
# Added: False
#
# Status 451,
# Page: https://en.wikipedia.org/wiki/Liberal_institutionalism
# Added: False
#
# Status 452,
# Page: https://en.wikipedia.org/wiki/Peace
# Added: False
#
# Status 453,
# Page: https://en.wikipedia.org/wiki/Sovereignty
# Added: False
#
# Status 454,
# Page: https://en.wikipedia.org/wiki/Suzerainty
# Added: False
#
# Status 455,
# Page: https://en.wikipedia.org/wiki/Treaty
# Added: False
#
# Status 456,
# Page: https://en.wikipedia.org/wiki/Marxist_international_relations_theory
# Added: False
#
# Status 457,
# Page: https://en.wikipedia.org/wiki/Diplomacy
# Added: False
#
# Status 458,
# Page: https://en.wikipedia.org/wiki/Geopolitics
# Added: False
#
# Status 459,
# Page: https://en.wikipedia.org/wiki/Help:Category
# Added: False
#
# Status 460,
# Page: https://en.wikipedia.org/wiki/Category:Dispute_resolution
# Added: False
#
# Status 461,
# Page: https://en.wikipedia.org/wiki/Category:Violence
# Added: False
#
# Status 462,
# Page: https://en.wikipedia.org/wiki/Category:CS1:_long_volume_value
# Added: False
#
# Status 463,
# Page: https://en.wikipedia.org/wiki/Category:CS1_errors:_missing_periodical
# Added: False
#
# Status 464,
# Page: https://en.wikipedia.org/wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# Added: False
#
# Status 465,
# Page: https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_October_2020
# Added: False
#
# Status 466,
# Page: https://en.wikipedia.org/wiki/Category:Use_American_English_from_October_2017
# Added: False
#
# Status 467,
# Page: https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_written_in_American_English
# Added: False
#
# Status 468,
# Page: https://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements
# Added: False
#
# Status 469,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_July_2016
# Added: False
#
# Status 470,
# Page: https://en.wikipedia.org/wiki/Category:All_articles_with_specifically_marked_weasel-worded_phrases
# Added: False
#
# Status 471,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_specifically_marked_weasel-worded_phrases_from_July_2016
# Added: False
#
# Status 472,
# Page: https://en.wikipedia.org/wiki/Category:All_articles_with_failed_verification
# Added: False
#
# Status 473,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_failed_verification_from_July_2016
# Added: False
#
# Status 474,
# Page: https://en.wikipedia.org/wiki/Category:Pages_using_Sister_project_links_with_hidden_wikidata
# Added: False
#
# Status 475,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_BNF_identifiers
# Added: False
#
# Status 476,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_LCCN_identifiers
# Added: False
#
# Status 477,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_FAST_identifiers
# Added: False
#
# Status 478,
# Page: https://en.wikipedia.org/wiki/Special:MyContributions
# Added: False
#
# Status 479,
# Page: https://en.wikipedia.org/wiki/Talk:War
# Added: False
#
# Status 480,
# Page: https://en.wikipedia.org/wiki/Main_Page
# Added: False
#
# Status 481,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Contents
# Added: False
#
# Status 482,
# Page: https://en.wikipedia.org/wiki/Portal:Current_events
# Added: False
#
# Status 483,
# Page: https://en.wikipedia.org/wiki/Wikipedia:About
# Added: False
#
# Status 484,
# Page: https://en.wikipedia.org/wiki/Help:Contents
# Added: False
#
# Status 485,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Community_portal
# Added: False
#
# Status 486,
# Page: https://en.wikipedia.org/wiki/Special:RecentChanges
# Added: False
#
# Status 487,
# Page: https://en.wikipedia.org/wiki/Special:WhatLinksHere/War
# Added: False
#
# Status 488,
# Page: https://en.wikipedia.org/wiki/Special:RecentChangesLinked/War
# Added: True
#
# Status 489,
# Page: https://en.wikipedia.org/wiki/Conflict_zone
# Added: False
#
# Status 490,
# Page: https://en.wikipedia.org/wiki/Video_game_developer
# Added: False
#
# Status 491,
# Page: https://en.wikipedia.org/wiki/Video_game_publisher
# Added: False
#
# Status 492,
# Page: https://en.wikipedia.org/wiki/Ubi_Soft
# Added: False
#
# Status 493,
# Page: https://en.wikipedia.org/wiki/Dreamcast
# Added: False
#
# Status 494,
# Page: https://en.wikipedia.org/wiki/Microsoft_Windows
# Added: False
#
# Status 495,
# Page: https://en.wikipedia.org/wiki/North_America
# Added: False
#
# Status 496,
# Page: https://en.wikipedia.org/wiki/Video_game_genre
# Added: False
#
# Status 497,
# Page: https://en.wikipedia.org/wiki/Real_time_strategy
# Added: False
#
# Status 498,
# Page: https://en.wikipedia.org/wiki/Single_player
# Added: False
#
# Status 499,
# Page: https://en.wikipedia.org/wiki/Multiplayer_video_game
# Added: False
#
# Status 500,
# Page: https://en.wikipedia.org/wiki/Real-time_strategy_game
# Added: False
#                                                   text  \
# 0    War - Wikipedia\nWar\nFrom Wikipedia, the free...
# 1    Conflict Zone - Wikipedia\nConflict Zone\nFrom...
# 2    Stele of the Vultures - Wikipedia\nStele of th...
# 3    Battle of Hastings - Wikipedia\nBattle of Hast...
# 4    French invasion of Russia - Wikipedia\nFrench ...
# ..                                                 ...
# 496  Video game genre - Wikipedia\nVideo game genre...
# 497  Real-time strategy - Wikipedia\nReal-time stra...
# 498  Single-player video game - Wikipedia\nSingle-p...
# 499  Multiplayer video game - Wikipedia\nMultiplaye...
# 500  Real-time strategy - Wikipedia\nReal-time stra...
#
#                                      title  \
# 0                          War - Wikipedia
# 1                Conflict Zone - Wikipedia
# 2        Stele of the Vultures - Wikipedia
# 3           Battle of Hastings - Wikipedia
# 4    French invasion of Russia - Wikipedia
# ..                                     ...
# 496           Video game genre - Wikipedia
# 497         Real-time strategy - Wikipedia
# 498   Single-player video game - Wikipedia
# 499     Multiplayer video game - Wikipedia
# 500         Real-time strategy - Wikipedia
#
#                                                    url
# 0                    https://en.wikipedia.org/wiki/War
# 1          https://en.wikipedia.org/wiki/Conflict_Zone
# 2    https://en.wikipedia.org/wiki/Stele_of_the_Vul...
# 3     https://en.wikipedia.org/wiki/Battle_of_Hastings
# 4    https://en.wikipedia.org/wiki/Retreat_from_Moscow
# ..                                                 ...
# 496     https://en.wikipedia.org/wiki/Video_game_genre
# 497   https://en.wikipedia.org/wiki/Real_time_strategy
# 498        https://en.wikipedia.org/wiki/Single_player
# 499  https://en.wikipedia.org/wiki/Multiplayer_vide...
# 500  https://en.wikipedia.org/wiki/Real-time_strate...
#
# [501 rows x 3 columns]

# %% [markdown]
# Cделайте `pandas`-таблицу со следующей информацией:
#
# * количество слов в тексте статьи;
# * принадлежит ли страница выбранной категории.
#
# Для последнего пункта можете воспользоваться функцией поиска слов по заданным префиксам, рассмотренной на <a href="https://mipt-stats.gitlab.io/courses/ad_fivt/data_parsing.html">занятии</a>.

# %% [markdown]
# *Скопируем наш датасет, чтобы потом всё можно было починить, ибо снова парсить - долго.*

# %%
import copy
work_df = copy.deepcopy(df)

# %% [markdown]
# Немного изменим наш hard_html_filter - разделим его на две функции, как требует apply.

# %%
def hard_url_filter(url):
    accepted_url = ["war"]
    for token in accepted_url:
        if token not in url.lower():
            return False
    return True

def hard_text_filter(text):
    accepted_text = ["war", "russia"]
    for token in accepted_text:
        if token not in text.lower():
            return False
    return True

# %% [markdown]
# Выполним задание

# %%
work_df['nice_text'] = work_df["text"].apply(hard_text_filter)
work_df['nice_url'] = work_df["url"].apply(hard_url_filter)
work_df['is_target'] = work_df["nice_url"] & work_df["nice_text"]
work_df['words'] = work_df["text"].apply(lambda x: len(x.split()))
work_df = work_df.reindex(columns=['words', 'is_target'])
work_df
# Out:
#      words  is_target
# 0    11321       True
# 1     1150      False
# 2     3002      False
# 3     8800      False
# 4    16290      False
# ..     ...        ...
# 496   2778      False
# 497   7361      False
# 498   1598      False
# 499   2985      False
# 500   7361      False
#
# [501 rows x 2 columns]

# %% [markdown]
# Определите, какой процент скачанных страниц принадлежит выбранной категории?

# %%
100 * work_df.groupby(by="is_target").count().loc[True].loc["words"] / len(work_df.index)
# Out:
# 16.167664670658684

# %% [markdown]
# C помощью гистограмм сравните визуально распределения количества слов в статьях из выбранной категории и во всех остальных. Для этих двух распределений вычислите средние, медианы и дисперсии. Средние и медианы отобразите на графиках с гистограммами. Сделайте выводы.

# %%
for attr in [True, False]:
    fig, ax = plt.subplots()
    data = work_df[work_df["is_target"] == attr]["words"]
    ax.hist(data[data < 30000], bins=20)
    ax.set_title(f"Длина статей с is_target={attr}")
    ax.set_xlabel("Количество слов")
    ax.set_ylabel("Количество статей")
    min_ylim, max_ylim = plt.ylim()
    height = 0.9
    for value, text in zip([data.mean(), data.median()],
                           ["Среднее", "Медиана"]):
        plt.axvline(value, color='black', linestyle='solid', linewidth=1)
        plt.text(value*1.1, max_ylim*height,
            text + ': {:.2f}'.format(value), fontdict={'size': 18})
        height -= 0.1
    plt.text(plt.xlim()[1]*0.8, 0.9*max_ylim, 
             'Дисперсия: {:.2f}'.format(data.var()), fontdict={'size': 18, 'weight': 'bold'})

# %% [markdown]
# **Вывод:** графики в целом схожи, превалируют короткие статьи. В среднем статьи про войны связанные с Россией длиннее, чем остальные полученные статьи.

# %% [markdown]
# Постройте boxplot-графики для того, чтобы сравнить эти 2 распределения. Какой способ сравнения кажется вам более удобным?

# %%
with sns.axes_style('whitegrid'):
    # plt.title("Длина статей по категориям")
    work_df["topic"] = work_df["is_target"].apply(lambda x: ("Война с участием России" if x else "Другое"))
    ax = sns.boxplot(data=work_df, x='topic', y='words', showmeans=True,
                     meanprops={"marker":"s","markerfacecolor":"white", "markeredgecolor":"blue"})
    del work_df["topic"]
    ax.set_yticks(np.arange(0, 40000, 2500))
    ax.set_title("Длина статей по категориям")
    ax.set_xlabel("Тема")
    ax.set_ylabel("Количество слов")

# %% [markdown]
# **Вывод:** Boxplot анализировать проще (особенно, если категорий больше 2), в том числе потому, что можно сравнивать медианы/среднее и т.п.

# %%
result1 = copy.deepcopy(work_df)
# Сохраним результат

# %% [markdown]
# **3.** Визуализируйте скачанные страницы сайта. В качестве значений по осям возьмите количество слов на странице и количество ссылок на ней. Цветом обозначьте принадлежность выбранной вами категории.

# %% [markdown]
# Поскольку это невозможно с нашей нынешней реализацией, то перепишем функции и снова запарсим.

# %%
import time
def load_web_pages(seed, max_downloads, url_filtration,
                   soft_html_filtration, hard_html_filtration):    
    # Создаём список со страницами
    pages_json = []
    
    # Создаём очередь для обхода в ширину
    q = Queue()
    q.put((seed, 0))

    already_visited = set()
    n_downloads = 0
    time_start = time.time()

    while not q.empty():
        # Нормализуем урл
        url, depth = q.get()
        try:
            main_url = url_normalize(url)
            if main_url in already_visited:
                continue
            already_visited.add(main_url)
            start = time.time()
            html = download_from_the_internet(main_url)
            end = time.time()
            # Извлекаем ссылки из страницы
            children_links = extract_links_from_html(main_url, html)
            time.sleep(1)

            # Извлекаем текст страницы
            text_info = extract_text_info_from_html(html) 

            # Добавляем запись в таблицу
            text_info['url'] = main_url
            text_info['depth'] = depth
            text_info['links'] = len(children_links)
            text_info['time'] = end - start
            hardOK = hard_html_filtration(text_info)
            softOK = soft_html_filtration(text_info)
            if ((not hardOK) and (not softOK)):
                continue
            '''В этом месте я хотел if (hardOK) -> pages.append(...),
            но будущие задания требуют всех данных, так что ничего.'''
            pages_json.append(text_info)
            print(f"Status {n_downloads},\nPage: {main_url}\nAdded: {hardOK}\n")
        
            n_downloads += 1
            if n_downloads > max_downloads:
                break
            
            # Добавляем ещё не посещённые ссылки в очередь
            for child in children_links:
                if (url_normalize(child) not in already_visited)\
                        and url_filtration(child):
                    q.put((child, depth + 1))
        except Exception as ex:
            print(f"-------EXCEPTION-------\n{ex}\n")
            continue
    return pages_json

# %%
raise Exception("Do not launch")

MAX_DOWNLOADS = 500
SEED = "https://en.wikipedia.org/wiki/War"

df = pd.DataFrame(load_web_pages(SEED, MAX_DOWNLOADS, url_filter,
                                    soft_html_filter, hard_html_filter))
df.head(5)
# Out:
# Status 0,
# Page: https://en.wikipedia.org/wiki/War
# Added: True
#
# Status 1,
# Page: https://en.wikipedia.org/wiki/Conflict_Zone
# Added: False
#
# Status 2,
# Page: https://en.wikipedia.org/wiki/Stele_of_the_Vultures
# Added: False
#
# Status 3,
# Page: https://en.wikipedia.org/wiki/Battle_of_Hastings
# Added: False
#
# Status 4,
# Page: https://en.wikipedia.org/wiki/Retreat_from_Moscow
# Added: False
#
# Status 5,
# Page: https://en.wikipedia.org/wiki/Battle_of_the_Somme
# Added: False
#
# Status 6,
# Page: https://en.wikipedia.org/wiki/Normandy_landings
# Added: False
#
# Status 7,
# Page: https://en.wikipedia.org/wiki/Nuclear_weapon
# Added: False
#
# Status 8,
# Page: https://en.wikipedia.org/wiki/Military_history
# Added: False
#
# Status 9,
# Page: https://en.wikipedia.org/wiki/Prehistoric_warfare
# Added: False
#
# Status 10,
# Page: https://en.wikipedia.org/wiki/Ancient_warfare
# Added: False
#
# Status 11,
# Page: https://en.wikipedia.org/wiki/Medieval_warfare
# Added: True
#
# Status 12,
# Page: https://en.wikipedia.org/wiki/Early_modern_warfare
# Added: True
#
# Status 13,
# Page: https://en.wikipedia.org/wiki/Modern_warfare
# Added: True
#
# Status 14,
# Page: https://en.wikipedia.org/wiki/Industrial_warfare
# Added: True
#
# Status 15,
# Page: https://en.wikipedia.org/wiki/Fourth-generation_warfare
# Added: True
#
# Status 16,
# Page: https://en.wikipedia.org/wiki/Battlespace
# Added: False
#
# Status 17,
# Page: https://en.wikipedia.org/wiki/Aerial_warfare
# Added: False
#
# Status 18,
# Page: https://en.wikipedia.org/wiki/Airborne_forces
# Added: False
#
# Status 19,
# Page: https://en.wikipedia.org/wiki/Space_warfare
# Added: True
#
# Status 20,
# Page: https://en.wikipedia.org/wiki/Ground_warfare
# Added: False
#
# Status 21,
# Page: https://en.wikipedia.org/wiki/Cold-weather_warfare
# Added: True
#
# Status 22,
# Page: https://en.wikipedia.org/wiki/Desert_warfare
# Added: False
#
# Status 23,
# Page: https://en.wikipedia.org/wiki/Jungle_warfare
# Added: False
#
# Status 24,
# Page: https://en.wikipedia.org/wiki/Mountain_warfare
# Added: True
#
# Status 25,
# Page: https://en.wikipedia.org/wiki/Urban_warfare
# Added: True
#
# Status 26,
# Page: https://en.wikipedia.org/wiki/Naval_warfare
# Added: True
#
# Status 27,
# Page: https://en.wikipedia.org/wiki/Amphibious_warfare
# Added: True
#
# Status 28,
# Page: https://en.wikipedia.org/wiki/Blue-water_navy
# Added: False
#
# Status 29,
# Page: https://en.wikipedia.org/wiki/Brown-water_navy
# Added: False
#
# Status 30,
# Page: https://en.wikipedia.org/wiki/Green-water_navy
# Added: False
#
# Status 31,
# Page: https://en.wikipedia.org/wiki/Surface_warfare
# Added: False
#
# Status 32,
# Page: https://en.wikipedia.org/wiki/Underwater_warfare
# Added: True
#
# Status 33,
# Page: https://en.wikipedia.org/wiki/Subterranean_warfare
# Added: False
#
# Status 34,
# Page: https://en.wikipedia.org/wiki/Tunnel_warfare
# Added: True
#
# Status 35,
# Page: https://en.wikipedia.org/wiki/Cyberwarfare
# Added: True
#
# Status 36,
# Page: https://en.wikipedia.org/wiki/Information_warfare
# Added: True
#
# Status 37,
# Page: https://en.wikipedia.org/wiki/Weapon
# Added: False
#
# Status 38,
# Page: https://en.wikipedia.org/wiki/Armoured_warfare
# Added: True
#
# Status 39,
# Page: https://en.wikipedia.org/wiki/Artillery
# Added: False
#
# Status 40,
# Page: https://en.wikipedia.org/wiki/Biological_warfare
# Added: True
#
# Status 41,
# Page: https://en.wikipedia.org/wiki/Military_camouflage
# Added: False
#
# Status 42,
# Page: https://en.wikipedia.org/wiki/Cavalry
# Added: False
#
# Status 43,
# Page: https://en.wikipedia.org/wiki/Chemical_warfare
# Added: True
#
# Status 44,
# Page: https://en.wikipedia.org/wiki/Class_conflict
# Added: False
#
# Status 45,
# Page: https://en.wikipedia.org/wiki/Combined_arms
# Added: False
#
# Status 46,
# Page: https://en.wikipedia.org/wiki/Conventional_warfare
# Added: True
#
# Status 47,
# Page: https://en.wikipedia.org/wiki/Cyberweapon
# Added: False
#
# Status 48,
# Page: https://en.wikipedia.org/wiki/Area_denial_weapon
# Added: False
#
# Status 49,
# Page: https://en.wikipedia.org/wiki/Disinformation
# Added: False
#
# Status 50,
# Page: https://en.wikipedia.org/wiki/Drone_strike
# Added: False
#
# Status 51,
# Page: https://en.wikipedia.org/wiki/Electronic_warfare
# Added: True
#
# Status 52,
# Page: https://en.wikipedia.org/wiki/Infantry
# Added: False
#
# Status 53,
# Page: https://en.wikipedia.org/wiki/Lawfare
# Added: False
#
# Status 54,
# Page: https://en.wikipedia.org/wiki/Loitering_munition
# Added: False
#
# Status 55,
# Page: https://en.wikipedia.org/wiki/Martial_music
# Added: False
#
# Status 56,
# Page: https://en.wikipedia.org/wiki/Nuclear_warfare
# Added: True
#
# Status 57,
# Page: https://en.wikipedia.org/wiki/Psychological_warfare
# Added: True
#
# Status 58,
# Page: https://en.wikipedia.org/wiki/Unconventional_warfare
# Added: False
#
# Status 59,
# Page: https://en.wikipedia.org/wiki/Military_tactics
# Added: False
#
# Status 60,
# Page: https://en.wikipedia.org/wiki/List_of_military_tactics
# Added: False
#
# Status 61,
# Page: https://en.wikipedia.org/wiki/Air_combat_manoeuvring
# Added: False
#
# Status 62,
# Page: https://en.wikipedia.org/wiki/Battle
# Added: False
#
# Status 63,
# Page: https://en.wikipedia.org/wiki/Cavalry_tactics
# Added: False
#
# Status 64,
# Page: https://en.wikipedia.org/wiki/Counterattack
# Added: False
#
# Status 65,
# Page: https://en.wikipedia.org/wiki/Counterinsurgency
# Added: False
#
# Status 66,
# Page: https://en.wikipedia.org/wiki/Defeat_in_detail
# Added: False
#
# Status 67,
# Page: https://en.wikipedia.org/wiki/Defensive_fighting_position
# Added: False
#
# Status 68,
# Page: https://en.wikipedia.org/wiki/Envelopment
# Added: False
#
# Status 69,
# Page: https://en.wikipedia.org/wiki/Guerrilla_warfare
# Added: True
#
# Status 70,
# Page: https://en.wikipedia.org/wiki/Morale
# Added: False
#
# Status 71,
# Page: https://en.wikipedia.org/wiki/Shock_and_awe
# Added: False
#
# Status 72,
# Page: https://en.wikipedia.org/wiki/Siege
# Added: False
#
# Status 73,
# Page: https://en.wikipedia.org/wiki/Tactical_objective
# Added: False
#
# Status 74,
# Page: https://en.wikipedia.org/wiki/Saturation_attack
# Added: False
#
# Status 75,
# Page: https://en.wikipedia.org/wiki/Trench_warfare
# Added: True
#
# Status 76,
# Page: https://en.wikipedia.org/wiki/Operational_level_of_war
# Added: True
#
# Status 77,
# Page: https://en.wikipedia.org/wiki/Blitzkrieg
# Added: False
#
# Status 78,
# Page: https://en.wikipedia.org/wiki/Expeditionary_warfare
# Added: True
#
# Status 79,
# Page: https://en.wikipedia.org/wiki/Deep_operation
# Added: False
#
# Status 80,
# Page: https://en.wikipedia.org/wiki/Maneuver_warfare
# Added: True
#
# Status 81,
# Page: https://en.wikipedia.org/wiki/Operational_manoeuvre_group
# Added: False
#
# Status 82,
# Page: https://en.wikipedia.org/wiki/Military_strategy
# Added: False
#
# Status 83,
# Page: https://en.wikipedia.org/wiki/List_of_military_strategies_and_concepts
# Added: False
#
# Status 84,
# Page: https://en.wikipedia.org/wiki/Attrition_warfare
# Added: True
#
# Status 85,
# Page: https://en.wikipedia.org/wiki/Counter-offensive
# Added: False
#
# Status 86,
# Page: https://en.wikipedia.org/wiki/Culminating_point
# Added: False
#
# Status 87,
# Page: https://en.wikipedia.org/wiki/Defence_in_depth
# Added: False
#
# Status 88,
# Page: https://en.wikipedia.org/wiki/Fabian_strategy
# Added: False
#
# Status 89,
# Page: https://en.wikipedia.org/wiki/Mosaic_Warfare
# Added: False
#
# Status 90,
# Page: https://en.wikipedia.org/wiki/Military_deception
# Added: False
#
# Status 91,
# Page: https://en.wikipedia.org/wiki/Strategic_defence
# Added: False
#
# Status 92,
# Page: https://en.wikipedia.org/wiki/Strategic_depth
# Added: False
#
# Status 93,
# Page: https://en.wikipedia.org/wiki/Naval_strategy
# Added: False
#
# Status 94,
# Page: https://en.wikipedia.org/wiki/Scorched_earth
# Added: False
#
# Status 95,
# Page: https://en.wikipedia.org/wiki/Grand_strategy
# Added: False
#
# Status 96,
# Page: https://en.wikipedia.org/wiki/Containment
# Added: False
#
# Status 97,
# Page: https://en.wikipedia.org/wiki/Economic_warfare
# Added: False
#
# Status 98,
# Page: https://en.wikipedia.org/wiki/Limited_war
# Added: True
#
# Status 99,
# Page: https://en.wikipedia.org/wiki/Philosophy_of_war
# Added: True
#
# Status 100,
# Page: https://en.wikipedia.org/wiki/Political_warfare
# Added: True
#
# Status 101,
# Page: https://en.wikipedia.org/wiki/Religious_war
# Added: False
#
# Status 102,
# Page: https://en.wikipedia.org/wiki/Strategic_studies
# Added: False
#
# Status 103,
# Page: https://en.wikipedia.org/wiki/Military_technology
# Added: False
#
# Status 104,
# Page: https://en.wikipedia.org/wiki/Total_war
# Added: True
#
# Status 105,
# Page: https://en.wikipedia.org/wiki/Military_administration
# Added: False
# Status 106,
# Page: https://en.wikipedia.org/wiki/Military_branch
# Added: False
#
# Status 107,
# Page: https://en.wikipedia.org/wiki/Military_policy
# Added: False
#
# Status 108,
# Page: https://en.wikipedia.org/wiki/Military_education_and_training
# Added: False
#
# Status 109,
# Page: https://en.wikipedia.org/wiki/Military_service
# Added: False
#
# Status 110,
# Page: https://en.wikipedia.org/wiki/Military_sociology
# Added: False
#
# Status 111,
# Page: https://en.wikipedia.org/wiki/Military_organization
# Added: False
#
# Status 112,
# Page: https://en.wikipedia.org/wiki/Command_hierarchy
# Added: False
#
# Status 113,
# Page: https://en.wikipedia.org/wiki/Command_and_control
# Added: False
#
# Status 114,
# Page: https://en.wikipedia.org/wiki/Military_doctrine
# Added: False
#
# Status 115,
# Page: https://en.wikipedia.org/wiki/Military_engineering
# Added: False
#
# Status 116,
# Page: https://en.wikipedia.org/wiki/Military_intelligence
# Added: False
#
# Status 117,
# Page: https://en.wikipedia.org/wiki/Military_rank
# Added: False
#
# Status 118,
# Page: https://en.wikipedia.org/wiki/Military_personnel
# Added: False
#
# Status 119,
# Page: https://en.wikipedia.org/wiki/Military_recruitment
# Added: False
#
# Status 120,
# Page: https://en.wikipedia.org/wiki/Conscription
# Added: False
#
# Status 121,
# Page: https://en.wikipedia.org/wiki/Recruit_training
# Added: False
#
# Status 122,
# Page: https://en.wikipedia.org/wiki/Military_specialism
# Added: False
#
# Status 123,
# Page: https://en.wikipedia.org/wiki/Women_in_the_military
# Added: False
#
# Status 124,
# Page: https://en.wikipedia.org/wiki/Children_in_the_military
# Added: False
#
# Status 125,
# Page: https://en.wikipedia.org/wiki/Transgender_people_and_military_service
# Added: False
#
# Status 126,
# Page: https://en.wikipedia.org/wiki/Sexual_harassment_in_the_military
# Added: False
#
# Status 127,
# Page: https://en.wikipedia.org/wiki/Conscientious_objector
# Added: False
#
# Status 128,
# Page: https://en.wikipedia.org/wiki/Counter-recruitment
# Added: False
#
# Status 129,
# Page: https://en.wikipedia.org/wiki/Military_logistics
# Added: False
#
# Status 130,
# Page: https://en.wikipedia.org/wiki/Arms_industry
# Added: False
#
# Status 131,
# Page: https://en.wikipedia.org/wiki/Materiel
# Added: False
#
# Status 132,
# Page: https://en.wikipedia.org/wiki/Military_supply-chain_management
# Added: False
#
# Status 133,
# Page: https://en.wikipedia.org/wiki/Main_operating_base
# Added: False
#
# Status 134,
# Page: https://en.wikipedia.org/wiki/Forward_operating_base
# Added: False
#
# Status 135,
# Page: https://en.wikipedia.org/wiki/Military_science
# Added: False
#
# Status 136,
# Page: https://en.wikipedia.org/wiki/Power_projection
# Added: False
#
# Status 137,
# Page: https://en.wikipedia.org/wiki/Loss_of_Strength_Gradient
# Added: False
#
# Status 138,
# Page: https://en.wikipedia.org/wiki/Law_of_war
# Added: False
#
# Status 139,
# Page: https://en.wikipedia.org/wiki/Court-martial
# Added: False
#
# Status 140,
# Page: https://en.wikipedia.org/wiki/Military_justice
# Added: False
#
# Status 141,
# Page: https://en.wikipedia.org/wiki/Perfidy
# Added: False
#
# Status 142,
# Page: https://en.wikipedia.org/wiki/Martial_law
# Added: False
#
# Status 143,
# Page: https://en.wikipedia.org/wiki/War_crime
# Added: True
#
# Status 144,
# Page: https://en.wikipedia.org/wiki/Military_theory
# Added: False
#
# Status 145,
# Page: https://en.wikipedia.org/wiki/Air_supremacy
# Added: False
#
# Status 146,
# Page: https://en.wikipedia.org/wiki/Full-spectrum_dominance
# Added: False
#
# Status 147,
# Page: https://en.wikipedia.org/wiki/Overmatch
# Added: False
#
# Status 148,
# Page: https://en.wikipedia.org/wiki/Asymmetric_warfare
# Added: False
#
# Status 149,
# Page: https://en.wikipedia.org/wiki/Broken-backed_war_theory
# Added: False
#
# Status 150,
# Page: https://en.wikipedia.org/wiki/Horses_in_warfare
# Added: True
#
# Status 151,
# Page: https://en.wikipedia.org/wiki/Irregular_warfare
# Added: False
#
# Status 152,
# Page: https://en.wikipedia.org/wiki/Just_war_theory
# Added: True
#
# Status 153,
# Page: https://en.wikipedia.org/wiki/Mercenary
# Added: False
#
# -------EXCEPTION-------
# encoding with 'idna' codec failed (UnicodeError: label empty or too long)
#
# Status 154,
# Page: https://en.wikipedia.org/wiki/Military_campaign
# Added: False
#
# Status 155,
# Page: https://en.wikipedia.org/wiki/Military_operation
# Added: False
#
# Status 156,
# Page: https://en.wikipedia.org/wiki/Network-centric_warfare
# Added: False
#
# Status 157,
# Page: https://en.wikipedia.org/wiki/Operations_research
# Added: False
#
# Status 158,
# Page: https://en.wikipedia.org/wiki/Perpetual_war
# Added: False
#
# Status 159,
# Page: https://en.wikipedia.org/wiki/Principles_of_war
# Added: True
#
# Status 160,
# Page: https://en.wikipedia.org/wiki/Proxy_war
# Added: False
#
# Status 161,
# Page: https://en.wikipedia.org/wiki/Security_dilemma
# Added: False
#
# Status 162,
# Page: https://en.wikipedia.org/wiki/Tripwire_force
# Added: False
#
# Status 163,
# Page: https://en.wikipedia.org/wiki/War_film
# Added: True
#
# Status 164,
# Page: https://en.wikipedia.org/wiki/Military_exercise
# Added: False
#
# Status 165,
# Page: https://en.wikipedia.org/wiki/War_novel
# Added: True
#
# Status 166,
# Page: https://en.wikipedia.org/wiki/Wartime_sexual_violence
# Added: True
#
# Status 167,
# Page: https://en.wikipedia.org/wiki/Women_in_war
# Added: False
#
# Status 168,
# Page: https://en.wikipedia.org/wiki/World_war
# Added: True
#
# Status 169,
# Page: https://en.wikipedia.org/wiki/Colonial_war
# Added: True
#
# Status 170,
# Page: https://en.wikipedia.org/wiki/Endemic_warfare
# Added: False
#
# Status 171,
# Page: https://en.wikipedia.org/wiki/Category:Military_lists
# Added: False
#
# Status 172,
# Page: https://en.wikipedia.org/wiki/Lists_of_battles
# Added: False
#
# Status 173,
# Page: https://en.wikipedia.org/wiki/List_of_military_occupations
# Added: False
#
# Status 174,
# Page: https://en.wikipedia.org/wiki/List_of_military_operations
# Added: False
#
# Status 175,
# Page: https://en.wikipedia.org/wiki/List_of_sieges
# Added: False
#
# Status 176,
# Page: https://en.wikipedia.org/wiki/List_of_war_crimes
# Added: True
#
# Status 177,
# Page: https://en.wikipedia.org/wiki/Lists_of_weapons
# Added: False
#
# Status 178,
# Page: https://en.wikipedia.org/wiki/List_of_military_writers
# Added: False
#
# Status 179,
# Page: https://en.wikipedia.org/wiki/Template:War
# Added: False
#
# Status 180,
# Page: https://en.wikipedia.org/wiki/Template_talk:War
# Added: False
#
# Status 181,
# Page: https://en.wikipedia.org/wiki/Government
# Added: False
#
# Status 182,
# Page: https://en.wikipedia.org/wiki/Society
# Added: False
#
# Status 183,
# Page: https://en.wikipedia.org/wiki/Paramilitary
# Added: False
#
# Status 184,
# Page: https://en.wikipedia.org/wiki/Insurgency
# Added: False
#
# Status 185,
# Page: https://en.wikipedia.org/wiki/Militia
# Added: False
#
# Status 186,
# Page: https://en.wikipedia.org/wiki/Violence
# Added: False
#
# Status 187,
# Page: https://en.wikipedia.org/wiki/Aggression
# Added: False
#
# Status 188,
# Page: https://en.wikipedia.org/wiki/Regular_army
# Added: False
#
# Status 189,
# Page: https://en.wikipedia.org/wiki/Irregular_military
# Added: False
#
# Status 190,
# Page: https://en.wikipedia.org/wiki/Military_forces
# Added: False
#
# Status 191,
# Page: https://en.wikipedia.org/wiki/Legitimate_military_target
# Added: False
#
# Status 192,
# Page: https://en.wikipedia.org/wiki/Civilian_casualties
# Added: False
#
# Status 193,
# Page: https://en.wikipedia.org/wiki/Non-combatant
# Added: False
#
# Status 194,
# Page: https://en.wikipedia.org/wiki/War_studies
# Added: False
#
# Status 195,
# Page: https://en.wikipedia.org/wiki/Human_nature
# Added: False
#
# Status 196,
# Page: https://en.wikipedia.org/wiki/Old_English
# Added: False
#
# Status 197,
# Page: https://en.wikipedia.org/wiki/Franks
# Added: False
#
# Status 198,
# Page: https://en.wikipedia.org/wiki/Proto-Germanic_language
# Added: False
#
# Status 199,
# Page: https://en.wikipedia.org/wiki/Siege_of_Dapur
# Added: False
#
# Status 200,
# Page: https://en.wikipedia.org/wiki/Ramesseum
# Added: False
#
# Status 201,
# Page: https://en.wikipedia.org/wiki/Thebes,_Egypt
# Added: False
#
# Status 202,
# Page: https://en.wikipedia.org/wiki/Mesolithic
# Added: False
#
# Status 203,
# Page: https://en.wikipedia.org/wiki/Jebel_Sahaba
# Added: False
#
# Status 204,
# Page: https://en.wikipedia.org/wiki/Gunpowder
# Added: False
#
# Status 205,
# Page: https://en.wikipedia.org/wiki/War_Before_Civilization
# Added: True
#
# Status 206,
# Page: https://en.wikipedia.org/wiki/Samurai
# Added: False
#
# Status 207,
# Page: https://en.wikipedia.org/wiki/Mongol_Empire
# Added: False
#
# Status 208,
# Page: https://en.wikipedia.org/wiki/Winter_War
# Added: True
# Status 209,
# Page: https://en.wikipedia.org/wiki/Atom_bomb
# Added: False
#
# Status 210,
# Page: https://en.wikipedia.org/wiki/Albert_Einstein
# Added: False
#
# Status 211,
# Page: https://en.wikipedia.org/wiki/Mao_Zedong
# Added: False
#
# Status 212,
# Page: https://en.wikipedia.org/wiki/Nuclear_war
# Added: True
#
# Status 213,
# Page: https://en.wikipedia.org/wiki/Indo-Pakistani_War_of_1971
# Added: True
#
# Status 214,
# Page: https://en.wikipedia.org/wiki/Gulf_War
# Added: True
#
# Status 215,
# Page: https://en.wikipedia.org/wiki/Human_Security_Report_2005
# Added: False
#
# Status 216,
# Page: https://en.wikipedia.org/wiki/Cold_War
# Added: True
#
# Status 217,
# Page: https://en.wikipedia.org/wiki/Australian_4th_Division
# Added: False
#
# Status 218,
# Page: https://en.wikipedia.org/wiki/Chemical_weapons_in_World_War_I
# Added: True
#
# Status 219,
# Page: https://en.wikipedia.org/wiki/Third_Battle_of_Ypres
# Added: False
#
# Status 220,
# Page: https://en.wikipedia.org/wiki/Belligerent
# Added: False
#
# Status 221,
# Page: https://en.wikipedia.org/wiki/World_War_I
# Added: True
#
# Status 222,
# Page: https://en.wikipedia.org/wiki/Cold_warfare
# Added: True
#
# Status 223,
# Page: https://en.wikipedia.org/wiki/Covert_operation
# Added: False
#
# Status 224,
# Page: https://en.wikipedia.org/wiki/Espionage
# Added: False
#
# Status 225,
# Page: https://en.wikipedia.org/wiki/Biological_weapon
# Added: False
#
# Status 226,
# Page: https://en.wikipedia.org/wiki/Chemical_weapons
# Added: False
#
# Status 227,
# Page: https://en.wikipedia.org/wiki/Computer
# Added: False
#
# Status 228,
# Page: https://en.wikipedia.org/wiki/Computer_network
# Added: False
#
# Status 229,
# Page: https://en.wikipedia.org/wiki/Laws_of_war
# Added: False
#
# Status 230,
# Page: https://en.wikipedia.org/wiki/War_effort
# Added: True
#
# Status 231,
# Page: https://en.wikipedia.org/wiki/Lebensraum
# Added: False
#
# Status 232,
# Page: https://en.wikipedia.org/wiki/Anglo-Dutch_Wars
# Added: True
#
# Status 233,
# Page: https://en.wikipedia.org/wiki/Effects_of_war
# Added: True
#
# Status 234,
# Page: https://en.wikipedia.org/wiki/World_War_II
# Added: True
#
# Status 235,
# Page: https://en.wikipedia.org/wiki/List_of_wars_by_death_toll
# Added: True
#
# Status 236,
# Page: https://en.wikipedia.org/wiki/Casualty_recording
# Added: False
#
# Status 237,
# Page: https://en.wikipedia.org/wiki/Mongol_conquests
# Added: False
#
# Status 238,
# Page: https://en.wikipedia.org/wiki/Modern_history
# Added: False
#
# Status 239,
# Page: https://en.wikipedia.org/wiki/Paraguayan_War
# Added: False
#
# Status 240,
# Page: https://en.wikipedia.org/wiki/Paraguayan_War_casualties
# Added: False
#
# Status 241,
# Page: https://en.wikipedia.org/wiki/Famine
# Added: False
#
# Status 242,
# Page: https://en.wikipedia.org/wiki/Prisoner_of_war
# Added: True
#
# Status 243,
# Page: https://en.wikipedia.org/wiki/Byelorussian_Soviet_Socialist_Republic
# Added: False
#
# Status 244,
# Page: https://en.wikipedia.org/wiki/Propaganda
# Added: False
#
# Status 245,
# Page: https://en.wikipedia.org/wiki/Weapons_manufacturers
# Added: False
#
# Status 246,
# Page: https://en.wikipedia.org/wiki/Second_Sino-Japanese_War
# Added: True
#
# Status 247,
# Page: https://en.wikipedia.org/wiki/World_War_II_casualties
# Added: True
#
# Status 248,
# Page: https://en.wikipedia.org/wiki/Tatar_invasions
# Added: False
#
# Status 249,
# Page: https://en.wikipedia.org/wiki/Taiping_Rebellion
# Added: False
#
# Status 250,
# Page: https://en.wikipedia.org/wiki/World_War_I_casualties
# Added: True
#
# Status 251,
# Page: https://en.wikipedia.org/wiki/An_Lushan_Rebellion
# Added: False
#
# Status 252,
# Page: https://en.wikipedia.org/wiki/Qing_dynasty
# Added: False
#
# Status 253,
# Page: https://en.wikipedia.org/wiki/Ming_dynasty
# Added: False
#
# Status 254,
# Page: https://en.wikipedia.org/wiki/Tamerlane
# Added: False
#
# Status 255,
# Page: https://en.wikipedia.org/wiki/Russian_Civil_War
# Added: True
#
# Status 256,
# Page: https://en.wikipedia.org/wiki/Allied_intervention_in_the_Russian_Civil_War
# Added: True
#
# Status 257,
# Page: https://en.wikipedia.org/wiki/Posttraumatic_stress_disorder
# Added: False
#
# Status 258,
# Page: https://en.wikipedia.org/wiki/US_Army
# Added: False
#
# Status 259,
# Page: https://en.wikipedia.org/wiki/S.L.A._Marshall
# Added: False
#
# Status 260,
# Page: https://en.wikipedia.org/wiki/The_Apotheosis_of_War
# Added: True
#
# Status 261,
# Page: https://en.wikipedia.org/wiki/Vasily_Vereshchagin
# Added: False
#
# Status 262,
# Page: https://en.wikipedia.org/wiki/American_Civil_War
# Added: True
#
# Status 263,
# Page: https://en.wikipedia.org/wiki/United_States_military_casualties_of_war
# Added: True
#
# Status 264,
# Page: https://en.wikipedia.org/wiki/Crow_Indians
# Added: False
#
# Status 265,
# Page: https://en.wikipedia.org/wiki/Napoleon_I_of_France
# Added: False
#
# Status 266,
# Page: https://en.wikipedia.org/wiki/Typhus
# Added: False
#
# Status 267,
# Page: https://en.wikipedia.org/wiki/Royal_Navy
# Added: False
#
# Status 268,
# Page: https://en.wikipedia.org/wiki/Civilian
# Added: False
#
# Status 269,
# Page: https://en.wikipedia.org/wiki/Population
# Added: False
#
# Status 270,
# Page: https://en.wikipedia.org/wiki/Holy_Roman_Empire
# Added: False
#
# Status 271,
# Page: https://en.wikipedia.org/wiki/Genocide
# Added: False
#
# Status 272,
# Page: https://en.wikipedia.org/wiki/Infant_mortality
# Added: False
#
# Status 273,
# Page: https://en.wikipedia.org/wiki/Malnutrition
# Added: False
#
# Status 274,
# Page: https://en.wikipedia.org/wiki/Drinking_water
# Added: False
#
# Status 275,
# Page: https://en.wikipedia.org/wiki/Soviet_Union
# Added: False
#
# Status 276,
# Page: https://en.wikipedia.org/wiki/World_War_II_casualties_of_the_Soviet_Union
# Added: True
#
# Status 277,
# Page: https://en.wikipedia.org/wiki/Military_Keynesianism
# Added: False
#
# Status 278,
# Page: https://en.wikipedia.org/wiki/War_reparations
# Added: True
#
# Status 279,
# Page: https://en.wikipedia.org/wiki/Alsace-Lorraine
# Added: False
#
# Status 280,
# Page: https://en.wikipedia.org/wiki/Great_Depression
# Added: False
#
# Status 281,
# Page: https://en.wikipedia.org/wiki/Keynesian
# Added: False
#
# Status 282,
# Page: https://en.wikipedia.org/wiki/Franco-Prussian_War
# Added: True
#
# Status 283,
# Page: https://en.wikipedia.org/wiki/Russian_Revolution_of_1917
# Added: False
#
# Status 284,
# Page: https://en.wikipedia.org/wiki/Warsaw
# Added: True
#
# Status 285,
# Page: https://en.wikipedia.org/wiki/International_relations_theory
# Added: False
#
# Status 286,
# Page: https://en.wikipedia.org/wiki/List_of_campaigns_of_Suleiman_the_Magnificent
# Added: False
#
# Status 287,
# Page: https://en.wikipedia.org/wiki/Ottoman_wars_in_Europe
# Added: True
#
# Status 288,
# Page: https://en.wikipedia.org/wiki/Carl_von_Clausewitz
# Added: False
#
# Status 289,
# Page: https://en.wikipedia.org/wiki/Psychoanalyst
# Added: False
#
# Status 290,
# Page: https://en.wikipedia.org/wiki/Joost_Meerloo
# Added: False
#
# Status 291,
# Page: https://en.wikipedia.org/wiki/John_Bowlby
# Added: False
#
# Status 292,
# Page: https://en.wikipedia.org/wiki/Inheritance
# Added: False
#
# Status 293,
# Page: https://en.wikipedia.org/wiki/Psychological_projection
# Added: False
#
# Status 294,
# Page: https://en.wikipedia.org/wiki/Ideology
# Added: False
#
# Status 295,
# Page: https://en.wikipedia.org/wiki/Melanie_Klein
# Added: False
#
# Status 296,
# Page: https://en.wikipedia.org/wiki/Adolf_Hitler
# Added: False
#
# Status 297,
# Page: https://en.wikipedia.org/wiki/Battle_of_Schwaderloh
# Added: False
#
# Status 298,
# Page: https://en.wikipedia.org/wiki/Luzerner_Schilling
# Added: False
#
# Status 299,
# Page: https://en.wikipedia.org/wiki/Competition
# Added: False
#
# Status 300,
# Page: https://en.wikipedia.org/wiki/Common_chimpanzee
# Added: False
#
# Status 301,
# Page: https://en.wikipedia.org/wiki/Ant
# Added: False
#
# Status 302,
# Page: https://en.wikipedia.org/wiki/Steven_Pinker
# Added: False
#
# Status 303,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Verifiability
# Added: False
#
# Status 304,
# Page: https://en.wikipedia.org/wiki/Deterrence_theory
# Added: False
#
# Status 305,
# Page: https://en.wikipedia.org/wiki/Revenge
# Added: False
#
# Status 306,
# Page: https://en.wikipedia.org/wiki/Honor
# Added: False
#
# Status 307,
# Page: https://en.wikipedia.org/wiki/Maya_warfare
# Added: False
#
# Status 308,
# Page: https://en.wikipedia.org/wiki/Classic_Maya_collapse
# Added: False
#
# Status 309,
# Page: https://en.wikipedia.org/wiki/Maya_civilization
# Added: False
#
# Status 310,
# Page: https://en.wikipedia.org/wiki/Ashley_Montagu
# Added: False
#
# Status 311,
# Page: https://en.wikipedia.org/wiki/Semai_people
# Added: False
#
# Status 312,
# Page: https://en.wikipedia.org/wiki/Oil_well
# Added: False
# Status 313,
# Page: https://en.wikipedia.org/wiki/Natural_resource
# Added: False
#
# Status 314,
# Page: https://en.wikipedia.org/wiki/State-building
# Added: False
#
# Status 315,
# Page: https://en.wikipedia.org/wiki/Fiscal_capacity
# Added: False
#
# Status 316,
# Page: https://en.wikipedia.org/wiki/Presidents_of_the_United_States
# Added: False
#
# Status 317,
# Page: https://en.wikipedia.org/wiki/General_officer
# Added: False
#
# Status 318,
# Page: https://en.wikipedia.org/wiki/Marxist_explanations_of_warfare
# Added: True
#
# Status 319,
# Page: https://en.wikipedia.org/wiki/Marxism
# Added: False
#
# Status 320,
# Page: https://en.wikipedia.org/wiki/Imperialism
# Added: False
#
# Status 321,
# Page: https://en.wikipedia.org/wiki/Capitalism
# Added: False
#
# Status 322,
# Page: https://en.wikipedia.org/wiki/Karl_Kautsky
# Added: False
#
# Status 323,
# Page: https://en.wikipedia.org/wiki/Rosa_Luxemburg
# Added: False
#
# Status 324,
# Page: https://en.wikipedia.org/wiki/Rudolf_Hilferding
# Added: False
#
# Status 325,
# Page: https://en.wikipedia.org/wiki/Vladimir_Lenin
# Added: False
#
# Status 326,
# Page: https://en.wikipedia.org/wiki/Means_of_production
# Added: False
#
# Status 327,
# Page: https://en.wikipedia.org/wiki/Consumer_demand
# Added: False
#
# Status 328,
# Page: https://en.wikipedia.org/wiki/Capitalist_economy
# Added: False
#
# Status 329,
# Page: https://en.wikipedia.org/wiki/Unified_Task_Force
# Added: False
#
# Status 330,
# Page: https://en.wikipedia.org/wiki/Malthusian_catastrophe
# Added: False
#
# Status 331,
# Page: https://en.wikipedia.org/wiki/Pope_Urban_II
# Added: False
#
# Status 332,
# Page: https://en.wikipedia.org/wiki/First_Crusade
# Added: False
#
# Status 333,
# Page: https://en.wikipedia.org/wiki/Thomas_Malthus
# Added: False
#
# Status 334,
# Page: https://en.wikipedia.org/wiki/Mali
# Added: False
#
# Status 335,
# Page: https://en.wikipedia.org/wiki/Sudanese_nomadic_conflicts
# Added: False
#
# Status 336,
# Page: https://en.wikipedia.org/wiki/Sahel
# Added: False
#
# Status 337,
# Page: https://en.wikipedia.org/wiki/Land_degradation
# Added: False
#
# Status 338,
# Page: https://en.wikipedia.org/wiki/Population_pyramid
# Added: False
#
# Status 339,
# Page: https://en.wikipedia.org/wiki/Demographics_of_Africa
# Added: False
#
# Status 340,
# Page: https://en.wikipedia.org/wiki/Gunnar_Heinsohn
# Added: False
#
# Status 341,
# Page: https://en.wikipedia.org/wiki/Youth_bulge
# Added: False
#
# Status 342,
# Page: https://en.wikipedia.org/wiki/French_Revolution
# Added: False
#
# Status 343,
# Page: https://en.wikipedia.org/wiki/Nazism
# Added: False
#
# Status 344,
# Page: https://en.wikipedia.org/wiki/Rwandan_genocide
# Added: False
#
# Status 345,
# Page: https://en.wikipedia.org/wiki/Population_Action_International
# Added: False
#
# Status 346,
# Page: https://en.wikipedia.org/wiki/Game_theory
# Added: False
#
# Status 347,
# Page: https://en.wikipedia.org/wiki/Peace_war_game
# Added: False
#
# Status 348,
# Page: https://en.wikipedia.org/wiki/James_Fearon
# Added: False
#
# Status 349,
# Page: https://en.wikipedia.org/wiki/Information_asymmetry
# Added: False
#
# Status 350,
# Page: https://en.wikipedia.org/wiki/Geoffrey_Blainey
# Added: False
#
# Status 351,
# Page: https://en.wikipedia.org/wiki/Cognitive_bias
# Added: False
#
# Status 352,
# Page: https://en.wikipedia.org/wiki/Iain_King
# Added: False
#
# Status 353,
# Page: https://en.wikipedia.org/wiki/GroupThink
# Added: False
#
# Status 354,
# Page: https://en.wikipedia.org/wiki/Lewis_Fry_Richardson
# Added: False
#
# Status 355,
# Page: https://en.wikipedia.org/wiki/Correlates_of_War
# Added: False
#
# Status 356,
# Page: https://en.wikipedia.org/wiki/Uppsala_Conflict_Data_Program
# Added: False
#
# Status 357,
# Page: https://en.wikipedia.org/wiki/Kenneth_Waltz
# Added: False
#
# Status 358,
# Page: https://en.wikipedia.org/wiki/Man,_the_State,_and_War
# Added: False
#
# Status 359,
# Page: https://en.wikipedia.org/wiki/Realism_in_international_relations
# Added: False
#
# Status 360,
# Page: https://en.wikipedia.org/wiki/Henry_Kissinger
# Added: False
#
# Status 361,
# Page: https://en.wikipedia.org/wiki/Hans_Morgenthau
# Added: False
#
# Status 362,
# Page: https://en.wikipedia.org/wiki/John_Mearsheimer
# Added: False
#
# Status 363,
# Page: https://en.wikipedia.org/wiki/Power_transition_theory
# Added: False
#
# Status 364,
# Page: https://en.wikipedia.org/wiki/Diversionary_foreign_policy
# Added: False
#
# Status 365,
# Page: https://en.wikipedia.org/wiki/Realistic_conflict_theory
# Added: False
#
# Status 366,
# Page: https://en.wikipedia.org/wiki/Group_cohesiveness
# Added: False
#
# Status 367,
# Page: https://en.wikipedia.org/wiki/Bounded_rationality
# Added: False
#
# Status 368,
# Page: https://en.wikipedia.org/wiki/Cognitive_biases
# Added: False
#
# Status 369,
# Page: https://en.wikipedia.org/wiki/Prospect_theory
# Added: False
#
# Status 370,
# Page: https://en.wikipedia.org/wiki/Battle_of_Waterloo
# Added: False
#
# Status 371,
# Page: https://en.wikipedia.org/wiki/John_Heaviside_Clark
# Added: False
#
# Status 372,
# Page: https://en.wikipedia.org/wiki/Morality
# Added: False
#
# Status 373,
# Page: https://en.wikipedia.org/wiki/Jus_ad_bellum
# Added: False
#
# Status 374,
# Page: https://en.wikipedia.org/wiki/Jus_in_bello
# Added: False
#
# Status 375,
# Page: https://en.wikipedia.org/wiki/Leningrad
# Added: False
#
# Status 376,
# Page: https://en.wikipedia.org/wiki/General_Plan_East
# Added: False
#
# Status 377,
# Page: https://en.wikipedia.org/wiki/International_law
# Added: False
#
# Status 378,
# Page: https://en.wikipedia.org/wiki/Pragmatism
# Added: False
#
# Status 379,
# Page: https://en.wikipedia.org/wiki/Social_Darwinism
# Added: False
#
# Status 380,
# Page: https://en.wikipedia.org/wiki/Archetypes
# Added: False
#
# Status 381,
# Page: https://en.wikipedia.org/wiki/Anti-war_movement
# Added: True
#
# Status 382,
# Page: https://en.wikipedia.org/wiki/Second_Vatican_Council
# Added: False
#
# Status 383,
# Page: https://en.wikipedia.org/wiki/Vietnam_War
# Added: True
#
# Status 384,
# Page: https://en.wikipedia.org/wiki/Iraq_War
# Added: True
#
# Status 385,
# Page: https://en.wikipedia.org/wiki/Mexican_Drug_War
# Added: False
#
# Status 386,
# Page: https://en.wikipedia.org/wiki/Portal:War
# Added: True
#
# Status 387,
# Page: https://en.wikipedia.org/wiki/Outline_of_war
# Added: True
#
# Status 388,
# Page: https://en.wikipedia.org/wiki/International_Committee_of_the_Red_Cross
# Added: False
#
# Status 389,
# Page: https://en.wikipedia.org/wiki/Wayback_Machine
# Added: False
#
# Status 390,
# Page: https://en.wikipedia.org/wiki/Hugo_Haase
# Added: False
#
# Status 391,
# Page: https://en.wikipedia.org/wiki/Marc_Pilisuk
# Added: False
#
# Status 392,
# Page: https://en.wikipedia.org/wiki/The_New_York_Times
# Added: False
#
# Status 393,
# Page: https://en.wikipedia.org/wiki/Roger_Griffin
# Added: False
#
# Status 394,
# Page: https://en.wikipedia.org/wiki/Marxists_Internet_Archive
# Added: False
#
# Status 395,
# Page: https://en.wikipedia.org/wiki/Foreign_Policy
# Added: False
#
# Status 396,
# Page: https://en.wikipedia.org/wiki/Henrik_Urdal
# Added: False
#
# Status 397,
# Page: https://en.wikipedia.org/wiki/I.C.B._Dear
# Added: False
#
# Status 398,
# Page: https://en.wikipedia.org/wiki/M.R.D._Foot
# Added: False
#
# Status 399,
# Page: https://en.wikipedia.org/wiki/Template:Cite_book
# Added: False
#
# Status 400,
# Page: https://en.wikipedia.org/wiki/Smedley_Butler
# Added: False
#
# Status 401,
# Page: https://en.wikipedia.org/wiki/War_is_a_Racket
# Added: False
#
# Status 402,
# Page: https://en.wikipedia.org/wiki/John_Keegan
# Added: False
#
# Status 403,
# Page: https://en.wikipedia.org/wiki/A_History_of_Warfare
# Added: False
#
# Status 404,
# Page: https://en.wikipedia.org/wiki/Gabriel_Kolko
# Added: False
#
# Status 405,
# Page: https://en.wikipedia.org/wiki/The_New_Press
# Added: False
#
# Status 406,
# Page: https://en.wikipedia.org/wiki/Strategic_Studies_Institute
# Added: False
#
# Status 407,
# Page: https://en.wikipedia.org/wiki/United_States_Army_War_College
# Added: False
#
# Status 408,
# Page: https://en.wikipedia.org/wiki/Hew_Strachan
# Added: False
#
# Status 409,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Wikimedia_sister_projects
# Added: False
#
# Status 410,
# Page: https://en.wikipedia.org/wiki/Template:War_navbox
# Added: False
#
# Status 411,
# Page: https://en.wikipedia.org/wiki/Template_talk:War_navbox
# Added: False
#
# Status 412,
# Page: https://en.wikipedia.org/wiki/Category:Peace
# Added: False
#
# Status 413,
# Page: https://en.wikipedia.org/wiki/List_of_periods_of_regional_peace
# Added: False
#
# Status 414,
# Page: https://en.wikipedia.org/wiki/Category:Conflicts
# Added: False
#
# Status 415,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_military_conflicts
# Added: False
# Status 416,
# Page: https://en.wikipedia.org/wiki/Category:War
# Added: False
#
# Status 417,
# Page: https://en.wikipedia.org/wiki/Category:Civil_wars
# Added: False
#
# Status 418,
# Page: https://en.wikipedia.org/wiki/List_of_civil_wars
# Added: True
#
# Status 419,
# Page: https://en.wikipedia.org/wiki/Category:Attacks
# Added: False
#
# Status 420,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_attacks
# Added: False
#
# Status 421,
# Page: https://en.wikipedia.org/wiki/Category:Terrorism_by_form
# Added: False
#
# Status 422,
# Page: https://en.wikipedia.org/wiki/List_of_terrorist_incidents
# Added: False
#
# Status 423,
# Page: https://en.wikipedia.org/wiki/Category:Massacres
# Added: False
#
# Status 424,
# Page: https://en.wikipedia.org/wiki/List_of_events_named_massacres
# Added: False
#
# Status 425,
# Page: https://en.wikipedia.org/wiki/Category:Warfare
# Added: False
#
# Status 426,
# Page: https://en.wikipedia.org/wiki/Category:Battles
# Added: False
#
# Status 427,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_battles
# Added: False
#
# Status 428,
# Page: https://en.wikipedia.org/wiki/Category:Wars
# Added: False
#
# Status 429,
# Page: https://en.wikipedia.org/wiki/Category:Lists_of_wars
# Added: False
#
# Status 430,
# Page: https://en.wikipedia.org/wiki/Category:Ongoing_conflicts
# Added: False
#
# Status 431,
# Page: https://en.wikipedia.org/wiki/List_of_ongoing_armed_conflicts
# Added: False
#
# Status 432,
# Page: https://en.wikipedia.org/wiki/International_relations
# Added: False
#
# Status 433,
# Page: https://en.wikipedia.org/wiki/International_organization
# Added: False
#
# Status 434,
# Page: https://en.wikipedia.org/wiki/BRICS
# Added: False
#
# Status 435,
# Page: https://en.wikipedia.org/wiki/Collective_Security_Treaty_Organization
# Added: False
#
# Status 436,
# Page: https://en.wikipedia.org/wiki/International_Criminal_Court
# Added: False
#
# Status 437,
# Page: https://en.wikipedia.org/wiki/League_of_Nations
# Added: False
#
# Status 438,
# Page: https://en.wikipedia.org/wiki/Non-Aligned_Movement
# Added: False
#
# Status 439,
# Page: https://en.wikipedia.org/wiki/NATO
# Added: False
#
# Status 440,
# Page: https://en.wikipedia.org/wiki/Shanghai_Cooperation_Organisation
# Added: False
#
# Status 441,
# Page: https://en.wikipedia.org/wiki/United_Nations
# Added: False
#
# Status 442,
# Page: https://en.wikipedia.org/wiki/Warsaw_Pact
# Added: True
#
# Status 443,
# Page: https://en.wikipedia.org/wiki/Political_history_of_the_world
# Added: False
#
# Status 444,
# Page: https://en.wikipedia.org/wiki/Diplomatic_history_of_World_War_II
# Added: True
#
# Status 445,
# Page: https://en.wikipedia.org/wiki/International_relations_since_1989
# Added: False
#
# Status 446,
# Page: https://en.wikipedia.org/wiki/Appeasement
# Added: False
#
# Status 447,
# Page: https://en.wikipedia.org/wiki/Collective_security
# Added: False
#
# Status 448,
# Page: https://en.wikipedia.org/wiki/Colonialism
# Added: False
#
# Status 449,
# Page: https://en.wikipedia.org/wiki/Hegemony
# Added: False
#
# Status 450,
# Page: https://en.wikipedia.org/wiki/Idealism_in_international_relations
# Added: False
#
# Status 451,
# Page: https://en.wikipedia.org/wiki/Liberal_institutionalism
# Added: False
#
# Status 452,
# Page: https://en.wikipedia.org/wiki/Peace
# Added: False
#
# Status 453,
# Page: https://en.wikipedia.org/wiki/Sovereignty
# Added: False
#
# Status 454,
# Page: https://en.wikipedia.org/wiki/Suzerainty
# Added: False
#
# Status 455,
# Page: https://en.wikipedia.org/wiki/Treaty
# Added: False
#
# Status 456,
# Page: https://en.wikipedia.org/wiki/Marxist_international_relations_theory
# Added: False
#
# Status 457,
# Page: https://en.wikipedia.org/wiki/Diplomacy
# Added: False
#
# Status 458,
# Page: https://en.wikipedia.org/wiki/Geopolitics
# Added: False
#
# Status 459,
# Page: https://en.wikipedia.org/wiki/Help:Category
# Added: False
#
# Status 460,
# Page: https://en.wikipedia.org/wiki/Category:Dispute_resolution
# Added: False
#
# Status 461,
# Page: https://en.wikipedia.org/wiki/Category:Violence
# Added: False
#
# Status 462,
# Page: https://en.wikipedia.org/wiki/Category:CS1:_long_volume_value
# Added: False
#
# Status 463,
# Page: https://en.wikipedia.org/wiki/Category:CS1_errors:_missing_periodical
# Added: False
#
# Status 464,
# Page: https://en.wikipedia.org/wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# Added: False
#
# Status 465,
# Page: https://en.wikipedia.org/wiki/Category:Use_dmy_dates_from_October_2020
# Added: False
#
# Status 466,
# Page: https://en.wikipedia.org/wiki/Category:Use_American_English_from_October_2017
# Added: False
#
# Status 467,
# Page: https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_written_in_American_English
# Added: False
#
# Status 468,
# Page: https://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements
# Added: False
#
# Status 469,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_July_2016
# Added: False
#
# Status 470,
# Page: https://en.wikipedia.org/wiki/Category:All_articles_with_specifically_marked_weasel-worded_phrases
# Added: False
#
# Status 471,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_specifically_marked_weasel-worded_phrases_from_July_2016
# Added: False
#
# Status 472,
# Page: https://en.wikipedia.org/wiki/Category:All_articles_with_failed_verification
# Added: False
#
# Status 473,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_failed_verification_from_July_2016
# Added: False
#
# Status 474,
# Page: https://en.wikipedia.org/wiki/Category:Pages_using_Sister_project_links_with_hidden_wikidata
# Added: False
#
# Status 475,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_BNF_identifiers
# Added: False
#
# Status 476,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_LCCN_identifiers
# Added: False
#
# Status 477,
# Page: https://en.wikipedia.org/wiki/Category:Articles_with_FAST_identifiers
# Added: False
#
# Status 478,
# Page: https://en.wikipedia.org/wiki/Special:MyContributions
# Added: False
#
# Status 479,
# Page: https://en.wikipedia.org/wiki/Talk:War
# Added: False
#
# Status 480,
# Page: https://en.wikipedia.org/wiki/Main_Page
# Added: False
#
# Status 481,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Contents
# Added: False
#
# Status 482,
# Page: https://en.wikipedia.org/wiki/Portal:Current_events
# Added: False
#
# Status 483,
# Page: https://en.wikipedia.org/wiki/Wikipedia:About
# Added: False
#
# Status 484,
# Page: https://en.wikipedia.org/wiki/Help:Contents
# Added: False
#
# Status 485,
# Page: https://en.wikipedia.org/wiki/Wikipedia:Community_portal
# Added: False
#
# Status 486,
# Page: https://en.wikipedia.org/wiki/Special:RecentChanges
# Added: False
#
# Status 487,
# Page: https://en.wikipedia.org/wiki/Special:WhatLinksHere/War
# Added: False
#
# Status 488,
# Page: https://en.wikipedia.org/wiki/Special:RecentChangesLinked/War
# Added: True
#
# Status 489,
# Page: https://en.wikipedia.org/wiki/Conflict_zone
# Added: False
#
# Status 490,
# Page: https://en.wikipedia.org/wiki/Video_game_developer
# Added: False
#
# Status 491,
# Page: https://en.wikipedia.org/wiki/Video_game_publisher
# Added: False
#
# Status 492,
# Page: https://en.wikipedia.org/wiki/Ubi_Soft
# Added: False
#
# Status 493,
# Page: https://en.wikipedia.org/wiki/Dreamcast
# Added: False
#
# Status 494,
# Page: https://en.wikipedia.org/wiki/Microsoft_Windows
# Added: False
#
# Status 495,
# Page: https://en.wikipedia.org/wiki/North_America
# Added: False
#
# Status 496,
# Page: https://en.wikipedia.org/wiki/Video_game_genre
# Added: False
#
# Status 497,
# Page: https://en.wikipedia.org/wiki/Real_time_strategy
# Added: False
#
# Status 498,
# Page: https://en.wikipedia.org/wiki/Single_player
# Added: False
#
# Status 499,
# Page: https://en.wikipedia.org/wiki/Multiplayer_video_game
# Added: False
#
# Status 500,
# Page: https://en.wikipedia.org/wiki/Real-time_strategy_game
# Added: False
#                                                 text  \
# 0  War - Wikipedia\nWar\nFrom Wikipedia, the free...
# 1  Conflict Zone - Wikipedia\nConflict Zone\nFrom...
# 2  Stele of the Vultures - Wikipedia\nStele of th...
# 3  Battle of Hastings - Wikipedia\nBattle of Hast...
# 4  French invasion of Russia - Wikipedia\nFrench ...
#
#                                    title  \
# 0                        War - Wikipedia
# 1              Conflict Zone - Wikipedia
# 2      Stele of the Vultures - Wikipedia
# 3         Battle of Hastings - Wikipedia
# 4  French invasion of Russia - Wikipedia
#
#                                                  url  depth  links      time
# 0                  https://en.wikipedia.org/wiki/War      0   1579  0.456161
# 1        https://en.wikipedia.org/wiki/Conflict_Zone      1    201  0.286110
# 2  https://en.wikipedia.org/wiki/Stele_of_the_Vul...      1    577  0.357884
# 3   https://en.wikipedia.org/wiki/Battle_of_Hastings      1   1058  0.419137
# 4  https://en.wikipedia.org/wiki/Retreat_from_Moscow      1   2239  0.467541

# %%
result2 = copy.deepcopy(df)

# %% [markdown]
# Снова отформатируем нашу таблицу.

# %%
work_df = copy.deepcopy(df)
work_df['nice_text'] = work_df["text"].apply(hard_text_filter)
work_df['nice_url'] = work_df["url"].apply(hard_url_filter)
work_df['is_target'] = work_df["nice_url"] & work_df["nice_text"]
work_df['words'] = work_df["text"].apply(lambda x: len(x.split()))
work_df = work_df.reindex(columns=['words', 'is_target', 'depth', 'links', 'time'])
work_df
# Out:
#      words  is_target  depth  links      time
# 0    11321       True      0   1579  0.456161
# 1     1150      False      1    201  0.286110
# 2     3002      False      1    577  0.357884
# 3     8800      False      1   1058  0.419137
# 4    16290      False      1   2239  0.467541
# ..     ...        ...    ...    ...       ...
# 496   2778      False      2    574  0.326159
# 497   7361      False      2    880  0.375559
# 498   1598      False      2    299  0.313116
# 499   2985      False      2    561  0.363640
# 500   7361      False      2    880  0.391335
#
# [501 rows x 5 columns]

# %% [markdown]
# Построим визуализацию.

# %%
with sns.axes_style('whitegrid'):
    ax = sns.scatterplot(data=work_df, x='words', y='links', hue='is_target', s=100)
    ax.set_title("Статьи на вики")
    ax.set_xlabel("Количество слов")
    ax.set_ylabel("Количество ссылок")

# %% [markdown]
# **Вывод:** Видна линейная зависимость. Как-то особенно статьи c Войной про Росиию не выделяются на этом графике.

# %% [markdown]
# **4.** Предложите функцию фильтрации web-страниц, которую нужно подать в `load_web_pages`, чтобы среди скачанных сайтов был больше процент страниц из выбранной вами категории.

# %%
def url_filter(url):    
    if 'en.wikipedia.org' not in url:
        return False  
    
    accepted = []
    
    for token in accepted:
        if token in url:
            return True
    
    prohibited = ["#", "?", "&", "%", "File", "(", ".jpg"]
    
    for token in prohibited:
        if token in url:
            return False
    
    article = url.split('/')[-1]
    
    prohibited = [':']
    
    for token in prohibited:
        if token in article:
            return False
    
    return True

def soft_html_filter(html_object):
    accepted = ["warrior", "battle", "weapon",
                "conflict", "military", "forces",
                "fighting", "combat", "raid"]
    for token in accepted:
        if token in html_object["text"].lower():
            return True
    return False

def hard_html_filter(html_object):
    accepted_text = ["war", "russia"]
    for token in accepted_text:
        if token not in html_object["text"].lower():
            return False
    accepted_url = ["war", "conflict"]
    for token in accepted_url:
        if token in html_object["url"].lower():
            return True
    
    return False

# %% [markdown]
# Скачайте снова не менее $500$ страниц, но уже с новой функцией фильтрации. Добавьте следующую информацию к каждой странице:
#
# * глубина в обходе,
# * время скачивания страницы.
#
# Для замера времени можете воспользоваться функцией `time` из пакета `time`.

# %%
raise Exception("Do not launch")

MAX_DOWNLOADS = 500
SEED = "https://en.wikipedia.org/wiki/War"

df = pd.DataFrame(load_web_pages(SEED, MAX_DOWNLOADS, url_filter,
                                    soft_html_filter, hard_html_filter))
df
# Out:
# Status 0,
# Page: https://en.wikipedia.org/wiki/War
# Added: True
#
# Status 1,
# Page: https://en.wikipedia.org/wiki/Conflict_Zone
# Added: False
#
# Status 2,
# Page: https://en.wikipedia.org/wiki/Stele_of_the_Vultures
# Added: False
#
# Status 3,
# Page: https://en.wikipedia.org/wiki/Battle_of_Hastings
# Added: False
#
# Status 4,
# Page: https://en.wikipedia.org/wiki/Retreat_from_Moscow
# Added: False
#
# Status 5,
# Page: https://en.wikipedia.org/wiki/Battle_of_the_Somme
# Added: False
#
# Status 6,
# Page: https://en.wikipedia.org/wiki/Normandy_landings
# Added: False
#
# Status 7,
# Page: https://en.wikipedia.org/wiki/Nuclear_weapon
# Added: False
#
# Status 8,
# Page: https://en.wikipedia.org/wiki/Military_history
# Added: False
#
# Status 9,
# Page: https://en.wikipedia.org/wiki/Prehistoric_warfare
# Added: False
#
# Status 10,
# Page: https://en.wikipedia.org/wiki/Ancient_warfare
# Added: False
#
# Status 11,
# Page: https://en.wikipedia.org/wiki/Medieval_warfare
# Added: True
#
# Status 12,
# Page: https://en.wikipedia.org/wiki/Early_modern_warfare
# Added: True
#
# Status 13,
# Page: https://en.wikipedia.org/wiki/Modern_warfare
# Added: True
#
# Status 14,
# Page: https://en.wikipedia.org/wiki/Industrial_warfare
# Added: True
#
# Status 15,
# Page: https://en.wikipedia.org/wiki/Fourth-generation_warfare
# Added: True
#
# Status 16,
# Page: https://en.wikipedia.org/wiki/Battlespace
# Added: False
#
# Status 17,
# Page: https://en.wikipedia.org/wiki/Aerial_warfare
# Added: False
#
# Status 18,
# Page: https://en.wikipedia.org/wiki/Airborne_forces
# Added: False
#
# Status 19,
# Page: https://en.wikipedia.org/wiki/Space_warfare
# Added: True
#
# Status 20,
# Page: https://en.wikipedia.org/wiki/Ground_warfare
# Added: False
#
# Status 21,
# Page: https://en.wikipedia.org/wiki/Cold-weather_warfare
# Added: True
#
# Status 22,
# Page: https://en.wikipedia.org/wiki/Desert_warfare
# Added: False
#
# Status 23,
# Page: https://en.wikipedia.org/wiki/Jungle_warfare
# Added: False
#
# Status 24,
# Page: https://en.wikipedia.org/wiki/Mountain_warfare
# Added: True
#
# Status 25,
# Page: https://en.wikipedia.org/wiki/Urban_warfare
# Added: True
#
# Status 26,
# Page: https://en.wikipedia.org/wiki/Naval_warfare
# Added: True
#
# Status 27,
# Page: https://en.wikipedia.org/wiki/Amphibious_warfare
# Added: True
#
# Status 28,
# Page: https://en.wikipedia.org/wiki/Blue-water_navy
# Added: False
#
# Status 29,
# Page: https://en.wikipedia.org/wiki/Brown-water_navy
# Added: False
#
# Status 30,
# Page: https://en.wikipedia.org/wiki/Green-water_navy
# Added: False
#
# Status 31,
# Page: https://en.wikipedia.org/wiki/Surface_warfare
# Added: False
#
# Status 32,
# Page: https://en.wikipedia.org/wiki/Underwater_warfare
# Added: True
#
# Status 33,
# Page: https://en.wikipedia.org/wiki/Subterranean_warfare
# Added: False
#
# Status 34,
# Page: https://en.wikipedia.org/wiki/Tunnel_warfare
# Added: True
#
# Status 35,
# Page: https://en.wikipedia.org/wiki/Cyberwarfare
# Added: True
#
# Status 36,
# Page: https://en.wikipedia.org/wiki/Information_warfare
# Added: True
#
# Status 37,
# Page: https://en.wikipedia.org/wiki/Weapon
# Added: False
#
# Status 38,
# Page: https://en.wikipedia.org/wiki/Armoured_warfare
# Added: True
#
# Status 39,
# Page: https://en.wikipedia.org/wiki/Artillery
# Added: False
#
# Status 40,
# Page: https://en.wikipedia.org/wiki/Biological_warfare
# Added: True
#
# Status 41,
# Page: https://en.wikipedia.org/wiki/Military_camouflage
# Added: False
#
# Status 42,
# Page: https://en.wikipedia.org/wiki/Cavalry
# Added: False
#
# Status 43,
# Page: https://en.wikipedia.org/wiki/Chemical_warfare
# Added: True
#
# Status 44,
# Page: https://en.wikipedia.org/wiki/Class_conflict
# Added: True
#
# Status 45,
# Page: https://en.wikipedia.org/wiki/Combined_arms
# Added: False
#
# Status 46,
# Page: https://en.wikipedia.org/wiki/Conventional_warfare
# Added: True
#
# Status 47,
# Page: https://en.wikipedia.org/wiki/Cyberweapon
# Added: False
#
# Status 48,
# Page: https://en.wikipedia.org/wiki/Area_denial_weapon
# Added: False
#
# Status 49,
# Page: https://en.wikipedia.org/wiki/Disinformation
# Added: False
#
# Status 50,
# Page: https://en.wikipedia.org/wiki/Drone_strike
# Added: False
#
# Status 51,
# Page: https://en.wikipedia.org/wiki/Electronic_warfare
# Added: True
#
# Status 52,
# Page: https://en.wikipedia.org/wiki/Infantry
# Added: False
#
# Status 53,
# Page: https://en.wikipedia.org/wiki/Lawfare
# Added: False
#
# Status 54,
# Page: https://en.wikipedia.org/wiki/Loitering_munition
# Added: False
#
# Status 55,
# Page: https://en.wikipedia.org/wiki/Martial_music
# Added: False
#
# Status 56,
# Page: https://en.wikipedia.org/wiki/Nuclear_warfare
# Added: True
#
# Status 57,
# Page: https://en.wikipedia.org/wiki/Psychological_warfare
# Added: True
#
# Status 58,
# Page: https://en.wikipedia.org/wiki/Unconventional_warfare
# Added: False
#
# Status 59,
# Page: https://en.wikipedia.org/wiki/Military_tactics
# Added: False
#
# Status 60,
# Page: https://en.wikipedia.org/wiki/List_of_military_tactics
# Added: False
#
# Status 61,
# Page: https://en.wikipedia.org/wiki/Air_combat_manoeuvring
# Added: False
#
# Status 62,
# Page: https://en.wikipedia.org/wiki/Battle
# Added: False
#
# Status 63,
# Page: https://en.wikipedia.org/wiki/Cavalry_tactics
# Added: False
#
# Status 64,
# Page: https://en.wikipedia.org/wiki/Counterattack
# Added: False
#
# Status 65,
# Page: https://en.wikipedia.org/wiki/Counterinsurgency
# Added: False
#
# Status 66,
# Page: https://en.wikipedia.org/wiki/Defeat_in_detail
# Added: False
#
# Status 67,
# Page: https://en.wikipedia.org/wiki/Defensive_fighting_position
# Added: False
#
# Status 68,
# Page: https://en.wikipedia.org/wiki/Envelopment
# Added: False
#
# Status 69,
# Page: https://en.wikipedia.org/wiki/Guerrilla_warfare
# Added: True
#
# Status 70,
# Page: https://en.wikipedia.org/wiki/Morale
# Added: False
#
# Status 71,
# Page: https://en.wikipedia.org/wiki/Shock_and_awe
# Added: False
#
# Status 72,
# Page: https://en.wikipedia.org/wiki/Siege
# Added: False
#
# Status 73,
# Page: https://en.wikipedia.org/wiki/Tactical_objective
# Added: False
#
# Status 74,
# Page: https://en.wikipedia.org/wiki/Saturation_attack
# Added: False
#
# Status 75,
# Page: https://en.wikipedia.org/wiki/Trench_warfare
# Added: True
#
# Status 76,
# Page: https://en.wikipedia.org/wiki/Operational_level_of_war
# Added: True
#
# Status 77,
# Page: https://en.wikipedia.org/wiki/Blitzkrieg
# Added: False
#
# Status 78,
# Page: https://en.wikipedia.org/wiki/Expeditionary_warfare
# Added: True
#
# Status 79,
# Page: https://en.wikipedia.org/wiki/Deep_operation
# Added: False
#
# Status 80,
# Page: https://en.wikipedia.org/wiki/Maneuver_warfare
# Added: True
#
# Status 81,
# Page: https://en.wikipedia.org/wiki/Operational_manoeuvre_group
# Added: False
#
# Status 82,
# Page: https://en.wikipedia.org/wiki/Military_strategy
# Added: False
#
# Status 83,
# Page: https://en.wikipedia.org/wiki/List_of_military_strategies_and_concepts
# Added: False
#
# Status 84,
# Page: https://en.wikipedia.org/wiki/Attrition_warfare
# Added: True
#
# Status 85,
# Page: https://en.wikipedia.org/wiki/Counter-offensive
# Added: False
#
# Status 86,
# Page: https://en.wikipedia.org/wiki/Culminating_point
# Added: False
#
# Status 87,
# Page: https://en.wikipedia.org/wiki/Defence_in_depth
# Added: False
#
# Status 88,
# Page: https://en.wikipedia.org/wiki/Fabian_strategy
# Added: False
#
# Status 89,
# Page: https://en.wikipedia.org/wiki/Mosaic_Warfare
# Added: False
#
# Status 90,
# Page: https://en.wikipedia.org/wiki/Military_deception
# Added: False
#
# Status 91,
# Page: https://en.wikipedia.org/wiki/Strategic_defence
# Added: False
#
# Status 92,
# Page: https://en.wikipedia.org/wiki/Strategic_depth
# Added: False
#
# Status 93,
# Page: https://en.wikipedia.org/wiki/Naval_strategy
# Added: False
#
# Status 94,
# Page: https://en.wikipedia.org/wiki/Scorched_earth
# Added: False
#
# Status 95,
# Page: https://en.wikipedia.org/wiki/Grand_strategy
# Added: False
#
# Status 96,
# Page: https://en.wikipedia.org/wiki/Containment
# Added: False
#
# Status 97,
# Page: https://en.wikipedia.org/wiki/Economic_warfare
# Added: False
#
# Status 98,
# Page: https://en.wikipedia.org/wiki/Limited_war
# Added: True
#
# Status 99,
# Page: https://en.wikipedia.org/wiki/Philosophy_of_war
# Added: True
#
# Status 100,
# Page: https://en.wikipedia.org/wiki/Political_warfare
# Added: True
#
# Status 101,
# Page: https://en.wikipedia.org/wiki/Religious_war
# Added: False
#
# Status 102,
# Page: https://en.wikipedia.org/wiki/Strategic_studies
# Added: False
#
# Status 103,
# Page: https://en.wikipedia.org/wiki/Military_technology
# Added: False
#
# Status 104,
# Page: https://en.wikipedia.org/wiki/Total_war
# Added: True
#
# Status 105,
# Page: https://en.wikipedia.org/wiki/Military_administration
# Added: False
# Status 106,
# Page: https://en.wikipedia.org/wiki/Military_branch
# Added: False
#
# Status 107,
# Page: https://en.wikipedia.org/wiki/Military_policy
# Added: False
#
# Status 108,
# Page: https://en.wikipedia.org/wiki/Military_education_and_training
# Added: False
#
# Status 109,
# Page: https://en.wikipedia.org/wiki/Military_service
# Added: False
#
# Status 110,
# Page: https://en.wikipedia.org/wiki/Military_sociology
# Added: False
#
# Status 111,
# Page: https://en.wikipedia.org/wiki/Military_organization
# Added: False
#
# Status 112,
# Page: https://en.wikipedia.org/wiki/Command_hierarchy
# Added: False
#
# Status 113,
# Page: https://en.wikipedia.org/wiki/Command_and_control
# Added: False
#
# Status 114,
# Page: https://en.wikipedia.org/wiki/Military_doctrine
# Added: False
#
# Status 115,
# Page: https://en.wikipedia.org/wiki/Military_engineering
# Added: False
#
# Status 116,
# Page: https://en.wikipedia.org/wiki/Military_intelligence
# Added: False
#
# Status 117,
# Page: https://en.wikipedia.org/wiki/Military_rank
# Added: False
#
# Status 118,
# Page: https://en.wikipedia.org/wiki/Military_personnel
# Added: False
#
# Status 119,
# Page: https://en.wikipedia.org/wiki/Military_recruitment
# Added: False
#
# Status 120,
# Page: https://en.wikipedia.org/wiki/Conscription
# Added: False
#
# Status 121,
# Page: https://en.wikipedia.org/wiki/Recruit_training
# Added: False
#
# Status 122,
# Page: https://en.wikipedia.org/wiki/Military_specialism
# Added: False
#
# Status 123,
# Page: https://en.wikipedia.org/wiki/Women_in_the_military
# Added: False
#
# Status 124,
# Page: https://en.wikipedia.org/wiki/Children_in_the_military
# Added: False
#
# Status 125,
# Page: https://en.wikipedia.org/wiki/Transgender_people_and_military_service
# Added: False
#
# Status 126,
# Page: https://en.wikipedia.org/wiki/Sexual_harassment_in_the_military
# Added: False
#
# Status 127,
# Page: https://en.wikipedia.org/wiki/Conscientious_objector
# Added: False
#
# Status 128,
# Page: https://en.wikipedia.org/wiki/Counter-recruitment
# Added: False
#
# Status 129,
# Page: https://en.wikipedia.org/wiki/Military_logistics
# Added: False
#
# Status 130,
# Page: https://en.wikipedia.org/wiki/Arms_industry
# Added: False
#
# Status 131,
# Page: https://en.wikipedia.org/wiki/Materiel
# Added: False
#
# Status 132,
# Page: https://en.wikipedia.org/wiki/Military_supply-chain_management
# Added: False
#
# Status 133,
# Page: https://en.wikipedia.org/wiki/Main_operating_base
# Added: False
#
# Status 134,
# Page: https://en.wikipedia.org/wiki/Forward_operating_base
# Added: False
#
# Status 135,
# Page: https://en.wikipedia.org/wiki/Military_science
# Added: False
#
# Status 136,
# Page: https://en.wikipedia.org/wiki/Power_projection
# Added: False
#
# Status 137,
# Page: https://en.wikipedia.org/wiki/Loss_of_Strength_Gradient
# Added: False
#
# Status 138,
# Page: https://en.wikipedia.org/wiki/Law_of_war
# Added: False
#
# Status 139,
# Page: https://en.wikipedia.org/wiki/Court-martial
# Added: False
#
# Status 140,
# Page: https://en.wikipedia.org/wiki/Military_justice
# Added: False
#
# Status 141,
# Page: https://en.wikipedia.org/wiki/Perfidy
# Added: False
#
# Status 142,
# Page: https://en.wikipedia.org/wiki/Martial_law
# Added: False
#
# Status 143,
# Page: https://en.wikipedia.org/wiki/War_crime
# Added: True
#
# Status 144,
# Page: https://en.wikipedia.org/wiki/Military_theory
# Added: False
#
# Status 145,
# Page: https://en.wikipedia.org/wiki/Air_supremacy
# Added: False
#
# Status 146,
# Page: https://en.wikipedia.org/wiki/Full-spectrum_dominance
# Added: False
#
# Status 147,
# Page: https://en.wikipedia.org/wiki/Overmatch
# Added: False
#
# Status 148,
# Page: https://en.wikipedia.org/wiki/Asymmetric_warfare
# Added: False
#
# Status 149,
# Page: https://en.wikipedia.org/wiki/Broken-backed_war_theory
# Added: False
#
# Status 150,
# Page: https://en.wikipedia.org/wiki/Horses_in_warfare
# Added: True
#
# Status 151,
# Page: https://en.wikipedia.org/wiki/Irregular_warfare
# Added: False
#
# Status 152,
# Page: https://en.wikipedia.org/wiki/Just_war_theory
# Added: True
#
# Status 153,
# Page: https://en.wikipedia.org/wiki/Mercenary
# Added: False
#
# -------EXCEPTION-------
# encoding with 'idna' codec failed (UnicodeError: label empty or too long)
#
# Status 154,
# Page: https://en.wikipedia.org/wiki/Military_campaign
# Added: False
#
# Status 155,
# Page: https://en.wikipedia.org/wiki/Military_operation
# Added: False
#
# Status 156,
# Page: https://en.wikipedia.org/wiki/Network-centric_warfare
# Added: False
#
# Status 157,
# Page: https://en.wikipedia.org/wiki/Operations_research
# Added: False
#
# Status 158,
# Page: https://en.wikipedia.org/wiki/Perpetual_war
# Added: False
#
# Status 159,
# Page: https://en.wikipedia.org/wiki/Principles_of_war
# Added: True
#
# Status 160,
# Page: https://en.wikipedia.org/wiki/Proxy_war
# Added: False
#
# Status 161,
# Page: https://en.wikipedia.org/wiki/Security_dilemma
# Added: False
#
# Status 162,
# Page: https://en.wikipedia.org/wiki/Tripwire_force
# Added: False
#
# Status 163,
# Page: https://en.wikipedia.org/wiki/War_film
# Added: True
#
# Status 164,
# Page: https://en.wikipedia.org/wiki/Military_exercise
# Added: False
#
# Status 165,
# Page: https://en.wikipedia.org/wiki/War_novel
# Added: True
#
# Status 166,
# Page: https://en.wikipedia.org/wiki/Wartime_sexual_violence
# Added: True
#
# Status 167,
# Page: https://en.wikipedia.org/wiki/Women_in_war
# Added: False
#
# Status 168,
# Page: https://en.wikipedia.org/wiki/World_war
# Added: True
#
# Status 169,
# Page: https://en.wikipedia.org/wiki/Colonial_war
# Added: True
#
# Status 170,
# Page: https://en.wikipedia.org/wiki/Endemic_warfare
# Added: False
#
# Status 171,
# Page: https://en.wikipedia.org/wiki/Lists_of_battles
# Added: False
#
# Status 172,
# Page: https://en.wikipedia.org/wiki/List_of_military_occupations
# Added: False
#
# Status 173,
# Page: https://en.wikipedia.org/wiki/List_of_military_operations
# Added: False
#
# Status 174,
# Page: https://en.wikipedia.org/wiki/List_of_sieges
# Added: False
#
# Status 175,
# Page: https://en.wikipedia.org/wiki/List_of_war_crimes
# Added: True
#
# Status 176,
# Page: https://en.wikipedia.org/wiki/Lists_of_weapons
# Added: False
#
# Status 177,
# Page: https://en.wikipedia.org/wiki/List_of_military_writers
# Added: False
#
# Status 178,
# Page: https://en.wikipedia.org/wiki/Government
# Added: False
#
# Status 179,
# Page: https://en.wikipedia.org/wiki/Society
# Added: False
#
# Status 180,
# Page: https://en.wikipedia.org/wiki/Paramilitary
# Added: False
#
# Status 181,
# Page: https://en.wikipedia.org/wiki/Insurgency
# Added: False
#
# Status 182,
# Page: https://en.wikipedia.org/wiki/Militia
# Added: False
#
# Status 183,
# Page: https://en.wikipedia.org/wiki/Violence
# Added: False
#
# Status 184,
# Page: https://en.wikipedia.org/wiki/Aggression
# Added: False
#
# Status 185,
# Page: https://en.wikipedia.org/wiki/Regular_army
# Added: False
#
# Status 186,
# Page: https://en.wikipedia.org/wiki/Irregular_military
# Added: False
#
# Status 187,
# Page: https://en.wikipedia.org/wiki/Military_forces
# Added: False
#
# Status 188,
# Page: https://en.wikipedia.org/wiki/Legitimate_military_target
# Added: False
#
# Status 189,
# Page: https://en.wikipedia.org/wiki/Civilian_casualties
# Added: False
#
# Status 190,
# Page: https://en.wikipedia.org/wiki/Non-combatant
# Added: False
#
# Status 191,
# Page: https://en.wikipedia.org/wiki/War_studies
# Added: False
#
# Status 192,
# Page: https://en.wikipedia.org/wiki/Human_nature
# Added: False
#
# Status 193,
# Page: https://en.wikipedia.org/wiki/Old_English
# Added: False
#
# Status 194,
# Page: https://en.wikipedia.org/wiki/Franks
# Added: False
#
# Status 195,
# Page: https://en.wikipedia.org/wiki/Proto-Germanic_language
# Added: False
#
# Status 196,
# Page: https://en.wikipedia.org/wiki/Siege_of_Dapur
# Added: False
#
# Status 197,
# Page: https://en.wikipedia.org/wiki/Ramesseum
# Added: False
#
# Status 198,
# Page: https://en.wikipedia.org/wiki/Thebes,_Egypt
# Added: False
#
# Status 199,
# Page: https://en.wikipedia.org/wiki/Mesolithic
# Added: False
#
# Status 200,
# Page: https://en.wikipedia.org/wiki/Jebel_Sahaba
# Added: False
#
# Status 201,
# Page: https://en.wikipedia.org/wiki/Gunpowder
# Added: False
#
# Status 202,
# Page: https://en.wikipedia.org/wiki/War_Before_Civilization
# Added: True
#
# Status 203,
# Page: https://en.wikipedia.org/wiki/Samurai
# Added: False
#
# Status 204,
# Page: https://en.wikipedia.org/wiki/Mongol_Empire
# Added: False
#
# Status 205,
# Page: https://en.wikipedia.org/wiki/Winter_War
# Added: True
#
# Status 206,
# Page: https://en.wikipedia.org/wiki/Atom_bomb
# Added: False
#
# Status 207,
# Page: https://en.wikipedia.org/wiki/Albert_Einstein
# Added: False
#
# Status 208,
# Page: https://en.wikipedia.org/wiki/Mao_Zedong
# Added: False
# Status 209,
# Page: https://en.wikipedia.org/wiki/Nuclear_war
# Added: True
#
# Status 210,
# Page: https://en.wikipedia.org/wiki/Indo-Pakistani_War_of_1971
# Added: True
#
# Status 211,
# Page: https://en.wikipedia.org/wiki/Gulf_War
# Added: True
#
# Status 212,
# Page: https://en.wikipedia.org/wiki/Human_Security_Report_2005
# Added: False
#
# Status 213,
# Page: https://en.wikipedia.org/wiki/Cold_War
# Added: True
#
# Status 214,
# Page: https://en.wikipedia.org/wiki/Australian_4th_Division
# Added: False
#
# Status 215,
# Page: https://en.wikipedia.org/wiki/Chemical_weapons_in_World_War_I
# Added: True
#
# Status 216,
# Page: https://en.wikipedia.org/wiki/Third_Battle_of_Ypres
# Added: False
#
# Status 217,
# Page: https://en.wikipedia.org/wiki/Belligerent
# Added: False
#
# Status 218,
# Page: https://en.wikipedia.org/wiki/World_War_I
# Added: True
#
# Status 219,
# Page: https://en.wikipedia.org/wiki/Cold_warfare
# Added: True
#
# Status 220,
# Page: https://en.wikipedia.org/wiki/Covert_operation
# Added: False
#
# Status 221,
# Page: https://en.wikipedia.org/wiki/Espionage
# Added: False
#
# Status 222,
# Page: https://en.wikipedia.org/wiki/Biological_weapon
# Added: False
#
# Status 223,
# Page: https://en.wikipedia.org/wiki/Chemical_weapons
# Added: False
#
# Status 224,
# Page: https://en.wikipedia.org/wiki/Computer
# Added: False
#
# Status 225,
# Page: https://en.wikipedia.org/wiki/Computer_network
# Added: False
#
# Status 226,
# Page: https://en.wikipedia.org/wiki/Laws_of_war
# Added: False
#
# Status 227,
# Page: https://en.wikipedia.org/wiki/War_effort
# Added: True
#
# Status 228,
# Page: https://en.wikipedia.org/wiki/Lebensraum
# Added: False
#
# Status 229,
# Page: https://en.wikipedia.org/wiki/Anglo-Dutch_Wars
# Added: True
#
# Status 230,
# Page: https://en.wikipedia.org/wiki/Effects_of_war
# Added: True
#
# Status 231,
# Page: https://en.wikipedia.org/wiki/World_War_II
# Added: True
#
# Status 232,
# Page: https://en.wikipedia.org/wiki/List_of_wars_by_death_toll
# Added: True
#
# Status 233,
# Page: https://en.wikipedia.org/wiki/Casualty_recording
# Added: False
#
# Status 234,
# Page: https://en.wikipedia.org/wiki/Mongol_conquests
# Added: False
#
# Status 235,
# Page: https://en.wikipedia.org/wiki/Modern_history
# Added: False
#
# Status 236,
# Page: https://en.wikipedia.org/wiki/Paraguayan_War
# Added: False
#
# Status 237,
# Page: https://en.wikipedia.org/wiki/Paraguayan_War_casualties
# Added: False
#
# Status 238,
# Page: https://en.wikipedia.org/wiki/Famine
# Added: False
#
# Status 239,
# Page: https://en.wikipedia.org/wiki/Prisoner_of_war
# Added: True
#
# Status 240,
# Page: https://en.wikipedia.org/wiki/Byelorussian_Soviet_Socialist_Republic
# Added: False
#
# Status 241,
# Page: https://en.wikipedia.org/wiki/Propaganda
# Added: False
#
# Status 242,
# Page: https://en.wikipedia.org/wiki/Weapons_manufacturers
# Added: False
#
# Status 243,
# Page: https://en.wikipedia.org/wiki/Second_Sino-Japanese_War
# Added: True
#
# Status 244,
# Page: https://en.wikipedia.org/wiki/World_War_II_casualties
# Added: True
#
# Status 245,
# Page: https://en.wikipedia.org/wiki/Tatar_invasions
# Added: False
#
# Status 246,
# Page: https://en.wikipedia.org/wiki/Taiping_Rebellion
# Added: False
#
# Status 247,
# Page: https://en.wikipedia.org/wiki/World_War_I_casualties
# Added: True
#
# Status 248,
# Page: https://en.wikipedia.org/wiki/An_Lushan_Rebellion
# Added: False
#
# Status 249,
# Page: https://en.wikipedia.org/wiki/Qing_dynasty
# Added: False
#
# Status 250,
# Page: https://en.wikipedia.org/wiki/Ming_dynasty
# Added: False
#
# Status 251,
# Page: https://en.wikipedia.org/wiki/Tamerlane
# Added: False
#
# Status 252,
# Page: https://en.wikipedia.org/wiki/Russian_Civil_War
# Added: True
#
# Status 253,
# Page: https://en.wikipedia.org/wiki/Allied_intervention_in_the_Russian_Civil_War
# Added: True
#
# Status 254,
# Page: https://en.wikipedia.org/wiki/Posttraumatic_stress_disorder
# Added: False
#
# Status 255,
# Page: https://en.wikipedia.org/wiki/US_Army
# Added: False
#
# Status 256,
# Page: https://en.wikipedia.org/wiki/S.L.A._Marshall
# Added: False
#
# Status 257,
# Page: https://en.wikipedia.org/wiki/The_Apotheosis_of_War
# Added: True
#
# Status 258,
# Page: https://en.wikipedia.org/wiki/Vasily_Vereshchagin
# Added: False
#
# Status 259,
# Page: https://en.wikipedia.org/wiki/American_Civil_War
# Added: True
#
# Status 260,
# Page: https://en.wikipedia.org/wiki/United_States_military_casualties_of_war
# Added: True
#
# Status 261,
# Page: https://en.wikipedia.org/wiki/Crow_Indians
# Added: False
#
# Status 262,
# Page: https://en.wikipedia.org/wiki/Napoleon_I_of_France
# Added: False
#
# Status 263,
# Page: https://en.wikipedia.org/wiki/Typhus
# Added: False
#
# Status 264,
# Page: https://en.wikipedia.org/wiki/Royal_Navy
# Added: False
#
# Status 265,
# Page: https://en.wikipedia.org/wiki/Civilian
# Added: False
#
# Status 266,
# Page: https://en.wikipedia.org/wiki/Population
# Added: False
#
# Status 267,
# Page: https://en.wikipedia.org/wiki/Holy_Roman_Empire
# Added: False
#
# Status 268,
# Page: https://en.wikipedia.org/wiki/Genocide
# Added: False
#
# Status 269,
# Page: https://en.wikipedia.org/wiki/Infant_mortality
# Added: False
#
# Status 270,
# Page: https://en.wikipedia.org/wiki/Malnutrition
# Added: False
#
# Status 271,
# Page: https://en.wikipedia.org/wiki/Drinking_water
# Added: False
#
# Status 272,
# Page: https://en.wikipedia.org/wiki/Soviet_Union
# Added: False
#
# Status 273,
# Page: https://en.wikipedia.org/wiki/World_War_II_casualties_of_the_Soviet_Union
# Added: True
#
# Status 274,
# Page: https://en.wikipedia.org/wiki/Military_Keynesianism
# Added: False
#
# Status 275,
# Page: https://en.wikipedia.org/wiki/War_reparations
# Added: True
#
# Status 276,
# Page: https://en.wikipedia.org/wiki/Alsace-Lorraine
# Added: False
#
# Status 277,
# Page: https://en.wikipedia.org/wiki/Great_Depression
# Added: False
#
# Status 278,
# Page: https://en.wikipedia.org/wiki/Keynesian
# Added: False
#
# Status 279,
# Page: https://en.wikipedia.org/wiki/Franco-Prussian_War
# Added: True
#
# Status 280,
# Page: https://en.wikipedia.org/wiki/Russian_Revolution_of_1917
# Added: False
#
# Status 281,
# Page: https://en.wikipedia.org/wiki/Warsaw
# Added: True
#
# Status 282,
# Page: https://en.wikipedia.org/wiki/International_relations_theory
# Added: False
#
# Status 283,
# Page: https://en.wikipedia.org/wiki/List_of_campaigns_of_Suleiman_the_Magnificent
# Added: False
#
# Status 284,
# Page: https://en.wikipedia.org/wiki/Ottoman_wars_in_Europe
# Added: True
#
# Status 285,
# Page: https://en.wikipedia.org/wiki/Carl_von_Clausewitz
# Added: False
#
# Status 286,
# Page: https://en.wikipedia.org/wiki/Psychoanalyst
# Added: False
#
# Status 287,
# Page: https://en.wikipedia.org/wiki/Joost_Meerloo
# Added: False
#
# Status 288,
# Page: https://en.wikipedia.org/wiki/John_Bowlby
# Added: False
#
# Status 289,
# Page: https://en.wikipedia.org/wiki/Inheritance
# Added: False
#
# Status 290,
# Page: https://en.wikipedia.org/wiki/Psychological_projection
# Added: False
#
# Status 291,
# Page: https://en.wikipedia.org/wiki/Ideology
# Added: False
#
# Status 292,
# Page: https://en.wikipedia.org/wiki/Melanie_Klein
# Added: False
#
# Status 293,
# Page: https://en.wikipedia.org/wiki/Adolf_Hitler
# Added: False
#
# Status 294,
# Page: https://en.wikipedia.org/wiki/Battle_of_Schwaderloh
# Added: False
#
# Status 295,
# Page: https://en.wikipedia.org/wiki/Luzerner_Schilling
# Added: False
#
# Status 296,
# Page: https://en.wikipedia.org/wiki/Competition
# Added: False
#
# Status 297,
# Page: https://en.wikipedia.org/wiki/Common_chimpanzee
# Added: False
#
# Status 298,
# Page: https://en.wikipedia.org/wiki/Ant
# Added: False
#
# Status 299,
# Page: https://en.wikipedia.org/wiki/Steven_Pinker
# Added: False
#
# Status 300,
# Page: https://en.wikipedia.org/wiki/Deterrence_theory
# Added: False
#
# Status 301,
# Page: https://en.wikipedia.org/wiki/Revenge
# Added: False
#
# Status 302,
# Page: https://en.wikipedia.org/wiki/Honor
# Added: False
#
# Status 303,
# Page: https://en.wikipedia.org/wiki/Maya_warfare
# Added: False
#
# Status 304,
# Page: https://en.wikipedia.org/wiki/Classic_Maya_collapse
# Added: False
#
# Status 305,
# Page: https://en.wikipedia.org/wiki/Maya_civilization
# Added: False
#
# Status 306,
# Page: https://en.wikipedia.org/wiki/Ashley_Montagu
# Added: False
#
# Status 307,
# Page: https://en.wikipedia.org/wiki/Semai_people
# Added: False
#
# Status 308,
# Page: https://en.wikipedia.org/wiki/Oil_well
# Added: False
#
# Status 309,
# Page: https://en.wikipedia.org/wiki/Natural_resource
# Added: False
#
# Status 310,
# Page: https://en.wikipedia.org/wiki/State-building
# Added: False
#
# Status 311,
# Page: https://en.wikipedia.org/wiki/Fiscal_capacity
# Added: False
#
# Status 312,
# Page: https://en.wikipedia.org/wiki/Presidents_of_the_United_States
# Added: False
# Status 313,
# Page: https://en.wikipedia.org/wiki/General_officer
# Added: False
#
# Status 314,
# Page: https://en.wikipedia.org/wiki/Marxist_explanations_of_warfare
# Added: True
#
# Status 315,
# Page: https://en.wikipedia.org/wiki/Marxism
# Added: False
#
# Status 316,
# Page: https://en.wikipedia.org/wiki/Imperialism
# Added: False
#
# Status 317,
# Page: https://en.wikipedia.org/wiki/Capitalism
# Added: False
#
# Status 318,
# Page: https://en.wikipedia.org/wiki/Karl_Kautsky
# Added: False
#
# Status 319,
# Page: https://en.wikipedia.org/wiki/Rosa_Luxemburg
# Added: False
#
# Status 320,
# Page: https://en.wikipedia.org/wiki/Rudolf_Hilferding
# Added: False
#
# Status 321,
# Page: https://en.wikipedia.org/wiki/Vladimir_Lenin
# Added: False
#
# Status 322,
# Page: https://en.wikipedia.org/wiki/Means_of_production
# Added: False
#
# Status 323,
# Page: https://en.wikipedia.org/wiki/Consumer_demand
# Added: False
#
# Status 324,
# Page: https://en.wikipedia.org/wiki/Capitalist_economy
# Added: False
#
# Status 325,
# Page: https://en.wikipedia.org/wiki/Unified_Task_Force
# Added: False
#
# Status 326,
# Page: https://en.wikipedia.org/wiki/Malthusian_catastrophe
# Added: False
#
# Status 327,
# Page: https://en.wikipedia.org/wiki/Pope_Urban_II
# Added: False
#
# Status 328,
# Page: https://en.wikipedia.org/wiki/First_Crusade
# Added: False
#
# Status 329,
# Page: https://en.wikipedia.org/wiki/Thomas_Malthus
# Added: False
#
# Status 330,
# Page: https://en.wikipedia.org/wiki/Mali
# Added: False
#
# Status 331,
# Page: https://en.wikipedia.org/wiki/Sudanese_nomadic_conflicts
# Added: False
#
# Status 332,
# Page: https://en.wikipedia.org/wiki/Sahel
# Added: False
#
# Status 333,
# Page: https://en.wikipedia.org/wiki/Land_degradation
# Added: False
#
# Status 334,
# Page: https://en.wikipedia.org/wiki/Population_pyramid
# Added: False
#
# Status 335,
# Page: https://en.wikipedia.org/wiki/Demographics_of_Africa
# Added: False
#
# Status 336,
# Page: https://en.wikipedia.org/wiki/Gunnar_Heinsohn
# Added: False
#
# Status 337,
# Page: https://en.wikipedia.org/wiki/Youth_bulge
# Added: False
#
# Status 338,
# Page: https://en.wikipedia.org/wiki/French_Revolution
# Added: False
#
# Status 339,
# Page: https://en.wikipedia.org/wiki/Nazism
# Added: False
#
# Status 340,
# Page: https://en.wikipedia.org/wiki/Rwandan_genocide
# Added: False
#
# Status 341,
# Page: https://en.wikipedia.org/wiki/Population_Action_International
# Added: False
#
# Status 342,
# Page: https://en.wikipedia.org/wiki/Berlin_Institute_for_Population_and_Development
# Added: False
#
# Status 343,
# Page: https://en.wikipedia.org/wiki/Game_theory
# Added: False
#
# Status 344,
# Page: https://en.wikipedia.org/wiki/Peace_war_game
# Added: False
#
# Status 345,
# Page: https://en.wikipedia.org/wiki/James_Fearon
# Added: False
#
# Status 346,
# Page: https://en.wikipedia.org/wiki/Information_asymmetry
# Added: False
#
# Status 347,
# Page: https://en.wikipedia.org/wiki/Geoffrey_Blainey
# Added: False
#
# Status 348,
# Page: https://en.wikipedia.org/wiki/Cognitive_bias
# Added: False
#
# Status 349,
# Page: https://en.wikipedia.org/wiki/Iain_King
# Added: False
#
# Status 350,
# Page: https://en.wikipedia.org/wiki/GroupThink
# Added: False
#
# Status 351,
# Page: https://en.wikipedia.org/wiki/Lewis_Fry_Richardson
# Added: False
#
# Status 352,
# Page: https://en.wikipedia.org/wiki/Correlates_of_War
# Added: False
#
# Status 353,
# Page: https://en.wikipedia.org/wiki/Uppsala_Conflict_Data_Program
# Added: False
#
# Status 354,
# Page: https://en.wikipedia.org/wiki/Kenneth_Waltz
# Added: False
#
# Status 355,
# Page: https://en.wikipedia.org/wiki/Man,_the_State,_and_War
# Added: False
#
# Status 356,
# Page: https://en.wikipedia.org/wiki/Realism_in_international_relations
# Added: False
#
# Status 357,
# Page: https://en.wikipedia.org/wiki/Henry_Kissinger
# Added: False
#
# Status 358,
# Page: https://en.wikipedia.org/wiki/Hans_Morgenthau
# Added: False
#
# Status 359,
# Page: https://en.wikipedia.org/wiki/John_Mearsheimer
# Added: False
#
# Status 360,
# Page: https://en.wikipedia.org/wiki/Power_transition_theory
# Added: False
#
# Status 361,
# Page: https://en.wikipedia.org/wiki/Diversionary_foreign_policy
# Added: False
#
# Status 362,
# Page: https://en.wikipedia.org/wiki/Realistic_conflict_theory
# Added: False
#
# Status 363,
# Page: https://en.wikipedia.org/wiki/Group_cohesiveness
# Added: False
#
# Status 364,
# Page: https://en.wikipedia.org/wiki/Bounded_rationality
# Added: False
#
# Status 365,
# Page: https://en.wikipedia.org/wiki/Cognitive_biases
# Added: False
#
# Status 366,
# Page: https://en.wikipedia.org/wiki/Prospect_theory
# Added: False
#
# Status 367,
# Page: https://en.wikipedia.org/wiki/Battle_of_Waterloo
# Added: False
#
# Status 368,
# Page: https://en.wikipedia.org/wiki/John_Heaviside_Clark
# Added: False
#
# Status 369,
# Page: https://en.wikipedia.org/wiki/Morality
# Added: False
#
# Status 370,
# Page: https://en.wikipedia.org/wiki/Jus_ad_bellum
# Added: False
#
# Status 371,
# Page: https://en.wikipedia.org/wiki/Jus_in_bello
# Added: False
#
# Status 372,
# Page: https://en.wikipedia.org/wiki/Leningrad
# Added: False
#
# Status 373,
# Page: https://en.wikipedia.org/wiki/General_Plan_East
# Added: False
#
# Status 374,
# Page: https://en.wikipedia.org/wiki/International_law
# Added: False
#
# Status 375,
# Page: https://en.wikipedia.org/wiki/Pragmatism
# Added: False
#
# Status 376,
# Page: https://en.wikipedia.org/wiki/Social_Darwinism
# Added: False
#
# Status 377,
# Page: https://en.wikipedia.org/wiki/Archetypes
# Added: False
#
# Status 378,
# Page: https://en.wikipedia.org/wiki/Anti-war_movement
# Added: True
#
# Status 379,
# Page: https://en.wikipedia.org/wiki/Second_Vatican_Council
# Added: False
#
# Status 380,
# Page: https://en.wikipedia.org/wiki/Vietnam_War
# Added: True
#
# Status 381,
# Page: https://en.wikipedia.org/wiki/Iraq_War
# Added: True
#
# Status 382,
# Page: https://en.wikipedia.org/wiki/Mexican_Drug_War
# Added: False
#
# Status 383,
# Page: https://en.wikipedia.org/wiki/Outline_of_war
# Added: True
#
# Status 384,
# Page: https://en.wikipedia.org/wiki/International_Committee_of_the_Red_Cross
# Added: False
#
# Status 385,
# Page: https://en.wikipedia.org/wiki/Wayback_Machine
# Added: False
#
# Status 386,
# Page: https://en.wikipedia.org/wiki/Hugo_Haase
# Added: False
#
# Status 387,
# Page: https://en.wikipedia.org/wiki/Marc_Pilisuk
# Added: False
#
# Status 388,
# Page: https://en.wikipedia.org/wiki/The_New_York_Times
# Added: False
#
# Status 389,
# Page: https://en.wikipedia.org/wiki/Roger_Griffin
# Added: False
#
# Status 390,
# Page: https://en.wikipedia.org/wiki/Marxists_Internet_Archive
# Added: False
#
# Status 391,
# Page: https://en.wikipedia.org/wiki/Foreign_Policy
# Added: False
#
# Status 392,
# Page: https://en.wikipedia.org/wiki/Henrik_Urdal
# Added: False
#
# Status 393,
# Page: https://en.wikipedia.org/wiki/I.C.B._Dear
# Added: False
#
# Status 394,
# Page: https://en.wikipedia.org/wiki/M.R.D._Foot
# Added: False
#
# Status 395,
# Page: https://en.wikipedia.org/wiki/Smedley_Butler
# Added: False
#
# Status 396,
# Page: https://en.wikipedia.org/wiki/War_is_a_Racket
# Added: False
#
# Status 397,
# Page: https://en.wikipedia.org/wiki/John_Keegan
# Added: False
#
# Status 398,
# Page: https://en.wikipedia.org/wiki/A_History_of_Warfare
# Added: False
#
# Status 399,
# Page: https://en.wikipedia.org/wiki/Gabriel_Kolko
# Added: False
#
# Status 400,
# Page: https://en.wikipedia.org/wiki/The_New_Press
# Added: False
#
# Status 401,
# Page: https://en.wikipedia.org/wiki/Strategic_Studies_Institute
# Added: False
#
# Status 402,
# Page: https://en.wikipedia.org/wiki/United_States_Army_War_College
# Added: False
#
# Status 403,
# Page: https://en.wikipedia.org/wiki/Hew_Strachan
# Added: False
#
# Status 404,
# Page: https://en.wikipedia.org/wiki/List_of_periods_of_regional_peace
# Added: False
#
# Status 405,
# Page: https://en.wikipedia.org/wiki/List_of_civil_wars
# Added: True
#
# Status 406,
# Page: https://en.wikipedia.org/wiki/List_of_terrorist_incidents
# Added: False
#
# Status 407,
# Page: https://en.wikipedia.org/wiki/List_of_events_named_massacres
# Added: False
#
# Status 408,
# Page: https://en.wikipedia.org/wiki/List_of_ongoing_armed_conflicts
# Added: True
#
# Status 409,
# Page: https://en.wikipedia.org/wiki/International_relations
# Added: False
#
# Status 410,
# Page: https://en.wikipedia.org/wiki/International_organization
# Added: False
#
# Status 411,
# Page: https://en.wikipedia.org/wiki/BRICS
# Added: False
#
# Status 412,
# Page: https://en.wikipedia.org/wiki/Collective_Security_Treaty_Organization
# Added: False
#
# Status 413,
# Page: https://en.wikipedia.org/wiki/International_Criminal_Court
# Added: False
#
# Status 414,
# Page: https://en.wikipedia.org/wiki/League_of_Nations
# Added: False
# Status 415,
# Page: https://en.wikipedia.org/wiki/Non-Aligned_Movement
# Added: False
#
# Status 416,
# Page: https://en.wikipedia.org/wiki/NATO
# Added: False
#
# Status 417,
# Page: https://en.wikipedia.org/wiki/Shanghai_Cooperation_Organisation
# Added: False
#
# Status 418,
# Page: https://en.wikipedia.org/wiki/United_Nations
# Added: False
#
# Status 419,
# Page: https://en.wikipedia.org/wiki/Warsaw_Pact
# Added: True
#
# Status 420,
# Page: https://en.wikipedia.org/wiki/Political_history_of_the_world
# Added: False
#
# Status 421,
# Page: https://en.wikipedia.org/wiki/Diplomatic_history_of_World_War_II
# Added: True
#
# Status 422,
# Page: https://en.wikipedia.org/wiki/International_relations_since_1989
# Added: False
#
# Status 423,
# Page: https://en.wikipedia.org/wiki/Appeasement
# Added: False
#
# Status 424,
# Page: https://en.wikipedia.org/wiki/Collective_security
# Added: False
#
# Status 425,
# Page: https://en.wikipedia.org/wiki/Colonialism
# Added: False
#
# Status 426,
# Page: https://en.wikipedia.org/wiki/Hegemony
# Added: False
#
# Status 427,
# Page: https://en.wikipedia.org/wiki/Idealism_in_international_relations
# Added: False
#
# Status 428,
# Page: https://en.wikipedia.org/wiki/Liberal_institutionalism
# Added: False
#
# Status 429,
# Page: https://en.wikipedia.org/wiki/Peace
# Added: False
#
# Status 430,
# Page: https://en.wikipedia.org/wiki/Sovereignty
# Added: False
#
# Status 431,
# Page: https://en.wikipedia.org/wiki/Suzerainty
# Added: False
#
# Status 432,
# Page: https://en.wikipedia.org/wiki/Treaty
# Added: False
#
# Status 433,
# Page: https://en.wikipedia.org/wiki/Marxist_international_relations_theory
# Added: False
#
# Status 434,
# Page: https://en.wikipedia.org/wiki/Diplomacy
# Added: False
#
# Status 435,
# Page: https://en.wikipedia.org/wiki/Geopolitics
# Added: False
#
# Status 436,
# Page: https://en.wikipedia.org/wiki/Main_Page
# Added: False
#
# Status 437,
# Page: https://en.wikipedia.org/wiki/Special:WhatLinksHere/War
# Added: False
#
# Status 438,
# Page: https://en.wikipedia.org/wiki/Special:RecentChangesLinked/War
# Added: True
#
# Status 439,
# Page: https://en.wikipedia.org/wiki/Conflict_zone
# Added: True
#
# Status 440,
# Page: https://en.wikipedia.org/wiki/Video_game_developer
# Added: False
#
# Status 441,
# Page: https://en.wikipedia.org/wiki/Video_game_publisher
# Added: False
#
# Status 442,
# Page: https://en.wikipedia.org/wiki/Ubi_Soft
# Added: False
#
# Status 443,
# Page: https://en.wikipedia.org/wiki/Dreamcast
# Added: False
#
# Status 444,
# Page: https://en.wikipedia.org/wiki/Microsoft_Windows
# Added: False
#
# Status 445,
# Page: https://en.wikipedia.org/wiki/North_America
# Added: False
#
# Status 446,
# Page: https://en.wikipedia.org/wiki/Video_game_genre
# Added: False
#
# Status 447,
# Page: https://en.wikipedia.org/wiki/Real_time_strategy
# Added: False
#
# Status 448,
# Page: https://en.wikipedia.org/wiki/Single_player
# Added: False
#
# Status 449,
# Page: https://en.wikipedia.org/wiki/Multiplayer_video_game
# Added: False
#
# Status 450,
# Page: https://en.wikipedia.org/wiki/Real-time_strategy_game
# Added: False
#
# Status 451,
# Page: https://en.wikipedia.org/wiki/Personal_computer
# Added: False
#
# Status 452,
# Page: https://en.wikipedia.org/wiki/GameSpy
# Added: False
#
# Status 453,
# Page: https://en.wikipedia.org/wiki/IGN
# Added: False
#
# Status 454,
# Page: https://en.wikipedia.org/wiki/PC_Zone
# Added: False
#
# Status 455,
# Page: https://en.wikipedia.org/wiki/X-Play
# Added: False
#
# Status 456,
# Page: https://en.wikipedia.org/wiki/Computer_Gaming_World
# Added: False
#
# Status 457,
# Page: https://en.wikipedia.org/wiki/TechTV
# Added: False
#
# Status 458,
# Page: https://en.wikipedia.org/wiki/Special:WhatLinksHere/Conflict_Zone
# Added: False
#
# Status 459,
# Page: https://en.wikipedia.org/wiki/Special:RecentChangesLinked/Conflict_Zone
# Added: False
#
# Status 460,
# Page: https://en.wikipedia.org/wiki/Sumerian_language
# Added: False
#
# Status 461,
# Page: https://en.wikipedia.org/wiki/Girsu
# Added: False
#
# Status 462,
# Page: https://en.wikipedia.org/wiki/Iraq
# Added: False
#
# Status 463,
# Page: https://en.wikipedia.org/wiki/Mesopotamia
# Added: False
#
# Status 464,
# Page: https://en.wikipedia.org/wiki/Lagash
# Added: False
#
# Status 465,
# Page: https://en.wikipedia.org/wiki/Umma
# Added: False
#
# Status 466,
# Page: https://en.wikipedia.org/wiki/Vultures
# Added: False
#
# Status 467,
# Page: https://en.wikipedia.org/wiki/Stele
# Added: False
#
# Status 468,
# Page: https://en.wikipedia.org/wiki/Eannatum
# Added: False
#
# Status 469,
# Page: https://en.wikipedia.org/wiki/Ush,_king_of_Umma
# Added: False
#
# Status 470,
# Page: https://en.wikipedia.org/wiki/British_Museum
# Added: False
#
# Status 471,
# Page: https://en.wikipedia.org/wiki/Victory_Stele_of_Naram-Sin
# Added: False
#
# Status 472,
# Page: https://en.wikipedia.org/wiki/Akkadian_Empire
# Added: False
#
# Status 473,
# Page: https://en.wikipedia.org/wiki/Ninurta
# Added: False
#
# Status 474,
# Page: https://en.wikipedia.org/wiki/Vulture
# Added: False
#
# Status 475,
# Page: https://en.wikipedia.org/wiki/Phalanx_formation
# Added: False
#
# Status 476,
# Page: https://en.wikipedia.org/wiki/Libation
# Added: False
#
# Status 477,
# Page: https://en.wikipedia.org/wiki/Gu-Edin
# Added: False
#
# Status 478,
# Page: https://en.wikipedia.org/wiki/Akurgal
# Added: False
#
# Status 479,
# Page: https://en.wikipedia.org/wiki/Louvre
# Added: False
#
# Status 480,
# Page: https://en.wikipedia.org/wiki/Louvre_Pyramid
# Added: False
#
# Status 481,
# Page: https://en.wikipedia.org/wiki/Medieval_Louvre
# Added: False
#
# Status 482,
# Page: https://en.wikipedia.org/wiki/Amarna_letter_EA_362
# Added: False
#
# Status 483,
# Page: https://en.wikipedia.org/wiki/Amarna_letter_EA_364
# Added: False
#
# Status 484,
# Page: https://en.wikipedia.org/wiki/Amarna_letter_EA_365
# Added: False
#
# Status 485,
# Page: https://en.wikipedia.org/wiki/Amarna_letter_EA_367
# Added: False
#
# Status 486,
# Page: https://en.wikipedia.org/wiki/Assyrian_lion_weights
# Added: False
#
# Status 487,
# Page: https://en.wikipedia.org/wiki/Baal_with_Thunderbolt
# Added: False
#
# Status 488,
# Page: https://en.wikipedia.org/wiki/Bushel_with_ibex_motifs
# Added: False
#
# Status 489,
# Page: https://en.wikipedia.org/wiki/Cippi_of_Melqart
# Added: False
#
# Status 490,
# Page: https://en.wikipedia.org/wiki/Code_of_Hammurabi
# Added: False
#
# Status 491,
# Page: https://en.wikipedia.org/wiki/Eshmunazar_II_sarcophagus
# Added: False
#
# Status 492,
# Page: https://en.wikipedia.org/wiki/Gudea_cylinders
# Added: False
#
# Status 493,
# Page: https://en.wikipedia.org/wiki/Hurrian_foundation_pegs
# Added: False
#
# Status 494,
# Page: https://en.wikipedia.org/wiki/Investiture_of_Zimri-Lim
# Added: False
#
# Status 495,
# Page: https://en.wikipedia.org/wiki/Lament_for_Ur
# Added: False
#
# Status 496,
# Page: https://en.wikipedia.org/wiki/Land_grant_to_Marduk-apla-iddina_I_by_Meli-Shipak_II
# Added: False
#
# Status 497,
# Page: https://en.wikipedia.org/wiki/Land_grant_to_Munnabittu_kudurru
# Added: False
#
# Status 498,
# Page: https://en.wikipedia.org/wiki/Lion_of_Mari
# Added: False
#
# Status 499,
# Page: https://en.wikipedia.org/wiki/Manishtushu_Obelisk
# Added: False
#
# Status 500,
# Page: https://en.wikipedia.org/wiki/Masub_inscription
# Added: False
#                                                   text  \
# 0    War - Wikipedia\nWar\nFrom Wikipedia, the free...
# 1    Conflict Zone - Wikipedia\nConflict Zone\nFrom...
# 2    Stele of the Vultures - Wikipedia\nStele of th...
# 3    Battle of Hastings - Wikipedia\nBattle of Hast...
# 4    French invasion of Russia - Wikipedia\nFrench ...
# ..                                                 ...
# 496  Land grant to Marduk-apla-iddina I by Meli-Shi...
# 497  Land grant to Munnabittu kudurru - Wikipedia\n...
# 498  Lion of Mari - Wikipedia\nLion of Mari\nFrom W...
# 499  Manishtushu Obelisk - Wikipedia\nManishtushu O...
# 500  Masub inscription - Wikipedia\nMasub inscripti...
#
#                                                  title  \
# 0                                      War - Wikipedia
# 1                            Conflict Zone - Wikipedia
# 2                    Stele of the Vultures - Wikipedia
# 3                       Battle of Hastings - Wikipedia
# 4                French invasion of Russia - Wikipedia
# ..                                                 ...
# 496  Land grant to Marduk-apla-iddina I by Meli-Shi...
# 497       Land grant to Munnabittu kudurru - Wikipedia
# 498                           Lion of Mari - Wikipedia
# 499                    Manishtushu Obelisk - Wikipedia
# 500                      Masub inscription - Wikipedia
#
#                                                    url  depth  links      time
# 0                    https://en.wikipedia.org/wiki/War      0   1579  0.431643
# 1          https://en.wikipedia.org/wiki/Conflict_Zone      1    201  0.273327
# 2    https://en.wikipedia.org/wiki/Stele_of_the_Vul...      1    577  0.612042
# 3     https://en.wikipedia.org/wiki/Battle_of_Hastings      1   1058  0.356594
# 4    https://en.wikipedia.org/wiki/Retreat_from_Moscow      1   2239  0.420102
# ..                                                 ...    ...    ...       ...
# 496  https://en.wikipedia.org/wiki/Land_grant_to_Ma...      2    511  0.308160
# 497  https://en.wikipedia.org/wiki/Land_grant_to_Mu...      2    518  0.310945
# 498         https://en.wikipedia.org/wiki/Lion_of_Mari      2    481  0.306115
# 499  https://en.wikipedia.org/wiki/Manishtushu_Obelisk      2    532  0.312592
# 500    https://en.wikipedia.org/wiki/Masub_inscription      2    466  0.301192
#
# [501 rows x 6 columns]

# %%
result3 = copy.deepcopy(df)

# %% [markdown]
# Вновь отформатируем таблицу и посчитаем успешность.

# %%
def hard_url_filter(url):
    accepted_url = ["war", "conflict"]
    for token in accepted_url:
        if token in url.lower():
            return True
    return False

def hard_text_filter(text):
    accepted_text = ["war", "russia"]
    for token in accepted_text:
        if token not in text.lower():
            return False
    return True

work_df = copy.deepcopy(df)
work_df['nice_text'] = work_df["text"].apply(hard_text_filter)
work_df['nice_url'] = work_df["url"].apply(hard_url_filter)
work_df['is_target'] = work_df["nice_url"] & work_df["nice_text"]
work_df['words'] = work_df["text"].apply(lambda x: len(x.split()))
work_df = work_df.reindex(columns=['words', 'is_target', 'depth', 'links', 'time'])
100 * work_df.groupby(by="is_target").count().loc[True].loc["words"] / len(work_df.index)
# Out:
# 16.56686626746507

# %% [markdown]
# Так или иначе - процент колеблется около 16. Вероятно, потому что количество Войн с Россией не исчисляется сотнями.

# %% [markdown]
# Постройте гистограмму для времени скачивания страницы.

# %%
for attr in [True, False]:
    fig, ax = plt.subplots()
    data = work_df[work_df["is_target"] == attr]["time"]
    ax.hist(data[data < 0.6], bins=30)
    ax.set_title(f"Время скачивания статей с is_target={attr}")
    ax.set_xlabel("Время")
    ax.set_ylabel("Количество статей")
    min_ylim, max_ylim = plt.ylim()
    height = 0.9
    for value, text in zip([data.mean(), data.median()],
                           ["Среднее", "Медиана"]):
        plt.axvline(value, color='black', linestyle='solid', linewidth=1)
        plt.text(value*1.1, max_ylim*height,
            text + ': {:.2f}'.format(value), fontdict={'size': 18})
        height -= 0.1
    plt.text(plt.xlim()[1]*0.8, 0.7*max_ylim, 
             'Дисперсия: {:.2f}'.format(data.var()), fontdict={'size': 18, 'weight': 'bold'})

# %% [markdown]
# Предположите, каким известным вам стандартным распределением оно может быть приближено?
#
# Похоже на нормальное, наверное. Попробуем.

# %%
from scipy.stats import norm

fig, ax = plt.subplots()
data = work_df["time"]
data = data[data < 0.6]
ax.hist(data, bins=30, density=True)
ax.set_title("Время скачивания статей")
ax.set_xlabel("Время")
ax.set_ylabel("Количество статей (в у.е.)")

mu, std = norm.fit(data)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)

# %% [markdown]
# **Выводы:**
# 1. Boxplot анализировать проще, чем несколько гистограм.
# 2. Существует линейная зависимость между длиной текста и количеством ссылок в нём.
# 3. В среднем скачивании статьи с вики занимает 0.4 с
# 4. Распределение этой случайной величины приближается нормальным распределением.
